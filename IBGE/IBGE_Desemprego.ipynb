# %%
import pandas as pd

# %%
arquivoCSV = '../Dados/tabela4093.csv'

df1 = pd.read_csv(arquivoCSV
                            , sep=';'
                          , skiprows=3)

# %%
df1.drop(df1.index[34:])
# Out:
#     Brasil, Grande Região e UF 1º trimestre 2018 2º trimestre 2018  \
# 0   Brasil, Grande Região e UF             Total             Total
# 1                       Brasil             13872             13148
# 2                        Norte              1043               994
# 3                     Rondônia                90                69
# 4                         Acre                53                48
# 5                     Amazonas               251               254
# 6                      Roraima                25                28
# 7                         Pará               465               434
# 8                        Amapá                80                80
# 9                    Tocantins                78                81
# 10                    Nordeste              3973              3688
# 11                    Maranhão               423               376
# 12                       Piauí               187               194
# ...

# %%
df1.head(50)
# Out:
#                            Brasil, Grande Região e UF  1º trimestre 2018  \
# 0                          Brasil, Grande Região e UF              Total
# 1                                              Brasil              13872
# 2                                               Norte               1043
# 3                                            Rondônia                 90
# 4                                                Acre                 53
# 5                                            Amazonas                251
# 6                                             Roraima                 25
# 7                                                Pará                465
# 8                                               Amapá                 80
# 9                                           Tocantins                 78
# 10                                           Nordeste               3973
# 11                                           Maranhão                423
# ...

# %%
arquivoCSV = '../Dados/tabela4093.csv'

df2 = pd.read_csv(arquivoCSV
                            , sep=';'
                          , skiprows=43)


df2
# Out:
#                            Brasil, Grande Região e UF  \
# 0                          Brasil, Grande Região e UF
# 1                                              Brasil
# 2                                               Norte
# 3                                            Rondônia
# 4                                                Acre
# 5                                            Amazonas
# 6                                             Roraima
# 7                                                Pará
# 8                                               Amapá
# 9                                           Tocantins
# 10                                           Nordeste
# 11                                           Maranhão
# 12                                              Piauí
# 13                                              Ceará
# 14                                Rio Grande do Norte
# 15                                            Paraíba
# ...
