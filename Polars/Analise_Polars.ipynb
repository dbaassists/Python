# %%
#pip install polars
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import polars as pl

# %%
temp = pl.scan_csv("../Polars/Parking_Violations_Issued_-_Fiscal_Year_2014__August_2013___June_2014_.csv", quote_char=None,
                      ignore_errors = True)

# %%
# Read the data
df = temp.collect()

# %%
df.schema
# Out:
# {'Summons Number': Int64,
#  'Plate ID': Utf8,
#  'Registration State': Utf8,
#  'Plate Type': Utf8,
#  'Issue Date': Utf8,
#  'Violation Code': Int64,
#  'Vehicle Body Type': Utf8,
#  'Vehicle Make': Utf8,
#  'Issuing Agency': Utf8,
#  'Street Code1': Int64,
#  'Street Code2': Int64,
#  'Street Code3': Int64,
#  'Vehicle Expiration Date': Int64,
#  'Violation Location': Int64,
#  'Violation Precinct': Int64,
#  'Issuer Precinct': Int64,
#  'Issuer Code': Int64,
#  'Issuer Command': Utf8,
#  'Issuer Squad': Int64,
#  'Violation Time': Utf8,
#  'Time First Observed': Utf8,
#  'Violation County': Utf8,
#  'Violation In Front Of Or Opposite': Utf8,
#  'House Number': Utf8,
#  'Street Name': Utf8,
#  'Intersecting Street': Utf8,
#  'Date First Observed': Utf8,
#  'Law Section': Int64,
#  'Sub Division': Utf8,
#  'Violation Legal Code': Utf8,
#  'Days Parking In Effect    ': Utf8,
#  'From Hours In Effect': Utf8,
#  'To Hours In Effect': Utf8,
#  'Vehicle Color': Utf8,
# ...

# %%
# Polars
df2 = pl.read_csv("../Polars/Parking_Violations_Issued_-_Fiscal_Year_2014__August_2013___June_2014_.csv"
                # ,infer_schema_length=1000
                 ,ignore_errors=True)

# %%
df3 = pl.read_csv("../Polars/Parking_Violations_Issued_-_Fiscal_Year_2014__August_2013___June_2014_.csv"
                  , columns=['Summons Number', 'Plate ID','Law Section']
                  
                 )

# %%
df3.head()
# Out:
# shape: (5, 3)
# ┌────────────────┬──────────┬─────────────┐
# │ Summons Number ┆ Plate ID ┆ Law Section │
# │ ---            ┆ ---      ┆ ---         │
# │ i64            ┆ str      ┆ i64         │
# ╞════════════════╪══════════╪═════════════╡
# │ 1283294138     ┆ GBB9093  ┆ 408         │
# │ 1283294151     ┆ 62416MB  ┆ 408         │
# │ 1283294163     ┆ 78755JZ  ┆ 408         │
# │ 1283294175     ┆ 63009MA  ┆ 408         │
# │ 1283294187     ┆ 91648MC  ┆ 408         │
# └────────────────┴──────────┴─────────────┘

# %%
#columns=[('Summons Number' , 'NumCodigo')]


import polars as pl
q = (
    pl.scan_csv("../Polars/Parking_Violations_Issued_-_Fiscal_Year_2014__August_2013___June_2014_.csv")
    .select(
    [
        'Summons Number',
        pl.col('Plate ID').str.lengths().alias('NumPlaca'),        
    ])
)
q.collect()
# Out:
# shape: (9100278, 2)
# ┌────────────────┬──────────┐
# │ Summons Number ┆ NumPlaca │
# │ ---            ┆ ---      │
# │ i64            ┆ u32      │
# ╞════════════════╪══════════╡
# │ 1283294138     ┆ 7        │
# │ 1283294151     ┆ 7        │
# │ 1283294163     ┆ 7        │
# │ 1283294175     ┆ 7        │
# │ ...            ┆ ...      │
# │ 8006150217     ┆ 7        │
# │ 8006150242     ┆ 7        │
# │ 8006150254     ┆ 6        │
# │ 8006150278     ┆ 7        │
# └────────────────┴──────────┘

# %%
type(qq)
# Out:
# polars.internals.dataframe.frame.DataFrame

# %%
df4.schema
# Out:
# {'Summons Number': Int64, 'Plate ID': Utf8, 'Registration State': Utf8}

# %%
help(pl.read_csv)
# Out:
# Help on function read_csv in module polars.io:
#
# ...

# %%
df2.schema
# Out:
# {'Summons Number': Int64,
#  'Plate ID': Utf8,
#  'Registration State': Utf8,
#  'Plate Type': Utf8,
#  'Issue Date': Utf8,
#  'Violation Code': Int64,
#  'Vehicle Body Type': Utf8,
#  'Vehicle Make': Utf8,
#  'Issuing Agency': Utf8,
#  'Street Code1': Int64,
#  'Street Code2': Int64,
#  'Street Code3': Int64,
#  'Vehicle Expiration Date': Int64,
#  'Violation Location': Int64,
#  'Violation Precinct': Int64,
#  'Issuer Precinct': Int64,
#  'Issuer Code': Int64,
#  'Issuer Command': Utf8,
#  'Issuer Squad': Int64,
#  'Violation Time': Utf8,
#  'Time First Observed': Utf8,
#  'Violation County': Utf8,
#  'Violation In Front Of Or Opposite': Utf8,
#  'House Number': Utf8,
#  'Street Name': Utf8,
#  'Intersecting Street': Utf8,
#  'Date First Observed': Int64,
#  'Law Section': Int64,
#  'Sub Division': Utf8,
#  'Violation Legal Code': Int64,
#  'Days Parking In Effect    ': Utf8,
#  'From Hours In Effect': Utf8,
#  'To Hours In Effect': Utf8,
#  'Vehicle Color': Utf8,
# ...

# %%
# Reading dataset
df.head()
# Out:
# shape: (5, 51)
# ┌────────────────┬──────────┬────────────────────┬────────────┬─────┬──────────────┬──────┬──────┬──────┐
# │ Summons Number ┆ Plate ID ┆ Registration State ┆ Plate Type ┆ ... ┆ Census Tract ┆ BIN  ┆ BBL  ┆ NTA  │
# │ ---            ┆ ---      ┆ ---                ┆ ---        ┆     ┆ ---          ┆ ---  ┆ ---  ┆ ---  │
# │ i64            ┆ str      ┆ str                ┆ str        ┆     ┆ str          ┆ str  ┆ str  ┆ str  │
# ╞════════════════╪══════════╪════════════════════╪════════════╪═════╪══════════════╪══════╪══════╪══════╡
# │ 1283294138     ┆ GBB9093  ┆ NY                 ┆ PAS        ┆ ... ┆ null         ┆ null ┆ null ┆ null │
# │ 1283294151     ┆ 62416MB  ┆ NY                 ┆ COM        ┆ ... ┆ null         ┆ null ┆ null ┆ null │
# │ 1283294163     ┆ 78755JZ  ┆ NY                 ┆ COM        ┆ ... ┆ null         ┆ null ┆ null ┆ null │
# │ 1283294175     ┆ 63009MA  ┆ NY                 ┆ COM        ┆ ... ┆ null         ┆ null ┆ null ┆ null │
# ...

# %%
df.tail() # Get the last n rows
# Out:
# shape: (5, 51)
# ┌────────────────┬──────────┬────────────────────┬────────────┬─────┬──────────────┬──────┬──────┬──────┐
# │ Summons Number ┆ Plate ID ┆ Registration State ┆ Plate Type ┆ ... ┆ Census Tract ┆ BIN  ┆ BBL  ┆ NTA  │
# │ ---            ┆ ---      ┆ ---                ┆ ---        ┆     ┆ ---          ┆ ---  ┆ ---  ┆ ---  │
# │ i64            ┆ str      ┆ str                ┆ str        ┆     ┆ str          ┆ str  ┆ str  ┆ str  │
# ╞════════════════╪══════════╪════════════════════╪════════════╪═════╪══════════════╪══════╪══════╪══════╡
# │ 8006150199     ┆ 16088MC  ┆ NY                 ┆ COM        ┆ ... ┆ null         ┆ null ┆ null ┆ null │
# │ 8006150217     ┆ 94008JW  ┆ NY                 ┆ COM        ┆ ... ┆ null         ┆ null ┆ null ┆ null │
# │ 8006150242     ┆ FWG3729  ┆ NY                 ┆ PAS        ┆ ... ┆ null         ┆ null ┆ null ┆ null │
# │ 8006150254     ┆ 193YUR   ┆ CT                 ┆ PAS        ┆ ... ┆ null         ┆ null ┆ null ┆ null │
# ...

# %%
type(df)
# Out:
# polars.internals.dataframe.frame.DataFrame

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 df.info()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\polars\utils.py:524, in redirect.<locals>._redirecting_getattr_(obj, item)
#     517     warnings.warn(
#     518         f"`{type(obj).__name__}.{item}` has been renamed; this"
#     519         f" redirect is temporary, please use `.{new_item}` instead",
#     520         category=DeprecationWarning,
#     521         stacklevel=2,
#     522     )
#     523     item = new_item
# --> 524 return obj.__getattribute__(item)
#
# AttributeError: 'DataFrame' object has no attribute 'info'

# %%
result_df.filter(pl.col('Registration State')=='NY')
# Out:
# shape: (7029787, 51)
# ┌────────────────┬──────────┬────────────────────┬────────────┬─────┬──────────────┬──────┬──────┬──────┐
# │ Summons Number ┆ Plate ID ┆ Registration State ┆ Plate Type ┆ ... ┆ Census Tract ┆ BIN  ┆ BBL  ┆ NTA  │
# │ ---            ┆ ---      ┆ ---                ┆ ---        ┆     ┆ ---          ┆ ---  ┆ ---  ┆ ---  │
# │ i64            ┆ str      ┆ str                ┆ str        ┆     ┆ str          ┆ str  ┆ str  ┆ str  │
# ╞════════════════╪══════════╪════════════════════╪════════════╪═════╪══════════════╪══════╪══════╪══════╡
# │ 1283294138     ┆ GBB9093  ┆ NY                 ┆ PAS        ┆ ... ┆ null         ┆ null ┆ null ┆ null │
# │ 1283294151     ┆ 62416MB  ┆ NY                 ┆ COM        ┆ ... ┆ null         ┆ null ┆ null ┆ null │
# │ 1283294163     ┆ 78755JZ  ┆ NY                 ┆ COM        ┆ ... ┆ null         ┆ null ┆ null ┆ null │
# │ 1283294175     ┆ 63009MA  ┆ NY                 ┆ COM        ┆ ... ┆ null         ┆ null ┆ null ┆ null │
# ...

# %%
help(pl.scan_csv)
# Out:
# Help on function scan_csv in module polars.io:
#
# scan_csv(file: 'str | Path', *, has_header: 'bool' = True, sep: 'str' = ',', comment_char: 'str | None' = None, quote_char: 'str | None' = '"', skip_rows: 'int' = 0, dtypes: 'SchemaDict | None' = None, null_values: 'str | list[str] | dict[str, str] | None' = None, missing_utf8_is_empty_string: 'bool' = False, ignore_errors: 'bool' = False, cache: 'bool' = True, with_column_names: 'Callable[[list[str]], list[str]] | None' = None, infer_schema_length: 'int | None' = 100, n_rows: 'int | None' = None, encoding: 'CsvEncoding' = 'utf8', low_memory: 'bool' = False, rechunk: 'bool' = True, skip_rows_after_header: 'int' = 0, row_count_name: 'str | None' = None, row_count_offset: 'int' = 0, try_parse_dates: 'bool' = False, eol_char: 'str' = '\n') -> 'LazyFrame'
#     Lazily read from a CSV file or multiple files via glob patterns.
#
#     This allows the query optimizer to push down predicates and
# ...
