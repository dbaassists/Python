# %% [markdown]
# * Criado por: Gabriel Quintella
# * Data Criação: 01.01.2023
# * Data Última Modificação: 02.01.2023
# * Repositório: https://github.com/dbaassists/Python/tree/main/ProjetoPythonKB
#
# DESCRIÇÃO DO PROJETO
#
# Criar uma base de conhecimento (KB) com comandos básicos de Python usando a biblioteca Pandas para auxiliar no seu aprendizado da linguagem.
#
# * Dia 1 - 01.01.2023 - Lançamento do Projeto;
# *  Dia 2 - 02.01.2023 - Aprimoramento do Projeto com melhoria nos exemplos criados;
#
#     ** Nesse dia estaremos abordando técnicas de importação de arquivos do tipo CSV e Excel

# %% [markdown]
# Sumário
#
# * 01 - Bibliotecas Usadas
# * 02 - Configurações de Exibição de Tela
# * 03 - Métodos de Importação de Arquivos CSV
#
# * 3.1 - Importando Arquivo CSV de forma FULL
# * 3.2 - Importando Arquivo CSV Definindo Colunas
# * 3.3 - Importando Arquivo CSV Definindo e Nomeando as Colunas
# * 3.4 - Importando Arquivo CSV Definindo Colunas e Datatypes
#
# * 04 - Explorando a Estrutura de um DataFrame
# * 05 - Removendo Vírgula por Ponto para Colunas do Tipo Float
# * 06 - Selecionando TOP N registros de um DataFrame
# * 07 - Aplicando o Comando Distinct em uma Coluna do DataFrame (unique())
# * 08 - Ordenando um DataFrame (sort_values())
# * 09 - Agrupando um DataFrame (groupby())
# * 10 - Funções de Agrupamento (Count(), Sum(), Min(), Max() e Mean())
# * 11 - Convertendo Datatype de uma Coluna em um DataFrame
# * 12 - Renomeando Colunas em um DataFrame
# * 13 - Removendo Colunas em um DataFrame
# * 14 - Tratando Valores Nulos em Colunas de um DataFrame
# * 15 - Comando Contém Valor em uma Coluna de um DataFrame
# * 16 - Filtrando Valores em um ou Várias Colunas de um DataFrame
# * 17 - Comando Similar ao Left e Right do SQL Server
# * 18 - Comando Similar ao Replicate do SQL Server
# * 19 - Removendo Duplicidades em um DataFrame
# * 20 - Relacionando DataFrames
# * 21 - Comando Similar ao Case When do SQL Server
# * 22 - Importando Planilha do Excel

# %% [markdown]
# # 01 - Bibliotecas Usadas

# %%
import warnings
import pandas as pd
from pandas.core.common import SettingWithCopyWarning
import numpy as np
import json

# %% [markdown]
# # 02 - Configurações de Exibição de Tela

# %%
# CONFIGURANDO A EXIBIÇAO DE REGISTROS NA TELA #

pd.options.display.max_rows = 999
pd.options.display.max_columns=999
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# %% [markdown]
# # 03 - Métodos de Importação de Arquivos CSV

# %% [markdown]
# ## 3.1 - Importando Arquivo CSV de forma FULL

# %%
# IMPORTAÇAO SIMPLES DE ARQUIVO CSV #

arquivoCSV = '..\ProjetoPythonKB\Dados\consulta_cand_2022_BRASIL.csv'

dfCandidatos = pd.read_csv(arquivoCSV
                           , sep=';'
                           ,encoding='latin-1'
                           )

# %% [markdown]
# ## 3.2 - Importando Arquivo CSV Definindo Colunas

# %%
arquivoCSV = '..\ProjetoPythonKB\Dados\consulta_cand_2022_BRASIL.csv'

dfCandidatos = pd.read_csv(arquivoCSV
                            , sep=';'
                            ,encoding='latin-1'
                            , usecols=[2,4,5,7,8,10,14,15,18,27,28,48,50])

# %% [markdown]
# ## 3.3 - Importando Arquivo CSV Definindo e Nomeando as Colunas

# %%
arquivoCSV = '..\ProjetoPythonKB\Dados\consulta_cand_2022_BRASIL.csv'

dfCandidatos = pd.read_csv(arquivoCSV
                            , sep=';'
                            ,encoding='latin-1'
                            , usecols=[2,4,5,7,8,10,14,15,18,27,28,48,50]
                            ,names=['NumAnoEleicao'
                                    ,'NomTpoEleicao'
                                    ,'NumTurno'
                                    ,'DescEleicao'
                                    ,'DtEleicao'
                                    ,'SigUF'
                                    ,'DescCargo'
                                    ,'SeqCandidato'
                                    ,'NomCandidatoUrna'
                                    ,'NumPartido'
                                    ,'SigParido'
                                    ,'DescInstrucao'
                                    ,'DescEstadoCivil']
                            ,header=0)

# %% [markdown]
# ## 3.4 - Importando Arquivo CSV Definindo Colunas e Datatypes

# %%
arquivoCSV = '..\ProjetoPythonKB\Dados\consulta_cand_2022_BRASIL.csv'

dfCandidatos = pd.read_csv(arquivoCSV
                            , sep=';'
                            ,encoding='latin-1'
                            , usecols=[2,4,5,7,8,10,14,15,18,27,28,48,50]
                            ,names=['NumAnoEleicao'
                                    ,'NomTpoEleicao'
                                    ,'NumTurno'
                                    ,'DescEleicao'
                                    ,'DtEleicao'
                                    ,'SigUF'
                                    ,'DescCargo'
                                    ,'SeqCandidato'
                                    ,'NomCandidatoUrna'
                                    ,'NumPartido'
                                    ,'SigParido'
                                    ,'DescInstrucao'
                                    ,'DescEstadoCivil']
                            ,dtype={'NumAnoEleicao':'long'
                                    ,'NomTpoEleicao':'str'
                                    ,'NumTurno':'long'
                                    ,'DescEleicao':'str'
                                    ,'DtEleicao':'str'
                                    ,'SigUF':'str'
                                    ,'DescCargo':'str'
                                    ,'SeqCandidato':'str'
                                    ,'NomCandidatoUrna':'str'
                                    ,'NumPartido':'long'
                                    ,'SigParido':'str'
                                    ,'DescInstrucao':'str'
                                    ,'DescEstadoCivil':'str'}
                            ,parse_dates=[4]
                            ,header=0)

# %% [markdown]
# # 04 - Explorando a Estrutura de um DataFrame

# %%
dfCandidatos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29262 entries, 0 to 29261
# Data columns (total 71 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DT_GERACAO                     29262 non-null  object
#  1   HH_GERACAO                     29262 non-null  object
#  2   ANO_ELEICAO                    29262 non-null  int64
#  3   CD_TIPO_ELEICAO                29262 non-null  int64
#  4   NM_TIPO_ELEICAO                29262 non-null  object
#  5   NR_TURNO                       29262 non-null  int64
#  6   CD_ELEICAO                     29262 non-null  int64
#  7   DS_ELEICAO                     29262 non-null  object
#  8   DT_ELEICAO                     29262 non-null  object
#  9   TP_ABRANGENCIA                 29262 non-null  object
#  10  SG_UF                          29262 non-null  object
#  11  SG_UE                          29262 non-null  object
#  12  NM_UE                          29262 non-null  object
#  13  CD_CARGO                       29262 non-null  int64
#  14  DS_CARGO                       29262 non-null  object
#  15  SQ_CANDIDATO                   29262 non-null  int64
#  16  NR_CANDIDATO                   29262 non-null  int64
#  17  NM_CANDIDATO                   29262 non-null  object
#  18  NM_URNA_CANDIDATO              29262 non-null  object
#  19  NM_SOCIAL_CANDIDATO            29262 non-null  object
#  20  NR_CPF_CANDIDATO               29262 non-null  int64
#  21  NM_EMAIL                       29262 non-null  object
#  22  CD_SITUACAO_CANDIDATURA        29262 non-null  int64
#  23  DS_SITUACAO_CANDIDATURA        29262 non-null  object
#  24  CD_DETALHE_SITUACAO_CAND       29262 non-null  int64
#  25  DS_DETALHE_SITUACAO_CAND       29262 non-null  object
#  26  TP_AGREMIACAO                  29262 non-null  object
#  27  NR_PARTIDO                     29262 non-null  int64
#  28  SG_PARTIDO                     29262 non-null  object
#  29  NM_PARTIDO                     29262 non-null  object
#  30  NR_FEDERACAO                   29262 non-null  int64
#  31  NM_FEDERACAO                   29262 non-null  object
#  32  SG_FEDERACAO                   29262 non-null  object
#  33  DS_COMPOSICAO_FEDERACAO        29262 non-null  object
#  34  SQ_COLIGACAO                   29262 non-null  object
#  35  NM_COLIGACAO                   29262 non-null  object
#  36  DS_COMPOSICAO_COLIGACAO        29262 non-null  object
#  37  CD_NACIONALIDADE               29262 non-null  int64
#  38  DS_NACIONALIDADE               29262 non-null  object
#  39  SG_UF_NASCIMENTO               29262 non-null  object
#  40  CD_MUNICIPIO_NASCIMENTO        29262 non-null  int64
#  41  NM_MUNICIPIO_NASCIMENTO        29262 non-null  object
#  42  DT_NASCIMENTO                  29238 non-null  object
#  43  NR_IDADE_DATA_POSSE            29238 non-null  float64
#  44  NR_TITULO_ELEITORAL_CANDIDATO  29262 non-null  object
#  45  CD_GENERO                      29262 non-null  int64
#  46  DS_GENERO                      29262 non-null  object
#  47  CD_GRAU_INSTRUCAO              29262 non-null  int64
#  48  DS_GRAU_INSTRUCAO              29262 non-null  object
#  49  CD_ESTADO_CIVIL                29262 non-null  int64
#  50  DS_ESTADO_CIVIL                29262 non-null  object
#  51  CD_COR_RACA                    29262 non-null  int64
#  52  DS_COR_RACA                    29262 non-null  object
#  53  CD_OCUPACAO                    29262 non-null  int64
#  54  DS_OCUPACAO                    29262 non-null  object
#  55  VR_DESPESA_MAX_CAMPANHA        29262 non-null  float64
#  56  CD_SIT_TOT_TURNO               29262 non-null  int64
#  57  DS_SIT_TOT_TURNO               29262 non-null  object
#  58  ST_REELEICAO                   29262 non-null  object
#  59  ST_DECLARAR_BENS               29262 non-null  object
#  60  NR_PROTOCOLO_CANDIDATURA       29262 non-null  int64
#  61  NR_PROCESSO                    29262 non-null  object
#  62  CD_SITUACAO_CANDIDATO_PLEITO   29262 non-null  int64
#  63  DS_SITUACAO_CANDIDATO_PLEITO   29262 non-null  object
#  64  CD_SITUACAO_CANDIDATO_URNA     29262 non-null  int64
#  65  DS_SITUACAO_CANDIDATO_URNA     29262 non-null  object
#  66  ST_CANDIDATO_INSERIDO_URNA     29262 non-null  object
#  67  NM_TIPO_DESTINACAO_VOTOS       29262 non-null  object
#  68  CD_SITUACAO_CANDIDATO_TOT      29262 non-null  int64
#  69  DS_SITUACAO_CANDIDATO_TOT      29262 non-null  object
#  70  ST_PREST_CONTAS                29262 non-null  object
# dtypes: float64(2), int64(24), object(45)
# memory usage: 15.9+ MB

# %% [markdown]
# # 05 - Removendo Vírgula por Ponto para Colunas do Tipo Float

# %%
arquivoBemCandidato = '../ProjetoPythonKB/Dados/bem_candidato_2022_BRASIL.csv'

dfBemCandidato = pd.read_csv(arquivoBemCandidato
                            ,sep=';'
                            ,encoding='latin-1'
                            ,usecols=[16]
                            ,names=['VlrBem']
                            ,dtype={'VlrBem':'str'
                            }
                            ,header=0)

dfBemCandidato['VlrBem_c'] = dfBemCandidato['VlrBem'].apply(lambda x: str(x).replace(",",".")).astype('float64')

dfBemCandidato
# Out:
#           VlrBem   VlrBem_c
# 0       33500,00   33500.00
# 1       22632,00   22632.00
# 2       46010,70   46010.70
# 3      800000,00  800000.00
# 4       95000,00   95000.00
# ...          ...        ...
# 90199   15129,56   15129.56
# 90200  150000,00  150000.00
# 90201    1217,50    1217.50
# 90202    1705,85    1705.85
# 90203    1298,25    1298.25
#
# [90204 rows x 2 columns]

# %% [markdown]
# # 06 - Selecionando TOP N registros de um DataFrame

# %%
# SELECIONANDO TOP N REGISTROS DE UM DATAFRAME #

dfCandidatos.head(1)
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  06/10/2022   13:10:14         2022                2  ELEIÇÃO ORDINÁRIA
#
#    NR_TURNO  CD_ELEICAO                      DS_ELEICAO  DT_ELEICAO  \
# 0         1         546  Eleições Gerais Estaduais 2022  02/10/2022
#
#   TP_ABRANGENCIA  ... NR_PROCESSO CD_SITUACAO_CANDIDATO_PLEITO  \
# 0       ESTADUAL  ...    6,02E+18                            2
#
#   DS_SITUACAO_CANDIDATO_PLEITO  CD_SITUACAO_CANDIDATO_URNA  \
# 0                     DEFERIDO                           2
#
#   DS_SITUACAO_CANDIDATO_URNA  ST_CANDIDATO_INSERIDO_URNA  \
# 0                   DEFERIDO                         SIM
#
#    NM_TIPO_DESTINACAO_VOTOS CD_SITUACAO_CANDIDATO_TOT  \
# 0                    Válido                         2
#
#   DS_SITUACAO_CANDIDATO_TOT ST_PREST_CONTAS
# 0                  Deferido               S
#
# [1 rows x 71 columns]

# %% [markdown]
# # 07 - Aplicando o Comando Distinct em uma Coluna do DataFrame (unique())

# %%
dfCandidatos['DescCargo'].unique()
# Out:
# array(['DEPUTADO ESTADUAL', 'DEPUTADO FEDERAL', '2º SUPLENTE', 'SENADOR',
#        'VICE-GOVERNADOR', 'DEPUTADO DISTRITAL', '1º SUPLENTE',
#        'GOVERNADOR', 'PRESIDENTE', 'VICE-PRESIDENTE'], dtype=object)

# %% [markdown]
# # 08 - Ordenando um DataFrame (sort_values())

# %%
# ORDENANDO UM DATAFRAME #

dfCandidatos.sort_values(by='SigUF'
                         , inplace=True
                         , ascending=True)

# %% [markdown]
# # 09 - Agrupando um DataFrame (groupby())

# %%
# AGRUPANDO VALORES DENTRO DE UM DATAFRAME #

dfCandidatos_Agrd = dfCandidatos.groupby(['DescCargo']
                                         , as_index=False).agg(QtdCandidato=('SeqCandidato'
                                                                             ,'count'))

dfCandidatos_Agrd.sort_values(by='QtdCandidato'
                                 , inplace=True
                                 , ascending=False
                             )

dfCandidatos_Agrd
# Out:
#             DescCargo  QtdCandidato
# 3   DEPUTADO ESTADUAL         16737
# 4    DEPUTADO FEDERAL         10630
# 2  DEPUTADO DISTRITAL           610
# 1         2º SUPLENTE           276
# 0         1º SUPLENTE           274
# 7             SENADOR           243
# 8     VICE-GOVERNADOR           242
# 5          GOVERNADOR           224
# 6          PRESIDENTE            13
# 9     VICE-PRESIDENTE            13

# %% [markdown]
# # 10 - Funções de Agrupamento (Count(), Sum(), Min(), Max() e Mean())

# %%
arquivoBemCandidato = '../ProjetoPythonKB/Dados/bem_candidato_2022_BRASIL.csv'

dfBemCandidato = pd.read_csv(arquivoBemCandidato
                            ,sep=';'
                            ,encoding='latin-1'
                            )

dfBemCandidato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90204 entries, 0 to 90203
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DT_GERACAO             90204 non-null  object
#  1   HH_GERACAO             90204 non-null  object
#  2   ANO_ELEICAO            90204 non-null  int64
#  3   CD_TIPO_ELEICAO        90204 non-null  int64
#  4   NM_TIPO_ELEICAO        90204 non-null  object
#  5   CD_ELEICAO             90204 non-null  int64
#  6   DS_ELEICAO             90204 non-null  object
#  7   DT_ELEICAO             90204 non-null  object
#  8   SG_UF                  90204 non-null  object
#  9   SG_UE                  90204 non-null  object
#  10  NM_UE                  90204 non-null  object
#  11  SQ_CANDIDATO           90204 non-null  int64
#  12  NR_ORDEM_CANDIDATO     90204 non-null  int64
#  13  CD_TIPO_BEM_CANDIDATO  90204 non-null  int64
#  14  DS_TIPO_BEM_CANDIDATO  90204 non-null  object
#  15  DS_BEM_CANDIDATO       90204 non-null  object
#  16  VR_BEM_CANDIDATO       90204 non-null  object
#  17  DT_ULTIMA_ATUALIZACAO  90204 non-null  object
#  18  HH_ULTIMA_ATUALIZACAO  90204 non-null  object
# dtypes: int64(6), object(13)
# memory usage: 13.1+ MB

# %%
arquivoBemCandidato = '../ProjetoPythonKB/Dados/bem_candidato_2022_BRASIL.csv'

dfBemCandidato = pd.read_csv(arquivoBemCandidato
                            ,sep=';'
                            ,encoding='latin-1'
                            ,usecols=[8,11,14,16]
                            ,names=['SigUF','SeqCandidato','DescTpoBem','VlrBem']
                            ,dtype={'SigUF':'str'
                                ,'SeqCandidato':'str'
                                ,'DescTpoBem':'str'
                                ,'VlrBem':'str'
                            }
                            ,header=0)

dfBemCandidato['VlrBem'] = dfBemCandidato['VlrBem'].apply(lambda x: str(x).replace(",",".")).astype('float64')

dfBemCandidato_Agrd = dfBemCandidato.groupby(['DescTpoBem'],as_index=True).agg( \
                                                    QtdBem=('DescTpoBem','count')
                                                   ,VltTotalBem=('VlrBem','sum')
                                                   ,VltMenorBem=('VlrBem','min')
                                                   ,VltMaiorBem=('VlrBem','max')
                                                   ,VltMedioBem=('VlrBem','mean'))

dfBemCandidato_Agrd.style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_89c83">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89c83_level0_col0" class="col_heading level0 col0" >QtdBem</th>
#       <th id="T_89c83_level0_col1" class="col_heading level0 col1" >VltTotalBem</th>
#       <th id="T_89c83_level0_col2" class="col_heading level0 col2" >VltMenorBem</th>
#       <th id="T_89c83_level0_col3" class="col_heading level0 col3" >VltMaiorBem</th>
#       <th id="T_89c83_level0_col4" class="col_heading level0 col4" >VltMedioBem</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >DescTpoBem</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89c83_level0_row0" class="row_heading level0 row0" >Aeronave</th>
#       <td id="T_89c83_row0_col0" class="data row0 col0" >95.00</td>
#       <td id="T_89c83_row0_col1" class="data row0 col1" >100085320.57</td>
#       <td id="T_89c83_row0_col2" class="data row0 col2" >20000.00</td>
#       <td id="T_89c83_row0_col3" class="data row0 col3" >10000000.00</td>
#       <td id="T_89c83_row0_col4" class="data row0 col4" >1053529.69</td>
#     </tr>
#     <tr>
#       <th id="T_89c83_level0_row1" class="row_heading level0 row1" >Apartamento</th>
#       <td id="T_89c83_row1_col0" class="data row1 col0" >6711.00</td>
#       <td id="T_89c83_row1_col1" class="data row1 col1" >2297953328.81</td>
#       <td id="T_89c83_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_89c83_row1_col3" class="data row1 col3" >7879197.99</td>
#       <td id="T_89c83_row1_col4" class="data row1 col4" >342415.93</td>
#     </tr>
#     <tr>
#       <th id="T_89c83_level0_row2" class="row_heading level0 row2" >Aplicação de renda fixa (CDB, RDB e outros)</th>
#       <td id="T_89c83_row2_col0" class="data row2 col0" >4126.00</td>
#       <td id="T_89c83_row2_col1" class="data row2 col1" >707325198.77</td>
#       <td id="T_89c83_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_89c83_row2_col3" class="data row2 col3" >61792857.29</td>
#       <td id="T_89c83_row2_col4" class="data row2 col4" >171431.22</td>
#     </tr>
#     <tr>
#       <th id="T_89c83_level0_row3" class="row_heading level0 row3" >Ações (inclusive as provenientes de linha telefônica)</th>
#       <td id="T_89c83_row3_col0" class="data row3 col0" >2297.00</td>
#       <td id="T_89c83_row3_col1" class="data row3 col1" >1011767357.79</td>
#       <td id="T_89c83_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_89c83_row3_col3" class="data row3 col3" >299503939.00</td>
#       <td id="T_89c83_row3_col4" class="data row3 col4" >440473.38</td>
#     </tr>
#     <tr>
#       <th id="T_89c83_level0_row4" class="row_heading level0 row4" >Bem relacionado com o exercício da atividade autônoma</th>
#       <td id="T_89c83_row4_col0" class="data row4 col0" >111.00</td>
#       <td id="T_89c83_row4_col1" class="data row4 col1" >12100496.58</td>
#       <td id="T_89c83_row4_col2" class="data row4 col2" >0.00</td>
#       <td id="T_89c83_row4_col3" class="data row4 col3" >1830500.00</td>
#       <td id="T_89c83_row4_col4" class="data row4 col4" >109013.48</td>
#     </tr>
#     <tr>
#       <th id="T_89c83_level0_row5" class="row_heading level0 row5" >Benfeitorias</th>
#       <td id="T_89c83_row5_col0" class="data row5 col0" >160.00</td>
#       <td id="T_89c83_row5_col1" class="data row5 col1" >42981548.23</td>
#       <td id="T_89c83_row5_col2" class="data row5 col2" >61.81</td>
#       <td id="T_89c83_row5_col3" class="data row5 col3" >2680325.00</td>
#       <td id="T_89c83_row5_col4" class="data row5 col4" >268634.68</td>
#     </tr>
#     <tr>
#       <th id="T_89c83_level0_row6" class="row_heading level0 row6" >Caderneta de poupança</th>
#       <td id="T_89c83_row6_col0" class="data row6 col0" >3166.00</td>
#       <td id="T_89c83_row6_col1" class="data row6 col1" >89716190.39</td>
#       <td id="T_89c83_row6_col2" class="data row6 col2" >0.00</td>
#       <td id="T_89c83_row6_col3" class="data row6 col3" >5832110.00</td>
#       <td id="T_89c83_row6_col4" class="data row6 col4" >28337.39</td>
#     </tr>
#     <tr>
#       <th id="T_89c83_level0_row7" class="row_heading level0 row7" >Casa</th>
#       <td id="T_89c83_row7_col0" class="data row7 col0" >8644.00</td>
#       <td id="T_89c83_row7_col1" class="data row7 col1" >2785069153.07</td>
#       <td id="T_89c83_row7_col2" class="data row7 col2" >0.00</td>
#       <td id="T_89c83_row7_col3" class="data row7 col3" >24163378.10</td>
#       <td id="T_89c83_row7_col4" class="data row7 col4" >322196.80</td>
#     </tr>
#     <tr>
#       <th id="T_89c83_level0_row8" class="row_heading level0 row8" >Construção</th>
#       <td id="T_89c83_row8_col0" class="data row8 col0" >203.00</td>
#       <td id="T_89c83_row8_col1" class="data row8 col1" >71980386.60</td>
#       <td id="T_89c83_row8_col2" class="data row8 col2" >110.00</td>
#       <td id="T_89c83_row8_col3" class="data row8 col3" >6099245.28</td>
#       <td id="T_89c83_row8_col4" class="data row8 col4" >354583.19</td>
#     </tr>
#     <tr>
#       <th id="T_89c83_level0_row9" class="row_heading level0 row9" >Consórcio não contemplado</th>
#       <td id="T_89c83_row9_col0" class="data row9 col0" >759.00</td>
#       <td id="T_89c83_row9_col1" class="data row9 col1" >48237244.46</td>
#       <td id="T_89c83_row9_col2" class="data row9 col2" >342.60</td>
#       <td id="T_89c83_row9_col3" class="data row9 col3" >1250000.00</td>
#       <td id="T_89c83_row9_col4" class="data row9 col4" >63553.68</td>
#     </tr>
#     <tr>
#       <th id="T_89c83_level0_row10" class="row_heading level0 row10" >Crédito decorrente de alienação</th>
#       <td id="T_89c83_row10_col0" class="data row10 col0" >71.00</td>
#       <td id="T_89c83_row10_col1" class="data row10 col1" >41002723.48</td>
#       <td id="T_89c83_row10_col2" class="data row10 col2" >7027.50</td>
#       <td id="T_89c83_row10_col3" class="data row10 col3" >7464750.00</td>
#       <td id="T_89c83_row10_col4" class="data row10 col4" >577503.15</td>
#     </tr>
#     <tr>
#       <th id="T_89c83_level0_row11" class="row_heading level0 row11" >Crédito decorrente de empréstimo</th>
#       <td id="T_89c83_row11_col0" class="data row11 col0" >595.00</td>
#       <td id="T_89c83_row11_col1" class="data row11 col1" >754961580.47</td>
#       <td id="T_89c83_row11_col2" class="data row11 col2" >0.00</td>
#       <td id="T_89c83_row11_col3" class="data row11 col3" >178000000.00</td>
#       <td id="T_89c83_row11_col4" class="data row11 col4" >1268842.99</td>
#     </tr>
#     <tr>
#       <th id="T_89c83_level0_row12" class="row_heading level0 row12" >Depósito bancário em conta corrente no País</th>
#       <td id="T_89c83_row12_col0" class="data row12 col0" >8295.00</td>
#       <td id="T_89c83_row12_col1" class="data row12 col1" >286795988.49</td>
#       <td id="T_89c83_row12_col2" class="data row12 col2" >0.00</td>
#       <td id="T_89c83_row12_col3" class="data row12 col3" >7731567.87</td>
#       <td id="T_89c83_row12_col4" class="data row12 col4" >34574.56</td>
#     </tr>
#     <tr>
#       <th id="T_89c83_level0_row13" class="row_heading level0 row13" >Depósito bancário em conta corrente no exterior</th>
#       <td id="T_89c83_row13_col0" class="data row13 col0" >109.00</td>
#       <td id="T_89c83_row13_col1" class="data row13 col1" >26685174.49</td>
#       <td id="T_89c83_row13_col2" class="data row13 col2" >0.00</td>
#       <td id="T_89c83_row13_col3" class="data row13 col3" >6190707.60</td>
#       <td id="T_89c83_row13_col4" class="data row13 col4" >244818.11</td>
#     </tr>
#     <tr>
#       <th id="T_89c83_level0_row14" class="row_heading level0 row14" >Dinheiro em espécie - moeda estrangeira</th>
#       <td id="T_89c83_row14_col0" class="data row14 col0" >149.00</td>
#       <td id="T_89c83_row14_col1" class="data row14 col1" >48580995.35</td>
#       <td id="T_89c83_row14_col2" class="data row14 col2" >0.00</td>
#       <td id="T_89c83_row14_col3" class="data row14 col3" >395643

# %% [markdown]
# # 11 - Convertendo Datatype de uma Coluna em um DataFrame

# %%
AnoMes=['Jan22', 'Fev22', 'Mar22', 'Abr22','Mai22','Jun22','Jul22','Ago22','Set22','Out22','Nov22','Dez22']
Pedidos=['10','20','10','15','10','12','15','11','22','23','9','42']
Valor=['2314,09','22311,90','2421.78','4311.89','123143,49','12331.43','4321,44','54322,56','23421.5','43156,99','123599.65','9943543,99']


df=pd.DataFrame({"AnoMes":AnoMes,
                "QtdPedidos":Pedidos,
                "Vlr":Valor})

df['QtdPedidos_c'] = df['QtdPedidos'].astype(int)

df['Vlr_c'] = df['Vlr'].apply(lambda x: str(x).replace(",",".")).astype('float64')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AnoMes        12 non-null     object
#  1   QtdPedidos    12 non-null     object
#  2   Vlr           12 non-null     object
#  3   QtdPedidos_c  12 non-null     int32
#  4   Vlr_c         12 non-null     float64
# dtypes: float64(1), int32(1), object(3)
# memory usage: 560.0+ bytes

# %% [markdown]
# # 12 - Renomeando Colunas em um DataFrame

# %%
df.rename(columns = {'Vlr_c':'Vlr_T'
                        , 'QtdPedidos_c':'QtdPedidos_T'}
                        , inplace = True)

df.head(1)
# Out:
#   AnoMes QtdPedidos      Vlr  QtdPedidos_T    Vlr_T
# 0  Jan22         10  2314,09            10  2314.09

# %% [markdown]
# # 13 - Removendo Colunas em um DataFrame

# %%
df.drop('AnoMes', axis=1, inplace=True)

df.head(1)
# Out:
#   QtdPedidos      Vlr  QtdPedidos_T    Vlr_T
# 0         10  2314,09            10  2314.09

# %%
df = df.drop(df.columns[0], axis=1) 

df.head(1)
# Out:
#    QtdPedidos_T    Vlr_T
# 0            10  2314.09

# %%
df.drop(['QtdPedidos', 'Vlr'], axis=1, inplace=True)

df.head(1)
# Out:
#   AnoMes  QtdPedidos_T    Vlr_T
# 0  Jan22            10  2314.09

# %% [markdown]
# # 14 - Tratando Valores Nulos em Colunas de um DataFrame

# %%
arquivoCSV = '..\ProjetoPythonKB\Dados\consulta_cand_2022_BRASIL.csv'

dfCandidatos = pd.read_csv(arquivoCSV
                            , sep=';'
                            ,encoding='latin-1'
                            , usecols=[2,4,5,7,8,10,14,15,18,27,28,43,48,50]
                            ,names=['NumAnoEleicao'
                                    ,'NomTpoEleicao'
                                    ,'NumTurno'
                                    ,'DescEleicao'
                                    ,'DtEleicao'
                                    ,'SigUF'
                                    ,'DescCargo'
                                    ,'SeqCandidato'
                                    ,'NomCandidatoUrna'
                                    ,'NumPartido'
                                    ,'SigParido'
                                    ,'NumIdadePosse'
                                    ,'DescInstrucao'
                                    ,'DescEstadoCivil']
                            ,dtype={'NumAnoEleicao':'long'
                                    ,'NomTpoEleicao':'str'
                                    ,'NumTurno':'long'
                                    ,'DescEleicao':'str'
                                    ,'DtEleicao':'str'
                                    ,'SigUF':'str'
                                    ,'DescCargo':'str'
                                    ,'SeqCandidato':'str'
                                    ,'NomCandidatoUrna':'str'
                                    ,'NumPartido':'long'
                                    ,'SigParido':'str'
                                    ,'NumIdadePosse':'str'
                                    ,'DescInstrucao':'str'
                                    ,'DescEstadoCivil':'str'}
                            ,parse_dates=[4]
                            ,header=0)

dfCandidatos['NumIdadePosse'].fillna('0',inplace=True)

dfCandidatos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29262 entries, 0 to 29261
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   NumAnoEleicao     29262 non-null  int32
#  1   NomTpoEleicao     29262 non-null  object
#  2   NumTurno          29262 non-null  int32
#  3   DescEleicao       29262 non-null  object
#  4   DtEleicao         29262 non-null  datetime64[ns]
#  5   SigUF             29262 non-null  object
#  6   DescCargo         29262 non-null  object
#  7   SeqCandidato      29262 non-null  object
#  8   NomCandidatoUrna  29262 non-null  object
#  9   NumPartido        29262 non-null  int32
#  10  SigParido         29262 non-null  object
#  11  NumIdadePosse     29262 non-null  object
#  12  DescInstrucao     29262 non-null  object
#  13  DescEstadoCivil   29262 non-null  object
# dtypes: datetime64[ns](1), int32(3), object(10)
# memory usage: 2.8+ MB

# %% [markdown]
# # 15 - Comando Contém Valor em uma Coluna de um DataFrame

# %% [markdown]
# # 16 - Filtrando Valores em um ou Várias Colunas de um DataFrame

# %% [markdown]
# # 17 - Comando Similar ao Left e Right do SQL Server

# %%
# COMANDO LEFT E RIGHT DO SQL SERVER #


AnoMes=['Jan2022', 'Fev2022', 'Mar2022', 'Abr2022','Mai2022','Jun2022','Jul2022','Ago2022','Set2022','Out2022','Nov2022','Dez2022']
Pedidos=['10','20','10','15','10','12','15','11','22','23','9','42']
Valor=['2314,09','22311,90','2421.78','4311.89','123143,49','12331.43','4321,44','54322,56','23421.5','43156,99','123599.65','9943543,99']


df=pd.DataFrame({"AnoMes":AnoMes,
                "QtdPedidos":Pedidos,
                "Vlr":Valor})

df['QtdPedidos_c'] = df['QtdPedidos'].astype(int)

df['Vlr_c'] = df['Vlr'].apply(lambda x: str(x).replace(",",".")).astype('float64')

df['Ano'] = df['AnoMes'].str[3:]

df['Mes'] = df['AnoMes'].str[:3]

df
# Out:
#      AnoMes Loja QtdPedidos         Vlr  QtdPedidos_c       Vlr_c   Ano  Mes
# 0   Jan2022   AB         10     2314,09            10     2314.09  2022  Jan
# 1   Fev2022   BC         20    22311,90            20    22311.90  2022  Fev
# 2   Mar2022   CD         10     2421.78            10     2421.78  2022  Mar
# 3   Abr2022   DE         15     4311.89            15     4311.89  2022  Abr
# 4   Mai2022   EF         10   123143,49            10   123143.49  2022  Mai
# 5   Jun2022   FG         12    12331.43            12    12331.43  2022  Jun
# 6   Jul2022   GH         15     4321,44            15     4321.44  2022  Jul
# 7   Ago2022   HI         11    54322,56            11    54322.56  2022  Ago
# 8   Set2022   IJ         22     23421.5            22    23421.50  2022  Set
# 9   Out2022   JK         23    43156,99            23    43156.99  2022  Out
# 10  Nov2022   KL          9   123599.65             9   123599.65  2022  Nov
# 11  Dez2022   LM         42  9943543,99            42  9943543.99  2022  Dez

# %% [markdown]
# # 18 - Comando Similar ao Replicate do SQL Server

# %%
# COMPLETANDO COM ZERO A ESQUERDA #




AnoMes=['Jan2022', 'Fev2022', 'Mar2022', 'Abr2022','Mai2022','Jun2022','Jul2022','Ago2022','Set2022','Out2022','Nov2022','Dez2022']
Loja=['ABCDE','BCDE','CD','DEFGH','EFG','FGIJK','GHIJ','HI','IJ','JKL','KL','LMNOPQ']
Pedidos=['10','20','10','15','10','12','15','11','22','23','9','42']
Valor=['2314,09','22311,90','2421.78','4311.89','123143,49','12331.43','4321,44','54322,56','23421.5','43156,99','123599.65','9943543,99']


df=pd.DataFrame({"AnoMes":AnoMes,
                 "Loja":Loja,
                "QtdPedidos":Pedidos,
                "Vlr":Valor})

df['QtdPedidos_c'] = df['QtdPedidos'].astype(int)

df['Vlr_c'] = df['Vlr'].apply(lambda x: str(x).replace(",",".")).astype('float64')

df['Ano'] = df['AnoMes'].str[3:]

df['Mes'] = df['AnoMes'].str[:3]

df['Loja'] = pd.Series(df['Loja']).astype(str).str.zfill(10) 

df
# Out:
#      AnoMes        Loja QtdPedidos         Vlr  QtdPedidos_c       Vlr_c  \
# 0   Jan2022  00000ABCDE         10     2314,09            10     2314.09
# 1   Fev2022  000000BCDE         20    22311,90            20    22311.90
# 2   Mar2022  00000000CD         10     2421.78            10     2421.78
# 3   Abr2022  00000DEFGH         15     4311.89            15     4311.89
# 4   Mai2022  0000000EFG         10   123143,49            10   123143.49
# 5   Jun2022  00000FGIJK         12    12331.43            12    12331.43
# 6   Jul2022  000000GHIJ         15     4321,44            15     4321.44
# 7   Ago2022  00000000HI         11    54322,56            11    54322.56
# 8   Set2022  00000000IJ         22     23421.5            22    23421.50
# 9   Out2022  0000000JKL         23    43156,99            23    43156.99
# 10  Nov2022  00000000KL          9   123599.65             9   123599.65
# 11  Dez2022  0000LMNOPQ         42  9943543,99            42  9943543.99
#
#      Ano  Mes
# 0   2022  Jan
# 1   2022  Fev
# 2   2022  Mar
# 3   2022  Abr
# 4   2022  Mai
# 5   2022  Jun
# 6   2022  Jul
# 7   2022  Ago
# 8   2022  Set
# 9   2022  Out
# 10  2022  Nov
# 11  2022  Dez

# %% [markdown]
# # 19 - Removendo Duplicidades em um DataFrame

# %%
# REMOVENDO DUPLICIDADES DE UM DATAFRAME #

arquivo_Alex_NE = 'C:\\Temp\\Frete_Rodrigo\\INDICADORES_FRETE_2021_COMPLETO_zerados.xlsx'

dfANE = pd.read_excel(arquivo_Alex_NE
                      , sheet_name='Não encontrados'
                      , usecols=[0]
                      , names=['CodDocVenda']
                      , dtype={'CodDocVenda':'str'})

dfANE = dfANE.drop_duplicates(
  subset = ['CodDocVenda'],
  keep = 'last').reset_index(drop = True)

dfANE.info()

# %% [markdown]
# # 20 - Relacionando DataFrames

# %%
# RELACIONANDO DOIS DATAFRAMES #

resultCandidatoBem = pd.merge(left=dfCandidatos
                              , right=dfBemCandidato
                              , left_on='SeqCandidato'
                              , right_on='SeqCandidato'                                                                                              
                                    )[['SeqCandidato'
                                       , 'NomCandidatoUrna'
                                       , 'DescCargo'
                                       , 'SigUF_y'
                                       , 'DescTpoBem'
                                       , 'VlrBem']]

resultCandidatoBem
# Out:
#       SeqCandidato             NomCandidatoUrna          DescCargo SigUF_y  \
# 0      90001675157             CYNTHIA OLIVEIRA   DEPUTADO FEDERAL      GO
# 1      40001671799            CIMARA CAVALCANTE   DEPUTADO FEDERAL      AM
# 2      90001652975  MAURICIO COMUNICATIVO LESTE  DEPUTADO ESTADUAL      GO
# 3      80001648791       PROFESSOR GEDAYAS DAYA  DEPUTADO ESTADUAL      ES
# 4      60001619178                   JOÃO JAIME  DEPUTADO ESTADUAL      CE
# ...            ...                          ...                ...     ...
# 20347  80001719429               HELDER SALOMÃO   DEPUTADO FEDERAL      ES
# 20348  80001719429               HELDER SALOMÃO   DEPUTADO FEDERAL      ES
# 20349  80001719429               HELDER SALOMÃO   DEPUTADO FEDERAL      ES
# 20350  80001719429               HELDER SALOMÃO   DEPUTADO FEDERAL      ES
# 20351  80001719429               HELDER SALOMÃO   DEPUTADO FEDERAL      ES
#
#                                               DescTpoBem     VlrBem
# 0      Veículo automotor terrestre: caminhão, automóv...    1000.00
# 1                   Dinheiro em espécie - moeda nacional    3000.00
# 2      Veículo automotor terrestre: caminhão, automóv...   15000.00
# 3                                                   Casa   78000.00
# 4      Fundos: Ações, Mútuos de Privatização, Invest....    9140.29
# ...                                                  ...        ...
# 20347  Veículo automotor terrestre: caminhão, automóv...   50364.48
# 20348             VGBL - Vida Gerador de Benefício Livre    7171.68
# 20349                                   Sala ou conjunto  138547.87
# 20350                                        Apartamento   26000.00
# 20351        Depósito bancário em conta corrente no País    1812.63
#
# [20352 rows x 6 columns]

# %% [markdown]
# # 21 - Comando Similar ao Case When do SQL Server

# %%
# APLICANDO O COMANDO CASE DO SQL SERVER #

resultAmostra.loc[resultAmostra['AnoMes'] >= '202201', 'Comparacao'] = 'REGISTRO NOVO'
resultAmostra.loc[resultAmostra['AnoMes'] < '202201', 'Comparacao'] = 'REGISTRO VELHO'

resultAmostra.groupby('Comparacao').agg(Qtd=('Comparacao','count'))
# Out:
#                   Qtd
# Comparacao
# REGISTRO NOVO      99
# REGISTRO VELHO  60501

# %% [markdown]
# # 22 - Importando Planilha do Excel

# %%
# IMPORTAÇÃO SIMPLES DE PLANILHA EXCEL #

arquivo_Alex_NE = 'C:\\Temp\\Frete_Rodrigo\\INDICADORES_FRETE_2021_COMPLETO_zerados.xlsx'

dfANE = pd.read_excel(arquivo_Alex_NE
                      , sheet_name='Não encontrados'
                      , usecols=[0]
                      , names=['CodDocVenda']
                      , dtype={'CodDocVenda':'str'})
