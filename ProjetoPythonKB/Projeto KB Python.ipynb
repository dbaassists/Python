# %% [markdown]
# * Criado por: Gabriel Quintella
# * Data Criação: 01.01.2023
# * Data Última Modificação: 07.01.2023
# * Repositório: https://github.com/dbaassists/Python/tree/main/ProjetoPythonKB
#
# DESCRIÇÃO DO PROJETO
#
# Criar uma base de conhecimento (KB) com comandos básicos de Python usando a biblioteca Pandas para auxiliar no seu aprendizado da linguagem.
#
# *  Dia 1 - 01.01.2023 - Lançamento do Projeto;
# *  Dia 2 - 02.01.2023 - Aprimoramento do Projeto com melhoria nos exemplos criados;
# *  Dia 3 - 03.01.2023 - Melhoria nos exemplos do notebook;
# *  Dia 4 - 04.01.2023 - Melhoria nos exemplos do notebook e inclusão de novos comandos;
# *  Dia 5 - 05.01.2023 - Melhoria nos exemplos do notebook e inclusão de novos comandos;
# *  Dia 6 - 06.01.2023 - Inclusão de novos comandos e documentação de cada etapa;
# *  Dia 7 - 07.01.2023 - Inclusão de novos comandos fazendo consultas em bancos de dados e Salesforce;
#
#     ** Nesse dia estaremos abordando técnicas de importação de arquivos do tipo CSV e Excel

# %% [markdown]
# Sumário
#
# * 01 - Bibliotecas Usadas
# * 02 - Configurações de Exibição de Tela
# * 03 - Métodos de Importação de Arquivos CSV
# * 03.1 - Importando Arquivo CSV de forma FULL
# * 03.2 - Importando Arquivo CSV Definindo Colunas
# * 03.3 - Importando Arquivo CSV Definindo e Nomeando as Colunas
# * 03.4 - Importando Arquivo CSV Definindo Colunas e Datatypes
# * 03.5 - Criar uma Função padrão para Importar um Arquivo CSV
# * 04 - Explorando a Estrutura de um DataFrame
# * 05 - Removendo Vírgula por Ponto para Colunas do Tipo Float
# * 06 - Selecionando TOP N registros de um DataFrame
# * 07 - Aplicando o Comando Distinct em uma Coluna do DataFrame (unique())
# * 08 - Ordenando um DataFrame (sort_values())
# * 09 - Agrupando um DataFrame (groupby())
# * 10 - Funções de Agrupamento (Count(), Sum(), Min(), Max() e Mean())
# * 11 - Convertendo Datatype de uma Coluna em um DataFrame
# * 12 - Renomeando Colunas em um DataFrame
# * 13 - Removendo Colunas em um DataFrame
# * 14 - Tratando Valores Nulos em Colunas de um DataFrame
# * 15 - Comando Contém (isin) Valor em uma Coluna de um DataFrame
# * 16 - Filtrando Valores em um ou Várias Colunas de um DataFrame
# * 17 - Comando Similar ao Left e Right do SQL Server
# * 18 - Comando Similar ao Replicate (zfill()) do SQL Server
# * 19 - Removendo Duplicidades em um DataFrame
# * 20 - Relacionando DataFrames
# * 21 - Comando Similar ao Case When do SQL Server
# * 22 - Importando Grandes Arquivos (chunksize)
# * 23 - Importandos Vários Arquivos (For e Biblioteca OS)
# * 24 - Compactar (Zipar) um arquivo
# * 25 - Descompactar (Zipar) um arquivo
# * 26 - Métodos de Importação Planilha do Excel
# * 26.1 - Importando Planilha do Excel de forma FULL
# * 26.2 - Importando Planilha do Excel Definindo Colunas e Datatypes
# * 26.3 - Criar uma Função padrão para Importar uma Planilha no Excel
# * 27 - Criar e Excluir Diretório
# * 28 - Listar o Último Arquivo em um Diretório
# * 29 - Conectar e Extrair Dados do Microsof SQL Server
# * 30 - Conectar e Extrair Dados do Oracle
# * 31 - Conectar e Extrair Dados do PostGre
# * 32 - Conectar e Extrair Dados do MySQL
# * 33 - Conectar e Extrair Dados do Salesforce
# * 34 - Comando Similar ao LIKE do SQL Server
# * 35 - Comando Similar ao SUBSTRING do SQL Server
# * 36 - Gerando Arquivo CSV a partir de um DataFrame
# * 37 - Download de Arquivo de uma URL
# * 38 - Colocando a primeira letra como Maiuscula
# * 39 - Verificando de a variável é Alfanuméria
# * 40 - Verificando de a variável é Numerica
# * 41 - Verificando de a variável está toda em caixa alta (Maiuscula)
# * 42 - Removendo espaços

# %% [markdown]
# # 01 - Bibliotecas Usadas

# %%
import warnings
import pandas as pd
from pandas.core.common import SettingWithCopyWarning
import numpy as np
import json

# %% [markdown]
# # 02 - Configurações de Exibição de Tela

# %%
# CONFIGURANDO A EXIBIÇAO DE REGISTROS NA TELA #

pd.options.display.max_rows = 999
pd.options.display.max_columns=999
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# %% [markdown]
# # 03 - Métodos de Importação de Arquivos CSV

# %% [markdown]
# ## 03.1 - Importando Arquivo CSV de forma FULL
#
# * Detalhe: Importação de um arquivo CSV em sua totalidade usando o método read_csv(), definindo apenas os parâmtros:
# ** sep=';' - delimitador de coluna
# ** encoding='latin-1' - códigicação dos dados

# %%
# IMPORTAÇAO SIMPLES DE ARQUIVO CSV #



arquivoCSV = '..\ProjetoPythonKB\Dados\Candidato\consulta_cand_2022_BRASIL.csv'

dfCandidatos = pd.read_csv(arquivoCSV
                           , sep=';'
                           ,encoding='latin-1'
                           )

# %% [markdown]
# ## 03.2 - Importando Arquivo CSV Definindo Colunas
#
# * Detalhe: Importação de um arquivo CSV em sua totalidade usando o método read_csv(), definindo apenas os parâmtros:
# ** sep=';' - delimitador de coluna
# ** encoding='latin-1' - códigicação dos dados
# ** usecols=[] - para definir as colunas

# %%
arquivoCSV = '..\ProjetoPythonKB\Dados\Candidato\consulta_cand_2022_BRASIL.csv'

dfCandidatos = pd.read_csv(arquivoCSV
                            , sep=';'
                            , encoding='latin-1'
                            , usecols=[2,4,5,7,8,10,14,15,18,27,28,48,50])

# %% [markdown]
# ## 03.3 - Importando Arquivo CSV Definindo e Nomeando as Colunas
# * Detalhe: Importação de um arquivo CSV em sua totalidade usando o método read_csv(), definindo apenas os parâmtros:
# ** sep=';' - delimitador de coluna
# ** encoding='latin-1' - códigicação dos dados
# ** usecols=[] - para definir as colunas
# ** names=[] - para definir o novo nome das colunas
# ** header=0 - para definir que a primeira linha do arquivo é a de dados

# %%
arquivoCSV = '..\ProjetoPythonKB\Dados\Candidato\consulta_cand_2022_BRASIL.csv'

dfCandidatos = pd.read_csv(arquivoCSV
                            , sep=';'
                            ,encoding='latin-1'
                            , usecols=[2,4,5,7,8,10,14,15,18,27,28,48,50]
                            ,names=['NumAnoEleicao'
                                    ,'NomTpoEleicao'
                                    ,'NumTurno'
                                    ,'DescEleicao'
                                    ,'DtEleicao'
                                    ,'SigUF'
                                    ,'DescCargo'
                                    ,'SeqCandidato'
                                    ,'NomCandidatoUrna'
                                    ,'NumPartido'
                                    ,'SigParido'
                                    ,'DescInstrucao'
                                    ,'DescEstadoCivil']
                            ,header=0)

# %% [markdown]
# ## 03.4 - Importando Arquivo CSV Definindo Colunas e Datatypes
# * Detalhe: Importação de um arquivo CSV em sua totalidade usando o método read_csv(), definindo apenas os parâmtros:
# ** sep=';' - delimitador de coluna
# ** encoding='latin-1' - códigicação dos dados
# ** usecols=[] - para definir as colunas
# ** names=[] - para definir o novo nome das colunas
# ** header=0 - para definir que a primeira linha do arquivo é a de dados
# ** dtype={} - para definir o datatype de cada coluna
# ** parse_date=[] - define que a coluna deverá ser convertida para o tipo datetime

# %%
arquivoCSV = '..\ProjetoPythonKB\Dados\Candidato\consulta_cand_2022_BRASIL.csv'

dfCandidatos = pd.read_csv(arquivoCSV
                            , sep=';'
                            ,encoding='latin-1'
                            , usecols=[2,4,5,7,8,10,14,15,18,27,28,48,50]
                            ,names=['NumAnoEleicao'
                                    ,'NomTpoEleicao'
                                    ,'NumTurno'
                                    ,'DescEleicao'
                                    ,'DtEleicao'
                                    ,'SigUF'
                                    ,'DescCargo'
                                    ,'SeqCandidato'
                                    ,'NomCandidatoUrna'
                                    ,'NumPartido'
                                    ,'SigParido'
                                    ,'DescInstrucao'
                                    ,'DescEstadoCivil']
                            ,dtype={'NumAnoEleicao':'long'
                                    ,'NomTpoEleicao':'str'
                                    ,'NumTurno':'long'
                                    ,'DescEleicao':'str'
                                    ,'DtEleicao':'str'
                                    ,'SigUF':'str'
                                    ,'DescCargo':'str'
                                    ,'SeqCandidato':'str'
                                    ,'NomCandidatoUrna':'str'
                                    ,'NumPartido':'long'
                                    ,'SigParido':'str'
                                    ,'DescInstrucao':'str'
                                    ,'DescEstadoCivil':'str'}
                            ,parse_dates=[4]
                            ,header=0)

# %% [markdown]
# # 03.5 - Criar uma Função padrão para Importar um Arquivo CSV

# %% [markdown]
# # 04 - Explorando a Estrutura de um DataFrame
# * Detalhe: Método info() exibe a estrutura de um dataframe, colunas, datatype, tamanho, quantidade registros por coluna

# %%
dfCandidatos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29262 entries, 0 to 29261
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   NumAnoEleicao     29262 non-null  int32
#  1   NomTpoEleicao     29262 non-null  object
#  2   NumTurno          29262 non-null  int32
#  3   DescEleicao       29262 non-null  object
#  4   DtEleicao         29262 non-null  datetime64[ns]
#  5   SigUF             29262 non-null  object
#  6   DescCargo         29262 non-null  object
#  7   SeqCandidato      29262 non-null  object
#  8   NomCandidatoUrna  29262 non-null  object
#  9   NumPartido        29262 non-null  int32
#  10  SigParido         29262 non-null  object
#  11  DescInstrucao     29262 non-null  object
#  12  DescEstadoCivil   29262 non-null  object
# dtypes: datetime64[ns](1), int32(3), object(9)
# memory usage: 2.6+ MB

# %% [markdown]
# # 05 - Removendo Vírgula por Ponto para Colunas do Tipo Float

# %%
arquivoBemCandidato = '../ProjetoPythonKB/Dados/BemCandidato/bem_candidato_2022_BRASIL.csv'

dfBemCandidato = pd.read_csv(arquivoBemCandidato
                            ,sep=';'
                            ,encoding='latin-1'
                            ,usecols=[16]
                            ,names=['VlrBem']
                            ,dtype={'VlrBem':'str'
                            }
                            ,header=0)

dfBemCandidato['VlrBem_c'] = dfBemCandidato['VlrBem'].apply(lambda x: str(x).replace(",",".")).astype('float64')

dfBemCandidato
# Out:
#           VlrBem   VlrBem_c
# 0       33500,00   33500.00
# 1       22632,00   22632.00
# 2       46010,70   46010.70
# 3      800000,00  800000.00
# 4       95000,00   95000.00
# ...          ...        ...
# 90199   15129,56   15129.56
# 90200  150000,00  150000.00
# 90201    1217,50    1217.50
# 90202    1705,85    1705.85
# 90203    1298,25    1298.25
#
# [90204 rows x 2 columns]

# %% [markdown]
# # 06 - Selecionando TOP N registros de um DataFrame
# * Detalhe: Método head() exibe por default os 10 primeiros registros de um DataFrame
# * Seu funcionamento é bem parecido com o comando TOP ou LIMIT de bancos de dados

# %%
# SELECIONANDO TOP N REGISTROS DE UM DATAFRAME #

dfCandidatos.head(1)
# Out:
#    NumAnoEleicao      NomTpoEleicao  NumTurno                     DescEleicao  \
# 0           2022  ELEIÇÃO ORDINÁRIA         1  Eleições Gerais Estaduais 2022
#
#    DtEleicao SigUF          DescCargo  SeqCandidato  \
# 0 2022-02-10    PR  DEPUTADO ESTADUAL  160002000000
#
#               NomCandidatoUrna  NumPartido SigParido      DescInstrucao  \
# 0  PROFESSOR MARCELINO ANTUNES          14       PTB  SUPERIOR COMPLETO
#
#   DescEstadoCivil
# 0   DIVORCIADO(A)

# %% [markdown]
# # 07 - Aplicando o Comando Distinct em uma Coluna do DataFrame (unique())
# * Detalhe: Método unique() exibe valores distintos de uma coluna
# * Seu funcionamento é bem parecido com o comando DISTINCT de bancos de dados

# %%
dfCandidatos['DescCargo'].unique()
# Out:
# array(['DEPUTADO ESTADUAL', 'DEPUTADO FEDERAL', '2º SUPLENTE', 'SENADOR',
#        'VICE-GOVERNADOR', 'DEPUTADO DISTRITAL', '1º SUPLENTE',
#        'GOVERNADOR', 'PRESIDENTE', 'VICE-PRESIDENTE'], dtype=object)

# %% [markdown]
# # 08 - Ordenando um DataFrame (sort_values())
# * Detalhe: Método sort_values() realiza a odernação de um DataFrame baseado nas colunas
# * Os parâmetros usados no exemplo abaixo foram:
# ** by='' - Define qual coluna deverá ser ordenada. Caso tenha mais de uma coluna na clausula de ordenação, elas devem vim dentro de conchetes ([]);
# ** inplace=True - significa que a ordenação deve ser persistida no DataFrame carregado;
# ** ascending=True - ordenação deverá ser feita do menor pro maior ou conforme o alfabeto [A-Z]. Caso seja ascending=False, ordenação decrescente.
# * Seu funcionamento é bem parecido com o comando ORDER BY ASC/DESC de bancos de dados

# %%
# ORDENANDO UM DATAFRAME #

dfCandidatos.sort_values(by='SigUF'
                         , inplace=True
                         , ascending=True)

# %% [markdown]
# # 09 - Agrupando um DataFrame (groupby())

# %%
# AGRUPANDO VALORES DENTRO DE UM DATAFRAME #

dfCandidatos_Agrd = dfCandidatos.groupby(['DescCargo']
                                         , as_index=False).agg(QtdCandidato=('SeqCandidato'
                                                                             ,'count'))

dfCandidatos_Agrd.sort_values(by='QtdCandidato'
                                 , inplace=True
                                 , ascending=False
                             )

dfCandidatos_Agrd
# Out:
#             DescCargo  QtdCandidato
# 3   DEPUTADO ESTADUAL         16737
# 4    DEPUTADO FEDERAL         10630
# 2  DEPUTADO DISTRITAL           610
# 1         2º SUPLENTE           276
# 0         1º SUPLENTE           274
# 7             SENADOR           243
# 8     VICE-GOVERNADOR           242
# 5          GOVERNADOR           224
# 6          PRESIDENTE            13
# 9     VICE-PRESIDENTE            13

# %% [markdown]
# # 10 - Funções de Agrupamento (Count(), Sum(), Min(), Max() e Mean())

# %%
arquivoBemCandidato = '../ProjetoPythonKB/Dados/BemCandidato/bem_candidato_2022_BRASIL.csv'

dfBemCandidato = pd.read_csv(arquivoBemCandidato
                            ,sep=';'
                            ,encoding='latin-1'
                            )

dfBemCandidato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90204 entries, 0 to 90203
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   DT_GERACAO             90204 non-null  object
#  1   HH_GERACAO             90204 non-null  object
#  2   ANO_ELEICAO            90204 non-null  int64
#  3   CD_TIPO_ELEICAO        90204 non-null  int64
#  4   NM_TIPO_ELEICAO        90204 non-null  object
#  5   CD_ELEICAO             90204 non-null  int64
#  6   DS_ELEICAO             90204 non-null  object
#  7   DT_ELEICAO             90204 non-null  object
#  8   SG_UF                  90204 non-null  object
#  9   SG_UE                  90204 non-null  object
#  10  NM_UE                  90204 non-null  object
#  11  SQ_CANDIDATO           90204 non-null  int64
#  12  NR_ORDEM_CANDIDATO     90204 non-null  int64
#  13  CD_TIPO_BEM_CANDIDATO  90204 non-null  int64
#  14  DS_TIPO_BEM_CANDIDATO  90204 non-null  object
#  15  DS_BEM_CANDIDATO       90204 non-null  object
#  16  VR_BEM_CANDIDATO       90204 non-null  object
#  17  DT_ULTIMA_ATUALIZACAO  90204 non-null  object
#  18  HH_ULTIMA_ATUALIZACAO  90204 non-null  object
# dtypes: int64(6), object(13)
# memory usage: 13.1+ MB

# %%
arquivoBemCandidato = '../ProjetoPythonKB/Dados/BemCandidato/bem_candidato_2022_BRASIL.csv'

dfBemCandidato = pd.read_csv(arquivoBemCandidato
                            ,sep=';'
                            ,encoding='latin-1'
                            ,usecols=[8,11,14,16]
                            ,names=['SigUF','SeqCandidato','DescTpoBem','VlrBem']
                            ,dtype={'SigUF':'str'
                                ,'SeqCandidato':'str'
                                ,'DescTpoBem':'str'
                                ,'VlrBem':'str'
                            }
                            ,header=0)

dfBemCandidato['VlrBem'] = dfBemCandidato['VlrBem'].apply(lambda x: str(x).replace(",",".")).astype('float64')

dfBemCandidato_Agrd = dfBemCandidato.groupby(['DescTpoBem'],as_index=True).agg( \
                                                    QtdBem=('DescTpoBem','count')
                                                   ,VltTotalBem=('VlrBem','sum')
                                                   ,VltMenorBem=('VlrBem','min')
                                                   ,VltMaiorBem=('VlrBem','max')
                                                   ,VltMedioBem=('VlrBem','mean'))

dfBemCandidato_Agrd.style.format("{:.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_c7f2c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7f2c_level0_col0" class="col_heading level0 col0" >QtdBem</th>
#       <th id="T_c7f2c_level0_col1" class="col_heading level0 col1" >VltTotalBem</th>
#       <th id="T_c7f2c_level0_col2" class="col_heading level0 col2" >VltMenorBem</th>
#       <th id="T_c7f2c_level0_col3" class="col_heading level0 col3" >VltMaiorBem</th>
#       <th id="T_c7f2c_level0_col4" class="col_heading level0 col4" >VltMedioBem</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >DescTpoBem</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7f2c_level0_row0" class="row_heading level0 row0" >Aeronave</th>
#       <td id="T_c7f2c_row0_col0" class="data row0 col0" >95.00</td>
#       <td id="T_c7f2c_row0_col1" class="data row0 col1" >100085320.57</td>
#       <td id="T_c7f2c_row0_col2" class="data row0 col2" >20000.00</td>
#       <td id="T_c7f2c_row0_col3" class="data row0 col3" >10000000.00</td>
#       <td id="T_c7f2c_row0_col4" class="data row0 col4" >1053529.69</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row1" class="row_heading level0 row1" >Apartamento</th>
#       <td id="T_c7f2c_row1_col0" class="data row1 col0" >6711.00</td>
#       <td id="T_c7f2c_row1_col1" class="data row1 col1" >2297953328.81</td>
#       <td id="T_c7f2c_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_c7f2c_row1_col3" class="data row1 col3" >7879197.99</td>
#       <td id="T_c7f2c_row1_col4" class="data row1 col4" >342415.93</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row2" class="row_heading level0 row2" >Aplicação de renda fixa (CDB, RDB e outros)</th>
#       <td id="T_c7f2c_row2_col0" class="data row2 col0" >4126.00</td>
#       <td id="T_c7f2c_row2_col1" class="data row2 col1" >707325198.77</td>
#       <td id="T_c7f2c_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_c7f2c_row2_col3" class="data row2 col3" >61792857.29</td>
#       <td id="T_c7f2c_row2_col4" class="data row2 col4" >171431.22</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row3" class="row_heading level0 row3" >Ações (inclusive as provenientes de linha telefônica)</th>
#       <td id="T_c7f2c_row3_col0" class="data row3 col0" >2297.00</td>
#       <td id="T_c7f2c_row3_col1" class="data row3 col1" >1011767357.79</td>
#       <td id="T_c7f2c_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_c7f2c_row3_col3" class="data row3 col3" >299503939.00</td>
#       <td id="T_c7f2c_row3_col4" class="data row3 col4" >440473.38</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row4" class="row_heading level0 row4" >Bem relacionado com o exercício da atividade autônoma</th>
#       <td id="T_c7f2c_row4_col0" class="data row4 col0" >111.00</td>
#       <td id="T_c7f2c_row4_col1" class="data row4 col1" >12100496.58</td>
#       <td id="T_c7f2c_row4_col2" class="data row4 col2" >0.00</td>
#       <td id="T_c7f2c_row4_col3" class="data row4 col3" >1830500.00</td>
#       <td id="T_c7f2c_row4_col4" class="data row4 col4" >109013.48</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row5" class="row_heading level0 row5" >Benfeitorias</th>
#       <td id="T_c7f2c_row5_col0" class="data row5 col0" >160.00</td>
#       <td id="T_c7f2c_row5_col1" class="data row5 col1" >42981548.23</td>
#       <td id="T_c7f2c_row5_col2" class="data row5 col2" >61.81</td>
#       <td id="T_c7f2c_row5_col3" class="data row5 col3" >2680325.00</td>
#       <td id="T_c7f2c_row5_col4" class="data row5 col4" >268634.68</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row6" class="row_heading level0 row6" >Caderneta de poupança</th>
#       <td id="T_c7f2c_row6_col0" class="data row6 col0" >3166.00</td>
#       <td id="T_c7f2c_row6_col1" class="data row6 col1" >89716190.39</td>
#       <td id="T_c7f2c_row6_col2" class="data row6 col2" >0.00</td>
#       <td id="T_c7f2c_row6_col3" class="data row6 col3" >5832110.00</td>
#       <td id="T_c7f2c_row6_col4" class="data row6 col4" >28337.39</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row7" class="row_heading level0 row7" >Casa</th>
#       <td id="T_c7f2c_row7_col0" class="data row7 col0" >8644.00</td>
#       <td id="T_c7f2c_row7_col1" class="data row7 col1" >2785069153.07</td>
#       <td id="T_c7f2c_row7_col2" class="data row7 col2" >0.00</td>
#       <td id="T_c7f2c_row7_col3" class="data row7 col3" >24163378.10</td>
#       <td id="T_c7f2c_row7_col4" class="data row7 col4" >322196.80</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row8" class="row_heading level0 row8" >Construção</th>
#       <td id="T_c7f2c_row8_col0" class="data row8 col0" >203.00</td>
#       <td id="T_c7f2c_row8_col1" class="data row8 col1" >71980386.60</td>
#       <td id="T_c7f2c_row8_col2" class="data row8 col2" >110.00</td>
#       <td id="T_c7f2c_row8_col3" class="data row8 col3" >6099245.28</td>
#       <td id="T_c7f2c_row8_col4" class="data row8 col4" >354583.19</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row9" class="row_heading level0 row9" >Consórcio não contemplado</th>
#       <td id="T_c7f2c_row9_col0" class="data row9 col0" >759.00</td>
#       <td id="T_c7f2c_row9_col1" class="data row9 col1" >48237244.46</td>
#       <td id="T_c7f2c_row9_col2" class="data row9 col2" >342.60</td>
#       <td id="T_c7f2c_row9_col3" class="data row9 col3" >1250000.00</td>
#       <td id="T_c7f2c_row9_col4" class="data row9 col4" >63553.68</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row10" class="row_heading level0 row10" >Crédito decorrente de alienação</th>
#       <td id="T_c7f2c_row10_col0" class="data row10 col0" >71.00</td>
#       <td id="T_c7f2c_row10_col1" class="data row10 col1" >41002723.48</td>
#       <td id="T_c7f2c_row10_col2" class="data row10 col2" >7027.50</td>
#       <td id="T_c7f2c_row10_col3" class="data row10 col3" >7464750.00</td>
#       <td id="T_c7f2c_row10_col4" class="data row10 col4" >577503.15</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row11" class="row_heading level0 row11" >Crédito decorrente de empréstimo</th>
#       <td id="T_c7f2c_row11_col0" class="data row11 col0" >595.00</td>
#       <td id="T_c7f2c_row11_col1" class="data row11 col1" >754961580.47</td>
#       <td id="T_c7f2c_row11_col2" class="data row11 col2" >0.00</td>
#       <td id="T_c7f2c_row11_col3" class="data row11 col3" >178000000.00</td>
#       <td id="T_c7f2c_row11_col4" class="data row11 col4" >1268842.99</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row12" class="row_heading level0 row12" >Depósito bancário em conta corrente no País</th>
#       <td id="T_c7f2c_row12_col0" class="data row12 col0" >8295.00</td>
#       <td id="T_c7f2c_row12_col1" class="data row12 col1" >286795988.49</td>
#       <td id="T_c7f2c_row12_col2" class="data row12 col2" >0.00</td>
#       <td id="T_c7f2c_row12_col3" class="data row12 col3" >7731567.87</td>
#       <td id="T_c7f2c_row12_col4" class="data row12 col4" >34574.56</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row13" class="row_heading level0 row13" >Depósito bancário em conta corrente no exterior</th>
#       <td id="T_c7f2c_row13_col0" class="data row13 col0" >109.00</td>
#       <td id="T_c7f2c_row13_col1" class="data row13 col1" >26685174.49</td>
#       <td id="T_c7f2c_row13_col2" class="data row13 col2" >0.00</td>
#       <td id="T_c7f2c_row13_col3" class="data row13 col3" >6190707.60</td>
#       <td id="T_c7f2c_row13_col4" class="data row13 col4" >244818.11</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row14" class="row_heading level0 row14" >Dinheiro em espécie - moeda estrangeira</th>
#       <td id="T_c7f2c_row14_col0" class="data row14 col0" >149.00</td>
#       <td id="T_c7f2c_row14_col1" class="data row14 col1" >48580995.35</td>
#       <td id="T_c7f2c_row14_col2" class="data row14 col2" >0.00</td>
#       <td id="T_c7f2c_row14_col3" class="data row14 col3" >395643

# %% [markdown]
# # 11 - Convertendo Datatype de uma Coluna em um DataFrame

# %%
AnoMes=['Jan22', 'Fev22', 'Mar22', 'Abr22','Mai22','Jun22','Jul22','Ago22','Set22','Out22','Nov22','Dez22']
Pedidos=['10','20','10','15','10','12','15','11','22','23','9','42']
Valor=['2314,09','22311,90','2421.78','4311.89','123143,49','12331.43','4321,44','54322,56','23421.5','43156,99','123599.65','9943543,99']


df=pd.DataFrame({"AnoMes":AnoMes,
                "QtdPedidos":Pedidos,
                "Vlr":Valor})

df['QtdPedidos_c'] = df['QtdPedidos'].astype(int)

df['Vlr_c'] = df['Vlr'].apply(lambda x: str(x).replace(",",".")).astype('float64')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AnoMes        12 non-null     object
#  1   QtdPedidos    12 non-null     object
#  2   Vlr           12 non-null     object
#  3   QtdPedidos_c  12 non-null     int32
#  4   Vlr_c         12 non-null     float64
# dtypes: float64(1), int32(1), object(3)
# memory usage: 560.0+ bytes

# %% [markdown]
# # 12 - Renomeando Colunas em um DataFrame

# %%
df.rename(columns = {'Vlr_c':'Vlr_T'
                        , 'QtdPedidos_c':'QtdPedidos_T'}
                        , inplace = True)

df.head(1)
# Out:
#   AnoMes QtdPedidos      Vlr  QtdPedidos_T    Vlr_T
# 0  Jan22         10  2314,09            10  2314.09

# %% [markdown]
# # 13 - Removendo Colunas em um DataFrame

# %%
df.drop('AnoMes', axis=1, inplace=True)

df.head(1)
# Out:
#   QtdPedidos      Vlr  QtdPedidos_T    Vlr_T
# 0         10  2314,09            10  2314.09

# %%
df = df.drop(df.columns[3], axis=1) 

df.head(1)
# Out:
#   QtdPedidos      Vlr  QtdPedidos_T
# 0         10  2314,09            10

# %%
df.drop(['QtdPedidos', 'Vlr'], axis=1, inplace=True)

df.head(1)
# Out:
#    QtdPedidos_T
# 0            10

# %% [markdown]
# # 14 - Tratando Valores Nulos em Colunas de um DataFrame

# %%
arquivoCSV = '..\ProjetoPythonKB\Dados\Candidato\consulta_cand_2022_BRASIL.csv'

dfCandidatos = pd.read_csv(arquivoCSV
                            , sep=';'
                            ,encoding='latin-1'
                            , usecols=[2,4,5,7,8,10,14,15,18,27,28,43,48,50]
                            ,names=['NumAnoEleicao'
                                    ,'NomTpoEleicao'
                                    ,'NumTurno'
                                    ,'DescEleicao'
                                    ,'DtEleicao'
                                    ,'SigUF'
                                    ,'DescCargo'
                                    ,'SeqCandidato'
                                    ,'NomCandidatoUrna'
                                    ,'NumPartido'
                                    ,'SigParido'
                                    ,'NumIdadePosse'
                                    ,'DescInstrucao'
                                    ,'DescEstadoCivil']
                            ,dtype={'NumAnoEleicao':'long'
                                    ,'NomTpoEleicao':'str'
                                    ,'NumTurno':'long'
                                    ,'DescEleicao':'str'
                                    ,'DtEleicao':'str'
                                    ,'SigUF':'str'
                                    ,'DescCargo':'str'
                                    ,'SeqCandidato':'str'
                                    ,'NomCandidatoUrna':'str'
                                    ,'NumPartido':'long'
                                    ,'SigParido':'str'
                                    ,'NumIdadePosse':'str'
                                    ,'DescInstrucao':'str'
                                    ,'DescEstadoCivil':'str'}
                            ,parse_dates=[4]
                            ,header=0)

dfCandidatos['NumIdadePosse'].fillna('0',inplace=True)

dfCandidatos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29262 entries, 0 to 29261
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   NumAnoEleicao     29262 non-null  int32
#  1   NomTpoEleicao     29262 non-null  object
#  2   NumTurno          29262 non-null  int32
#  3   DescEleicao       29262 non-null  object
#  4   DtEleicao         29262 non-null  datetime64[ns]
#  5   SigUF             29262 non-null  object
#  6   DescCargo         29262 non-null  object
#  7   SeqCandidato      29262 non-null  object
#  8   NomCandidatoUrna  29262 non-null  object
#  9   NumPartido        29262 non-null  int32
#  10  SigParido         29262 non-null  object
#  11  NumIdadePosse     29262 non-null  object
#  12  DescInstrucao     29262 non-null  object
#  13  DescEstadoCivil   29262 non-null  object
# dtypes: datetime64[ns](1), int32(3), object(10)
# memory usage: 2.8+ MB

# %% [markdown]
# # 15 - Comando Contém (isin) Valor em uma Coluna de um DataFrame

# %%
arquivoCSV = '..\ProjetoPythonKB\Dados\Candidato\consulta_cand_2022_BRASIL.csv'

dfCandidatos = pd.read_csv(arquivoCSV
                            , sep=';'
                            ,encoding='latin-1'
                            , usecols=[2,4,5,7,8,10,14,15,18,27,28,43,48,50]
                            ,names=['NumAnoEleicao'
                                    ,'NomTpoEleicao'
                                    ,'NumTurno'
                                    ,'DescEleicao'
                                    ,'DtEleicao'
                                    ,'SigUF'
                                    ,'DescCargo'
                                    ,'SeqCandidato'
                                    ,'NomCandidatoUrna'
                                    ,'NumPartido'
                                    ,'SigParido'
                                    ,'NumIdadePosse'
                                    ,'DescInstrucao'
                                    ,'DescEstadoCivil']
                            ,dtype={'NumAnoEleicao':'long'
                                    ,'NomTpoEleicao':'str'
                                    ,'NumTurno':'long'
                                    ,'DescEleicao':'str'
                                    ,'DtEleicao':'str'
                                    ,'SigUF':'str'
                                    ,'DescCargo':'str'
                                    ,'SeqCandidato':'str'
                                    ,'NomCandidatoUrna':'str'
                                    ,'NumPartido':'long'
                                    ,'SigParido':'str'
                                    ,'NumIdadePosse':'str'
                                    ,'DescInstrucao':'str'
                                    ,'DescEstadoCivil':'str'}
                            ,parse_dates=[4]
                            ,header=0)

dfCandidatos['NumIdadePosse'].fillna('0',inplace=True)

dfCandidatos[dfCandidatos['SigUF'].isin(['RJ','SP'])]['SigUF'].unique()
# Out:
# array(['SP', 'RJ'], dtype=object)

# %% [markdown]
# # 16 - Filtrando Valores em um ou Várias Colunas de um DataFrame

# %%
arquivoCSV = '..\ProjetoPythonKB\Dados\Candidato\consulta_cand_2022_BRASIL.csv'

dfCandidatos = pd.read_csv(arquivoCSV
                            , sep=';'
                            ,encoding='latin-1'
                            , usecols=[2,4,5,7,8,10,14,15,18,27,28,43,48,50]
                            ,names=['NumAnoEleicao'
                                    ,'NomTpoEleicao'
                                    ,'NumTurno'
                                    ,'DescEleicao'
                                    ,'DtEleicao'
                                    ,'SigUF'
                                    ,'DescCargo'
                                    ,'SeqCandidato'
                                    ,'NomCandidatoUrna'
                                    ,'NumPartido'
                                    ,'SigParido'
                                    ,'NumIdadePosse'
                                    ,'DescInstrucao'
                                    ,'DescEstadoCivil']
                            ,dtype={'NumAnoEleicao':'long'
                                    ,'NomTpoEleicao':'str'
                                    ,'NumTurno':'long'
                                    ,'DescEleicao':'str'
                                    ,'DtEleicao':'str'
                                    ,'SigUF':'str'
                                    ,'DescCargo':'str'
                                    ,'SeqCandidato':'str'
                                    ,'NomCandidatoUrna':'str'
                                    ,'NumPartido':'long'
                                    ,'SigParido':'str'
                                    ,'NumIdadePosse':'str'
                                    ,'DescInstrucao':'str'
                                    ,'DescEstadoCivil':'str'}
                            ,parse_dates=[4]
                            ,header=0)

dfCandidatos['NumIdadePosse'].fillna('0',inplace=True)

# %%
dfCandidatos[dfCandidatos['SigUF']=='RJ'].head(3)
# Out:
#     NumAnoEleicao      NomTpoEleicao  NumTurno  \
# 22           2022  ELEIÇÃO ORDINÁRIA         1
# 38           2022  ELEIÇÃO ORDINÁRIA         1
# 85           2022  ELEIÇÃO ORDINÁRIA         1
#
#                        DescEleicao  DtEleicao SigUF          DescCargo  \
# 22  Eleições Gerais Estaduais 2022 2022-02-10    RJ   DEPUTADO FEDERAL
# 38  Eleições Gerais Estaduais 2022 2022-02-10    RJ  DEPUTADO ESTADUAL
# 85  Eleições Gerais Estaduais 2022 2022-02-10    RJ  DEPUTADO ESTADUAL
#
#     SeqCandidato              NomCandidatoUrna  NumPartido SigParido  \
# 22  190002000000                  RENÊ FREITAS          30      NOVO
# 38  190002000000  PROFESSORA ADRIANA DE MORAES          51  PATRIOTA
# 85  190002000000                  MARQUINHO OI          44     UNIÃO
#
#    NumIdadePosse          DescInstrucao DescEstadoCivil
# 22            39      SUPERIOR COMPLETO     SOLTEIRO(A)
# 38            44      SUPERIOR COMPLETO     SOLTEIRO(A)
# 85            61  ENSINO MÉDIO COMPLETO       CASADO(A)

# %%
dfCandidatos[(dfCandidatos['SigUF']=='RJ') & (dfCandidatos['DescCargo']=='DEPUTADO FEDERAL')]
# Out:
#        NumAnoEleicao      NomTpoEleicao  NumTurno  \
# 22              2022  ELEIÇÃO ORDINÁRIA         1
# 101             2022  ELEIÇÃO ORDINÁRIA         1
# 148             2022  ELEIÇÃO ORDINÁRIA         1
# 166             2022  ELEIÇÃO ORDINÁRIA         1
# 177             2022  ELEIÇÃO ORDINÁRIA         1
# ...              ...                ...       ...
# 29123           2022  ELEIÇÃO ORDINÁRIA         1
# 29129           2022  ELEIÇÃO ORDINÁRIA         1
# 29176           2022  ELEIÇÃO ORDINÁRIA         1
# 29179           2022  ELEIÇÃO ORDINÁRIA         1
# 29208           2022  ELEIÇÃO ORDINÁRIA         1
#
#                           DescEleicao  DtEleicao SigUF         DescCargo  \
# 22     Eleições Gerais Estaduais 2022 2022-02-10    RJ  DEPUTADO FEDERAL
# 101    Eleições Gerais Estaduais 2022 2022-02-10    RJ  DEPUTADO FEDERAL
# 148    Eleições Gerais Estaduais 2022 2022-02-10    RJ  DEPUTADO FEDERAL
# 166    Eleições Gerais Estaduais 2022 2022-02-10    RJ  DEPUTADO FEDERAL
# 177    Eleições Gerais Estaduais 2022 2022-02-10    RJ  DEPUTADO FEDERAL
# ...                               ...        ...   ...               ...
# 29123  Eleições Gerais Estaduais 2022 2022-02-10    RJ  DEPUTADO FEDERAL
# 29129  Eleições Gerais Estaduais 2022 2022-02-10    RJ  DEPUTADO FEDERAL
# 29176  Eleições Gerais Estaduais 2022 2022-02-10    RJ  DEPUTADO FEDERAL
# 29179  Eleições Gerais Estaduais 2022 2022-02-10    RJ  DEPUTADO FEDERAL
# 29208  Eleições Gerais Estaduais 2022 2022-02-10    RJ  DEPUTADO FEDERAL
#
#        SeqCandidato  NomCandidatoUrna  NumPartido      SigParido  \
# 22     190002000000      RENÊ FREITAS          30           NOVO
# 101    190002000000     ARIEL MARTINS          14            PTB
# 148    190002000000      EDUARDO BADU          10   REPUBLICANOS
# 166    190002000000  BISPO JOÃO LEITE          15            MDB
# 177    190002000000             KEREM          19           PODE
# ...             ...               ...         ...            ...
# 29123  190002000000       MAJOR JOYCE          14            PTB
# 29129  190002000000  DRA SARITA PAIVA          28           PRTB
# 29176  190002000000     NELSON JUNIOR          40            PSB
# 29179  190002000000    LETICIA CABRAL          28           PRTB
# 29208  190002000000  ANATIELY BARBOSA          77  SOLIDARIEDADE
#
#       NumIdadePosse                DescInstrucao DescEstadoCivil
# 22               39            SUPERIOR COMPLETO     SOLTEIRO(A)
# 101              30            SUPERIOR COMPLETO     SOLTEIRO(A)
# 148              41            SUPERIOR COMPLETO       CASADO(A)
# 166              54  ENSINO FUNDAMENTAL COMPLETO   DIVORCIADO(A)
# 177              46          SUPERIOR INCOMPLETO       CASADO(A)
# ...             ...                          ...             ...
# 29123            41            SUPERIOR COMPLETO       CASADO(A)
# 29129            58            SUPERIOR COMPLETO       CASADO(A)
# 29176            45        ENSINO MÉDIO COMPLETO       CASADO(A)
# 29179            34        ENSINO MÉDIO COMPLETO       CASADO(A)
# 29208            37        ENSINO MÉDIO COMPLETO       CASADO(A)
#
# [1083 rows x 14 columns]

# %%
dfCandidatos.where(dfCandidatos['SigUF'] !='SP')
# Out:
#        NumAnoEleicao      NomTpoEleicao  NumTurno  \
# 0             2022.0  ELEIÇÃO ORDINÁRIA       1.0
# 1             2022.0  ELEIÇÃO ORDINÁRIA       1.0
# 2             2022.0  ELEIÇÃO ORDINÁRIA       1.0
# 3             2022.0  ELEIÇÃO ORDINÁRIA       1.0
# 4                NaN                NaN       NaN
# ...              ...                ...       ...
# 29257         2022.0  ELEIÇÃO ORDINÁRIA       1.0
# 29258         2022.0  ELEIÇÃO ORDINÁRIA       1.0
# 29259         2022.0  ELEIÇÃO ORDINÁRIA       1.0
# 29260         2022.0  ELEIÇÃO ORDINÁRIA       1.0
# 29261         2022.0  ELEIÇÃO ORDINÁRIA       1.0
#
#                           DescEleicao  DtEleicao SigUF          DescCargo  \
# 0      Eleições Gerais Estaduais 2022 2022-02-10    PR  DEPUTADO ESTADUAL
# 1      Eleições Gerais Estaduais 2022 2022-02-10    MS   DEPUTADO FEDERAL
# 2      Eleições Gerais Estaduais 2022 2022-02-10    GO   DEPUTADO FEDERAL
# 3      Eleições Gerais Estaduais 2022 2022-02-10    RN   DEPUTADO FEDERAL
# 4                                 NaN        NaT   NaN                NaN
# ...                               ...        ...   ...                ...
# 29257  Eleições Gerais Estaduais 2022 2022-02-10    ES   DEPUTADO FEDERAL
# 29258  Eleições Gerais Estaduais 2022 2022-02-10    MG   DEPUTADO FEDERAL
# 29259  Eleições Gerais Estaduais 2022 2022-02-10    TO  DEPUTADO ESTADUAL
# 29260  Eleições Gerais Estaduais 2022 2022-02-10    MA   DEPUTADO FEDERAL
# 29261  Eleições Gerais Estaduais 2022 2022-02-10    MA  DEPUTADO ESTADUAL
#
#        SeqCandidato             NomCandidatoUrna  NumPartido  SigParido  \
# 0      160002000000  PROFESSOR MARCELINO ANTUNES        14.0        PTB
# 1      120002000000             LOURDES MONTEIRO        15.0        MDB
# 2       90001675157             CYNTHIA OLIVEIRA        18.0       REDE
# 3      200002000000               GIDEON ISMAIAS        23.0  CIDADANIA
# 4               NaN                          NaN         NaN        NaN
# ...             ...                          ...         ...        ...
# 29257   80001719429               HELDER SALOMÃO        13.0         PT
# 29258  130002000000         ROSSY DA AUTO ESCOLA        14.0        PTB
# 29259  270002000000                LUANA RIBEIRO        65.0    PC do B
# 29260  100002000000                      MAGRADO        44.0      UNIÃO
# 29261  100002000000               DOMINGOS FILHO        16.0       PSTU
#
#       NumIdadePosse          DescInstrucao DescEstadoCivil
# 0                62      SUPERIOR COMPLETO   DIVORCIADO(A)
# 1                68      SUPERIOR COMPLETO       CASADO(A)
# 2                36      SUPERIOR COMPLETO       CASADO(A)
# 3                41  ENSINO MÉDIO COMPLETO       CASADO(A)
# 4               NaN                    NaN             NaN
# ...             ...                    ...             ...
# 29257            58      SUPERIOR COMPLETO       CASADO(A)
# 29258            58      SUPERIOR COMPLETO   DIVORCIADO(A)
# 29259            44      SUPERIOR COMPLETO   DIVORCIADO(A)
# 29260            49    SUPERIOR INCOMPLETO   DIVORCIADO(A)
# 29261            47      SUPERIOR COMPLETO       CASADO(A)
#
# [29262 rows x 14 columns]

# %% [markdown]
# # 17 - Comando Similar ao Left e Right do SQL Server

# %%
# COMANDO LEFT E RIGHT DO SQL SERVER #


AnoMes=['Jan2022', 'Fev2022', 'Mar2022', 'Abr2022','Mai2022','Jun2022','Jul2022','Ago2022','Set2022','Out2022','Nov2022','Dez2022']
Pedidos=['10','20','10','15','10','12','15','11','22','23','9','42']
Valor=['2314,09','22311,90','2421.78','4311.89','123143,49','12331.43','4321,44','54322,56','23421.5','43156,99','123599.65','9943543,99']


df=pd.DataFrame({"AnoMes":AnoMes,
                "QtdPedidos":Pedidos,
                "Vlr":Valor})

df['QtdPedidos_c'] = df['QtdPedidos'].astype(int)

df['Vlr_c'] = df['Vlr'].apply(lambda x: str(x).replace(",",".")).astype('float64')

df['Ano'] = df['AnoMes'].str[3:]

df['Mes'] = df['AnoMes'].str[:3]

df
# Out:
#      AnoMes QtdPedidos         Vlr  QtdPedidos_c       Vlr_c   Ano  Mes
# 0   Jan2022         10     2314,09            10     2314.09  2022  Jan
# 1   Fev2022         20    22311,90            20    22311.90  2022  Fev
# 2   Mar2022         10     2421.78            10     2421.78  2022  Mar
# 3   Abr2022         15     4311.89            15     4311.89  2022  Abr
# 4   Mai2022         10   123143,49            10   123143.49  2022  Mai
# 5   Jun2022         12    12331.43            12    12331.43  2022  Jun
# 6   Jul2022         15     4321,44            15     4321.44  2022  Jul
# 7   Ago2022         11    54322,56            11    54322.56  2022  Ago
# 8   Set2022         22     23421.5            22    23421.50  2022  Set
# 9   Out2022         23    43156,99            23    43156.99  2022  Out
# 10  Nov2022          9   123599.65             9   123599.65  2022  Nov
# 11  Dez2022         42  9943543,99            42  9943543.99  2022  Dez

# %% [markdown]
# # 18 - Comando Similar ao Replicate "zfill()" do SQL Server

# %%
# COMPLETANDO COM ZERO A ESQUERDA #

AnoMes=['Jan2022', 'Fev2022', 'Mar2022', 'Abr2022','Mai2022','Jun2022','Jul2022','Ago2022','Set2022','Out2022','Nov2022','Dez2022']
Loja=['ABCDE','BCDE','CD','DEFGH','EFG','FGIJK','GHIJ','HI','IJ','JKL','KL','LMNOPQ']
Pedidos=['10','20','10','15','10','12','15','11','22','23','9','42']
Valor=['2314,09','22311,90','2421.78','4311.89','123143,49','12331.43','4321,44','54322,56','23421.5','43156,99','123599.65','9943543,99']


df=pd.DataFrame({"AnoMes":AnoMes,
                 "Loja":Loja,
                "QtdPedidos":Pedidos,
                "Vlr":Valor})

df['QtdPedidos_c'] = df['QtdPedidos'].astype(int)

df['Vlr_c'] = df['Vlr'].apply(lambda x: str(x).replace(",",".")).astype('float64')

df['Ano'] = df['AnoMes'].str[3:]

df['Mes'] = df['AnoMes'].str[:3]

df['Loja'] = pd.Series(df['Loja']).astype(str).str.zfill(10) 

df
# Out:
#      AnoMes        Loja QtdPedidos         Vlr  QtdPedidos_c       Vlr_c  \
# 0   Jan2022  00000ABCDE         10     2314,09            10     2314.09
# 1   Fev2022  000000BCDE         20    22311,90            20    22311.90
# 2   Mar2022  00000000CD         10     2421.78            10     2421.78
# 3   Abr2022  00000DEFGH         15     4311.89            15     4311.89
# 4   Mai2022  0000000EFG         10   123143,49            10   123143.49
# 5   Jun2022  00000FGIJK         12    12331.43            12    12331.43
# 6   Jul2022  000000GHIJ         15     4321,44            15     4321.44
# 7   Ago2022  00000000HI         11    54322,56            11    54322.56
# 8   Set2022  00000000IJ         22     23421.5            22    23421.50
# 9   Out2022  0000000JKL         23    43156,99            23    43156.99
# 10  Nov2022  00000000KL          9   123599.65             9   123599.65
# 11  Dez2022  0000LMNOPQ         42  9943543,99            42  9943543.99
#
#      Ano  Mes
# 0   2022  Jan
# 1   2022  Fev
# 2   2022  Mar
# 3   2022  Abr
# 4   2022  Mai
# 5   2022  Jun
# 6   2022  Jul
# 7   2022  Ago
# 8   2022  Set
# 9   2022  Out
# 10  2022  Nov
# 11  2022  Dez

# %% [markdown]
# # 19 - Removendo Duplicidades em um DataFrame

# %%
arquivoCSV = '..\ProjetoPythonKB\Dados\Candidato\consulta_cand_2022_BRASIL.csv'

dfSigUFFiltrado = pd.DataFrame()

dfSigUFFiltrado.info()

dfCandidatos = pd.read_csv(arquivoCSV
                            , sep=';'
                            ,encoding='latin-1'
                            , usecols=[2,4,5,7,8,10,14,15,18,27,28,43,48,50]
                            ,names=['NumAnoEleicao'
                                    ,'NomTpoEleicao'
                                    ,'NumTurno'
                                    ,'DescEleicao'
                                    ,'DtEleicao'
                                    ,'SigUF'
                                    ,'DescCargo'
                                    ,'SeqCandidato'
                                    ,'NomCandidatoUrna'
                                    ,'NumPartido'
                                    ,'SigParido'
                                    ,'NumIdadePosse'
                                    ,'DescInstrucao'
                                    ,'DescEstadoCivil']
                            ,dtype={'NumAnoEleicao':'long'
                                    ,'NomTpoEleicao':'str'
                                    ,'NumTurno':'long'
                                    ,'DescEleicao':'str'
                                    ,'DtEleicao':'str'
                                    ,'SigUF':'str'
                                    ,'DescCargo':'str'
                                    ,'SeqCandidato':'str'
                                    ,'NomCandidatoUrna':'str'
                                    ,'NumPartido':'long'
                                    ,'SigParido':'str'
                                    ,'NumIdadePosse':'str'
                                    ,'DescInstrucao':'str'
                                    ,'DescEstadoCivil':'str'}
                            ,parse_dates=[4]
                            ,header=0)


dfCandidatos.groupby(['SigUF']).agg(Qtd=('SigUF','count'))

dfSigUFFiltrado = pd.DataFrame(dfCandidatos['SigUF'])

dfSigUFFiltrado = dfSigUFFiltrado.drop_duplicates(['SigUF'] , keep='first').reset_index(drop = True)

dfSigUFFiltrado
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Empty DataFrame
#    SigUF
# 0     PR
# 1     MS
# 2     GO
# 3     RN
# 4     SP
# 5     AL
# 6     PI
# 7     MT
# 8     RO
# 9     SC
# 10    PE
# 11    RS
# 12    ES
# 13    AM
# 14    MG
# 15    RJ
# 16    PA
# 17    DF
# 18    TO
# 19    PB
# 20    CE
# 21    MA
# 22    BA
# 23    SE
# 24    AC
# 25    RR
# 26    AP
# 27    BR

# %% [markdown]
# # 20 - Relacionando DataFrames

# %%
# RELACIONANDO DOIS DATAFRAMES #

resultCandidatoBem = pd.merge(left=dfCandidatos
                              , right=dfBemCandidato
                              , left_on='SeqCandidato'
                              , right_on='SeqCandidato'                                                                                              
                                    )[['SeqCandidato'
                                       , 'NomCandidatoUrna'
                                       , 'DescCargo'
                                       , 'SigUF_y'
                                       , 'DescTpoBem'
                                       , 'VlrBem']]

resultCandidatoBem
# Out:
#       SeqCandidato             NomCandidatoUrna          DescCargo SigUF_y  \
# 0      90001675157             CYNTHIA OLIVEIRA   DEPUTADO FEDERAL      GO
# 1      40001671799            CIMARA CAVALCANTE   DEPUTADO FEDERAL      AM
# 2      90001652975  MAURICIO COMUNICATIVO LESTE  DEPUTADO ESTADUAL      GO
# 3      80001648791       PROFESSOR GEDAYAS DAYA  DEPUTADO ESTADUAL      ES
# 4      60001619178                   JOÃO JAIME  DEPUTADO ESTADUAL      CE
# ...            ...                          ...                ...     ...
# 20347  80001719429               HELDER SALOMÃO   DEPUTADO FEDERAL      ES
# 20348  80001719429               HELDER SALOMÃO   DEPUTADO FEDERAL      ES
# 20349  80001719429               HELDER SALOMÃO   DEPUTADO FEDERAL      ES
# 20350  80001719429               HELDER SALOMÃO   DEPUTADO FEDERAL      ES
# 20351  80001719429               HELDER SALOMÃO   DEPUTADO FEDERAL      ES
#
#                                               DescTpoBem     VlrBem
# 0      Veículo automotor terrestre: caminhão, automóv...    1000.00
# 1                   Dinheiro em espécie - moeda nacional    3000.00
# 2      Veículo automotor terrestre: caminhão, automóv...   15000.00
# 3                                                   Casa   78000.00
# 4      Fundos: Ações, Mútuos de Privatização, Invest....    9140.29
# ...                                                  ...        ...
# 20347  Veículo automotor terrestre: caminhão, automóv...   50364.48
# 20348             VGBL - Vida Gerador de Benefício Livre    7171.68
# 20349                                   Sala ou conjunto  138547.87
# 20350                                        Apartamento   26000.00
# 20351        Depósito bancário em conta corrente no País    1812.63
#
# [20352 rows x 6 columns]

# %% [markdown]
# # 21 - Comando Similar ao Case When do SQL Server

# %%
# APLICANDO O COMANDO CASE DO SQL SERVER #

arquivoCSV = '..\ProjetoPythonKB\Dados\Candidato\consulta_cand_2022_BRASIL.csv'

dfSigUFFiltrado = pd.DataFrame()

dfSigUFFiltrado.info()

dfCandidatos = pd.read_csv(arquivoCSV
                            , sep=';'
                            ,encoding='latin-1'
                            , usecols=[2,4,5,7,8,10,14,15,18,27,28,43,48,50]
                            ,names=['NumAnoEleicao'
                                    ,'NomTpoEleicao'
                                    ,'NumTurno'
                                    ,'DescEleicao'
                                    ,'DtEleicao'
                                    ,'SigUF'
                                    ,'DescCargo'
                                    ,'SeqCandidato'
                                    ,'NomCandidatoUrna'
                                    ,'NumPartido'
                                    ,'SigParido'
                                    ,'NumIdadePosse'
                                    ,'DescInstrucao'
                                    ,'DescEstadoCivil']
                            ,dtype={'NumAnoEleicao':'long'
                                    ,'NomTpoEleicao':'str'
                                    ,'NumTurno':'long'
                                    ,'DescEleicao':'str'
                                    ,'DtEleicao':'str'
                                    ,'SigUF':'str'
                                    ,'DescCargo':'str'
                                    ,'SeqCandidato':'str'
                                    ,'NomCandidatoUrna':'str'
                                    ,'NumPartido':'long'
                                    ,'SigParido':'str'
                                    ,'NumIdadePosse':'str'
                                    ,'DescInstrucao':'str'
                                    ,'DescEstadoCivil':'str'}
                            ,parse_dates=[4]
                            ,header=0)


dfCandidatos.groupby(['SigUF']).agg(Qtd=('SigUF','count'))

dfSigUFFiltrado = pd.DataFrame(dfCandidatos['SigUF'])

dfSigUFFiltrado = dfSigUFFiltrado.drop_duplicates(['SigUF'] , keep='first').reset_index(drop = True)

dfSigUFFiltrado.loc[dfSigUFFiltrado['SigUF'].isin(['AC','AP','AM','PA','TO','RR','RO']), 'NomRegiaoBrasil'] = 'Região Norte'

dfSigUFFiltrado.loc[dfSigUFFiltrado['SigUF'].isin(['AL','BA','CE','MA','PB','PE','PI','RN','SE']), 'NomRegiaoBrasil'] = 'Região Nordeste'

dfSigUFFiltrado.loc[dfSigUFFiltrado['SigUF'].isin(['GO','MS','MT','DF']), 'NomRegiaoBrasil'] = 'Região Centro-Oeste'

dfSigUFFiltrado.loc[dfSigUFFiltrado['SigUF'].isin(['ES','MG','RJ','SP']), 'NomRegiaoBrasil'] = 'Região Sudeste'

dfSigUFFiltrado.loc[dfSigUFFiltrado['SigUF'].isin(['PR','SC','RS']), 'NomRegiaoBrasil'] = 'Região Sul'

dfSigUFFiltrado.loc[dfSigUFFiltrado['SigUF'].isin(['BR']), 'NomRegiaoBrasil'] = 'Brasil'

dfSigUFFiltrado.sort_values(by=(['NomRegiaoBrasil','SigUF']),inplace=True,ignore_index=True)

dfSigUFFiltrado
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Empty DataFrame
#    SigUF      NomRegiaoBrasil
# 0     BR               Brasil
# 1     DF  Região Centro-Oeste
# 2     GO  Região Centro-Oeste
# 3     MS  Região Centro-Oeste
# 4     MT  Região Centro-Oeste
# 5     AL      Região Nordeste
# 6     BA      Região Nordeste
# 7     CE      Região Nordeste
# 8     MA      Região Nordeste
# 9     PB      Região Nordeste
# 10    PE      Região Nordeste
# 11    PI      Região Nordeste
# 12    RN      Região Nordeste
# 13    SE      Região Nordeste
# 14    AC         Região Norte
# 15    AM         Região Norte
# 16    AP         Região Norte
# 17    PA         Região Norte
# 18    RO         Região Norte
# 19    RR         Região Norte
# 20    TO         Região Norte
# 21    ES       Região Sudeste
# 22    MG       Região Sudeste
# 23    RJ       Região Sudeste
# 24    SP       Região Sudeste
# 25    PR           Região Sul
# 26    RS           Região Sul
# 27    SC           Região Sul

# %% [markdown]
# # 22 - Importando Grandes Arquivos (chunksize)

# %% [markdown]
# # 23 - Importandos Vários Arquivos (For e Biblioteca OS)

# %%
import os

diretorioCSV = '..\ProjetoPythonKB\Dados\Candidato'

dfCandidato = pd.DataFrame()

for arquivoCSV in os.listdir(diretorioCSV):

    diretorioArquivoCSV = diretorioCSV + '\\' + arquivoCSV

    print(diretorioArquivoCSV)
    
    df = pd.read_csv(diretorioArquivoCSV
                    , sep=';'
                    , encoding='latin-1')
    
    df['ArquivoImportado'] = arquivoCSV
    
    dfCandidato = dfCandidato.append(df)
    
dfCandidato.groupby(['ArquivoImportado']).agg(Qtd=('ArquivoImportado','count'))
# Out:
# ..\ProjetoPythonKB\Dados\Candidato\consulta_cand_2014_BRASIL.csv
# C:\Users\lacer\AppData\Local\Temp\ipykernel_25092\1212904864.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfCandidato = dfCandidato.append(df)
# ..\ProjetoPythonKB\Dados\Candidato\consulta_cand_2018_BRASIL.csv
# C:\Users\lacer\AppData\Local\Temp\ipykernel_25092\1212904864.py:13: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(diretorioArquivoCSV
# C:\Users\lacer\AppData\Local\Temp\ipykernel_25092\1212904864.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfCandidato = dfCandidato.append(df)
# ..\ProjetoPythonKB\Dados\Candidato\consulta_cand_2022_BRASIL.csv
# C:\Users\lacer\AppData\Local\Temp\ipykernel_25092\1212904864.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfCandidato = dfCandidato.append(df)
#                                  Qtd
# ArquivoImportado
# consulta_cand_2014_BRASIL.csv  26271
# consulta_cand_2018_BRASIL.csv  29180
# consulta_cand_2022_BRASIL.csv  29262

# %% [markdown]
# # 24 - Compactar (Zipar) um arquivo

# %%
import os
import zipfile

arquivoZip = 'arquivo.zip'
diretorio = '..\ProjetoPythonKB\Dados\Candidato'

zf = zipfile.ZipFile(arquivoZip, "w")

for dirname, subdirs, files in os.walk(diretorio):
    zf.write(dirname)

    for filename in files:
        zf.write(os.path.join(dirname, filename))

zf.close()

# %%
import shutil

arquivoZip = 'arquivo2'
diretorio = '..\ProjetoPythonKB\Dados\Candidato'

shutil.make_archive(arquivoZip, 'zip', diretorio)
# Out:
# 'C:\\Temp\\ProjetoPythonKB\\arquivo2.zip'

# %% [markdown]
# # 25 - Descompactar (Zipar) um arquivo

# %%
from zipfile import ZipFile

diretorio = '..\\ProjetoPythonKB\\arquivo2.zip'

with ZipFile(diretorio, 'r') as zipObj:
   
   zipObj.extractall()

# %%
from zipfile import ZipFile

diretorioRaiz = '..\\ProjetoPythonKB\\arquivo2.zip'
diretorioUnZip = '..\\ProjetoPythonKB\\unzip' ## CASO NÃO EXISTE O DIRETÓRIO SERÁ CRIADO

with ZipFile(diretorio, 'r') as zipObj:
   
   zipObj.extractall(diretorioUnZip)

# %% [markdown]
# # 26 - Métodos de Importação Planilha do Excel

# %% [markdown]
# ## 26.1 - Importando Planilha do Excel de forma FULL

# %%
arquivoXLSX = '..\ProjetoPythonKB\Dados\IndicadorSegurancaPublica\indicadoressegurancapublicauf.xlsx'


dfIndicadorSegurancaPublica = pd.read_excel(arquivoXLSX
                                           ,sheet_name='Vítimas')


dfIndicadorSegurancaPublica
# Out:
#               UF                           Tipo Crime   Ano        Mês  \
# 0           Acre                     Homicídio doloso  2022    janeiro
# 1           Acre                     Homicídio doloso  2022    janeiro
# 2           Acre                     Homicídio doloso  2022    janeiro
# 3           Acre                     Homicídio doloso  2022  fevereiro
# 4           Acre                     Homicídio doloso  2022  fevereiro
# ...          ...                                  ...   ...        ...
# 18535  Tocantins  Roubo seguido de morte (latrocínio)  2015      junho
# 18536  Tocantins  Roubo seguido de morte (latrocínio)  2015      julho
# 18537  Tocantins  Roubo seguido de morte (latrocínio)  2015     agosto
# 18538  Tocantins  Roubo seguido de morte (latrocínio)  2015    outubro
# 18539  Tocantins  Roubo seguido de morte (latrocínio)  2015   dezembro
#
#       Sexo da Vítima  Vítimas
# 0           Feminino        2
# 1          Masculino        8
# 2            Sexo NI        0
# 3           Feminino        0
# 4          Masculino       10
# ...              ...      ...
# 18535      Masculino        1
# 18536      Masculino        1
# 18537      Masculino        1
# 18538      Masculino        2
# 18539      Masculino        2
#
# [18540 rows x 6 columns]

# %% [markdown]
# ## 26.2 - Importando Planilha do Excel Definindo Colunas e Datatypes

# %%
# IMPORTAÇÃO SIMPLES DE PLANILHA EXCEL #

arquivoXLSX = '..\ProjetoPythonKB\Dados\IndicadorSegurancaPublica\indicadoressegurancapublicauf.xlsx'


dfIndicadorSegurancaPublica = pd.read_excel(arquivoXLSX
                                           ,sheet_name='Vítimas'
                                            , usecols=[0,1,2,3,4,5]
                      , names=['CodUf'
                               , 'TpoCrime'
                               , 'NumAno'
                               , 'NumMes'
                               , 'CodSexo'
                               , 'NumVitima']
                      , dtype={'CodUf':'str'
                               , 'TpoCrime':'str'
                               , 'NumAno':'int'
                               , 'NumMes':'str'
                               , 'CodSexo':'str'
                               , 'NumVitima':'int'}
                      ,header=0)


dfIndicadorSegurancaPublica
# Out:
#            CodUf                             TpoCrime  NumAno     NumMes  \
# 0           Acre                     Homicídio doloso    2022    janeiro
# 1           Acre                     Homicídio doloso    2022    janeiro
# 2           Acre                     Homicídio doloso    2022    janeiro
# 3           Acre                     Homicídio doloso    2022  fevereiro
# 4           Acre                     Homicídio doloso    2022  fevereiro
# ...          ...                                  ...     ...        ...
# 18535  Tocantins  Roubo seguido de morte (latrocínio)    2015      junho
# 18536  Tocantins  Roubo seguido de morte (latrocínio)    2015      julho
# 18537  Tocantins  Roubo seguido de morte (latrocínio)    2015     agosto
# 18538  Tocantins  Roubo seguido de morte (latrocínio)    2015    outubro
# 18539  Tocantins  Roubo seguido de morte (latrocínio)    2015   dezembro
#
#          CodSexo  NumVitima
# 0       Feminino          2
# 1      Masculino          8
# 2        Sexo NI          0
# 3       Feminino          0
# 4      Masculino         10
# ...          ...        ...
# 18535  Masculino          1
# 18536  Masculino          1
# 18537  Masculino          1
# 18538  Masculino          2
# 18539  Masculino          2
#
# [18540 rows x 6 columns]

# %% [markdown]
# # 26.3 - Criar uma Função padrão para Importar uma Planilha no Excel

# %% [markdown]
# # 27 - Criar e Excluir Diretório

# %%
def fn_cria_diretorio(diretorio):
    
    vDiretorio = Path(diretorio)    
    dataInicio = datetime.now()    
    vAno = dataInicio.strftime('%Y')
    vMes = dataInicio.strftime('%m')
    vDia = dataInicio.strftime('%d')
    
    datafinal = vAno+vMes+vDia 

    # Verifica se o diretório existe
    if not os.path.isdir(vDiretorio/vAno):
        
        dir1 = vDiretorio / vAno / vMes        
        # Criando o primeiro diretório (Ano)
        os.mkdir(vDiretorio / vAno)
        # Criando o sub diretório (Mes)
        os.mkdir(vDiretorio / vAno / vMes)

# %% [markdown]
# # 28 - Listar o Último Arquivo em um Diretório

# %% [markdown]
# # 29 - Conectar e Extrair Dados do Microsof SQL Server

# %%
import pyodbc
import pandas as pd

server = 'localhost\DBAASSISTS' 
database = 'COPA' 
username = 'python' 
password = 'python'  
cnxn = pyodbc.connect('DRIVER={SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = cnxn.cursor()

query = "SELECT * FROM SUA_TABELA"
df = pd.read_sql(query, cnxn)
df.head(26)

# %%
## INCLUIR UM EXEMPLO FAZENDO A EXTRAÇÃO DE DADOS DA COPA USANDO JSON PARAMETRIZADO

# %% [markdown]
# # 30 - Conectar e Extrair Dados do Oracle

# %% [markdown]
# # 31 - Conectar e Extrair Dados do PostGreSQL

# %%
import psycopg2

ip_servidor = 'IP SERVIDOR OU NOME SERVIDOR'
porta = 'PORTA BANCO'
banco = 'BANDO DE DADOS'
usuario = 'USUARIO'
senha = 'SENHA'

enginepostgre = psycopg2.connect(host=ip_servidor,database=banco,user=usuario,password=senha)

con = psycopg2.connect(host=ip_servidor , database=banco ,user=usuario , password=senha )

cur = con.cursor()

cur.execute('SELECT * FROM SUA_TABELA')

recset = cur.fetchall()
for rec in recset:
    print (rec)

con.close()

# %% [markdown]
# # 32 - Conectar e Extrair Dados do MySQL

# %%
import warnings
import pandas as pd
import sqlalchemy
import pymysql
from pandas.core.common import SettingWithCopyWarning
import numpy as np
import json

pd.options.display.max_rows = 999
pd.options.display.max_columns=999
pd.options
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

usuario = 'SEU USUARIO'
senha = 'SUA SENHA'
ip_servidor = 'IP DO SERVIDOR'
porta = 'PORTA DO BANCO'
banco = 'BANCO DE DADOS'

enginemysql = sqlalchemy.create_engine(f'mysql+pymysql://{usuario}:{senha}@{ip_servidor}:{porta}/{banco}')

df = pd.read_sql_table('TABELA',enginemysql)

df.head(3)

# %% [markdown]
# # 33 - Conectar e Extrair Dados do Salesforce

# %%
import os
import datetime
import pandas as pd
from simple_salesforce import Salesforce, SalesforceLogin, SFType
from datetime import datetime
from pathlib import Path
from os.path import getmtime
from os import scandir

# Instalação Biblioteca 
#pip install simple_salesforce

# CONEXÃO COM O SALESFORCE

sf = Salesforce(
username = 'SEU_USUARIO', 
password = 'SUA_SENHA', 
security_token= 'SEU_TOKEN',
domain= 'SEU_DOMINIO')

# FUNÇÃO QUE CRIA DIRETÓRIO

def fn_cria_diretorio(diretorio):
    
    vDiretorio = Path(diretorio)    
    dataInicio = datetime.now()    
    vAno = dataInicio.strftime('%Y')
    vMes = dataInicio.strftime('%m')
    vDia = dataInicio.strftime('%d')
    
    datafinal = vAno+vMes+vDia 

    # Verifica se o diretório existe
    if not os.path.isdir(vDiretorio/vAno):
        
        dir1 = vDiretorio / vAno / vMes        
        # Criando o primeiro diretório (Ano)
        os.mkdir(vDiretorio / vAno)
        # Criando o sub diretório (Mes)
        os.mkdir(vDiretorio / vAno / vMes)

        

# FUNÇÃO QUE EXTRAI OS DADOS DO SALESFORCE

def fn_extrai_dados_salesforce(query,arquivo,diretorio):
    
    dataInicio = datetime.now()
    vAno = dataInicio.strftime('%Y')
    vMes = dataInicio.strftime('%m')
    vDia = dataInicio.strftime('%d') 

    fn_cria_diretorio(diretorio)
    
    diretorio = diretorio + vAno +'\\' + vMes + '\\' + arquivo + '_' + vAno+vMes+vDia + '.csv'
    
    sf_dataExtracaoDadosSalesforce = sf.query_all(query)
  
    sf_dataExtracaoDadosSalesforce = pd.DataFrame(sf_dataExtracaoDadosSalesforce['records']) \
                                                    .drop(columns='attributes')

    sf_dataExtracaoDadosSalesforce.to_csv(diretorio , sep=';', index=False)

query = """SELECT Id FROM Account limit 100"""
arquivo = 'ACCOUNT'
diretorio = 'C:\\Temp\\Salesforce\\'

fn_extrai_dados_salesforce(query,arquivo,diretorio)

# %% [markdown]
# # 34 - Comando Similar ao LIKE do SQL Server

# %%
# IMPORTAÇÃO SIMPLES DE PLANILHA EXCEL #

arquivoXLSX = '..\ProjetoPythonKB\Dados\IndicadorSegurancaPublica\indicadoressegurancapublicauf.xlsx'


dfIndicadorSegurancaPublica = pd.read_excel(arquivoXLSX
                                           ,sheet_name='Vítimas'
                                            , usecols=[0,1,2,3,4,5]
                      , names=['CodUf'
                               , 'TpoCrime'
                               , 'NumAno'
                               , 'NumMes'
                               , 'CodSexo'
                               , 'NumVitima']
                      , dtype={'CodUf':'str'
                               , 'TpoCrime':'str'
                               , 'NumAno':'int'
                               , 'NumMes':'str'
                               , 'CodSexo':'str'
                               , 'NumVitima':'int'}
                      ,header=0)


dfIndicadorSegurancaPublica[dfIndicadorSegurancaPublica['TpoCrime'].str.contains('doloso',na=False)]
# Out:
#            CodUf          TpoCrime  NumAno     NumMes    CodSexo  NumVitima
# 0           Acre  Homicídio doloso    2022    janeiro   Feminino          2
# 1           Acre  Homicídio doloso    2022    janeiro  Masculino          8
# 2           Acre  Homicídio doloso    2022    janeiro    Sexo NI          0
# 3           Acre  Homicídio doloso    2022  fevereiro   Feminino          0
# 4           Acre  Homicídio doloso    2022  fevereiro  Masculino         10
# ...          ...               ...     ...        ...        ...        ...
# 18522  Tocantins  Homicídio doloso    2015    outubro  Masculino         33
# 18523  Tocantins  Homicídio doloso    2015   novembro   Feminino          3
# 18524  Tocantins  Homicídio doloso    2015   novembro  Masculino         35
# 18525  Tocantins  Homicídio doloso    2015   dezembro   Feminino          3
# 18526  Tocantins  Homicídio doloso    2015   dezembro  Masculino         49
#
# [6788 rows x 6 columns]

# %% [markdown]
# # 35 - Comando Similar ao SUBSTRING do SQL Server

# %%
# IMPORTAÇÃO SIMPLES DE PLANILHA EXCEL #

arquivoXLSX = '..\ProjetoPythonKB\Dados\IndicadorSegurancaPublica\indicadoressegurancapublicauf.xlsx'


dfIndicadorSegurancaPublica = pd.read_excel(arquivoXLSX
                                           ,sheet_name='Vítimas'
                                            , usecols=[0,1,2,3,4,5]
                      , names=['CodUf'
                               , 'TpoCrime'
                               , 'NumAno'
                               , 'NumMes'
                               , 'CodSexo'
                               , 'NumVitima']
                      , dtype={'CodUf':'str'
                               , 'TpoCrime':'str'
                               , 'NumAno':'int'
                               , 'NumMes':'str'
                               , 'CodSexo':'str'
                               , 'NumVitima':'int'}
                      ,header=0)


dfIndicadorSegurancaPublicaHOMICIDIO = dfIndicadorSegurancaPublica[dfIndicadorSegurancaPublica['TpoCrime'].str.contains('Homicídio',na=False)][['CodUf','TpoCrime','NumVitima']]

dfIndicadorSegurancaPublicaHOMICIDIO['TpoHomocidio'] = dfIndicadorSegurancaPublicaHOMICIDIO['TpoCrime'].str[10:20]

dfIndicadorSegurancaPublicaHOMICIDIO['TpoHomocidio'].unique()
# Out:
# array(['doloso'], dtype=object)

# %% [markdown]
# # 36 - Gerando Arquivo CSV a partir de um DataFrame

# %%
# IMPORTAÇÃO SIMPLES DE PLANILHA EXCEL #

arquivoXLSX = '..\ProjetoPythonKB\Dados\IndicadorSegurancaPublica\indicadoressegurancapublicauf.xlsx'


dfIndicadorSegurancaPublica = pd.read_excel(arquivoXLSX
                                           ,sheet_name='Vítimas'
                                            , usecols=[0,1,2,3,4,5]
                      , names=['CodUf'
                               , 'TpoCrime'
                               , 'NumAno'
                               , 'NumMes'
                               , 'CodSexo'
                               , 'NumVitima']
                      , dtype={'CodUf':'str'
                               , 'TpoCrime':'str'
                               , 'NumAno':'int'
                               , 'NumMes':'str'
                               , 'CodSexo':'str'
                               , 'NumVitima':'int'}
                      ,header=0)


dfIndicadorSegurancaPublicaHOMICIDIO = dfIndicadorSegurancaPublica[dfIndicadorSegurancaPublica['TpoCrime'].str.contains('Homicídio',na=False)][['CodUf','TpoCrime','NumVitima']]

dfIndicadorSegurancaPublicaHOMICIDIO.groupby(['CodUf'
                                              ,'TpoCrime'],as_index=False).agg(Qtd=('NumVitima'
                                                                                    ,'sum')).sort_values(by='Qtd') \
                                                                                    .to_csv('..\ProjetoPythonKB\Dados\IndicadorSegurancaPublica\indicador_homocidio.csv'
                                                                                     ,sep=';'
                                                                                     ,index=False
                                                                                     ,encoding='latin-1')

# %% [markdown]
# # 37 - Download de Arquivo de uma URL

# %% [markdown]
# # 38 - Colocando a primeira letra como Maiuscula

# %%
v = 'gabriel frederico lacerda quintella'

v.title()
# Out:
# 'Gabriel Frederico Lacerda Quintella'

# %% [markdown]
# # 39 - Verificando de a variável é Alfanuméria

# %%
v = 'gabriel frederico lacerda quintella'

v.isalpha()
# Out:
# True

# %% [markdown]
# # 40 - Verificando de a variável é Numerica

# %%
v = 'gabriel frederico lacerda quintella'

v.isnumeric()
# Out:
# False

# %%
v = '12345'

v.isnumeric()
# Out:
# True

# %% [markdown]
# # 41 - Verificando de a variável está toda em caixa alta (Maiuscula)

# %%
v = 'gabriel frederico lacerda quintella'

v.isupper()
# Out:
# False

# %%
v = 'GABRIEL'

v.isupper()
# Out:
# True

# %% [markdown]
# # 42 - Removendo espaços

# %%
v = "gabriel frederico lacerda quintella"

v.stip()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [70], in <cell line: 3>()
#       1 v = "gabriel frederico lacerda quintella"
# ----> 3 v.stip()
#
# AttributeError: 'str' object has no attribute 'stip'
