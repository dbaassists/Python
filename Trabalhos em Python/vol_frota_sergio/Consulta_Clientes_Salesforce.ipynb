# %%
import json
import datetime
import pandas as pd
from simple_salesforce import Salesforce, SalesforceLogin, SFType

# %% [markdown]
# #pip install simple_salesforce

# %% [markdown]
# AMBIENTE DE PRODUÇÃO

# %%
username='etlshv@supergasbras.com.br', 
password='Super2020', 
security_token='2yY5vNvSMICU35NLeEjGAqtSJ'

# %%
#loginInfo = json.load(open('login.json'))
username = username #loginInfo['username']
password = password #loginInfo['password']
security_token = security_token #loginInfo['security_token']
domain = 'login'

# %%
session_id, instance = SalesforceLogin(username='etlshv@supergasbras.com.br', password='Super2020', security_token='2yY5vNvSMICU35NLeEjGAqtSJ', domain=domain)
sf = Salesforce(instance=instance, session_id=session_id)

# %% [markdown]
# AMBIENTE DE UAT

# %%
username='etlshv@supergasbras.com.br.uat', 
password='ETLS@&UAT@21', 
security_token='92MFvc9OAkhLZ1WRl2V2OwJJ'

# %%
#loginInfo = json.load(open('login.json'))
username = username #loginInfo['username']
password = password #loginInfo['password']
security_token = security_token #loginInfo['security_token']
domain = 'test'

# %%
session_id, instance = SalesforceLogin(username='etlshv@supergasbras.com.br.uat', password='ETLS@&UAT@21', security_token='92MFvc9OAkhLZ1WRl2V2OwJJ', domain=domain)
sf = Salesforce(instance=instance, session_id=session_id)

# %%
sf = Salesforce(
username = 'etlshv@supergasbras.com.br.uat', 
password = 'ETLS@&UAT@21',
security_token= '92MFvc9OAkhLZ1WRl2V2OwJJ',
domain= 'test')

# %%
queryConta = f"""SELECT 
Id
,Id_ODS__c
,Canal_de_Distribuicao__c
,Conta__c
FROM Area_de_Vendas__c
WHERE Conta__c = '001F000001qCgY9IAK'"""
sf_dataConta = sf.query_all(queryConta)

# %%
queryConta = f"""SELECT 
Id
,Id_ODS__c
,Canal_de_Distribuicao__c
,Conta__c
FROM Area_de_Vendas__c
WHERE Conta__c = '001F000001qCgY9IAK'"""
sf_dataConta = sf.query_all(queryConta)

sf_dfConta = pd.DataFrame(sf_dataConta['records']).drop(columns='attributes')
sf_dfConta

# %%
sf_dfConta = pd.DataFrame(sf_dataConta['records']).drop(columns='attributes')
sf_dfConta

# %%
queryConta = f""" SELECT 
Id
,Codigo_do_Cliente_SAP__c
,Name
,UFCapex__c
,Estabelecimento_Unidade_de_Negocio_SHV__c 
,Grupo_de_Contas2__c
,Grupo_de_Contas__c
,ownerid
,CodigoClienteSAPRecebedor_DFV__c
FROM Account
where Codigo_do_Cliente_SAP__c in ('0000996371',
'0001959482',
'0003924725',
'0003933725',
'0003735413',
'0003908847',
'0003721858',
'0003775920',
'0003933496',
'0003857600',
'0003928641',
'0003913457',
'0003922916',
'0003927816',
'0003917204',
'0003901676',
'0003797915',
'0000075760',
'0001061173',
'0001206105',
'0000075710',
'0001085274',
'0001072001',
'0001963727',
'0003637036',
'0002672489',
'0003490451',
'0003596816',
'0003629027',
'0003650979',
'0003643011',
'0003683570',
'0003649268',
'0003737673',
'0003801524',
'0003916735',
'0003918848',
'0001293204',
'0003901735',
'0003925149',
'0003948298',
'0003911350',
'0003917795',
'0003925532',
'0003934408',
'0003920246',
'0003953326',
'0003917874',
'0003951770'
)
"""
sf_dataConta = sf.query_all(queryConta)

# %%
sf_dfConta = pd.DataFrame(sf_dataConta['records']).drop(columns='attributes')
sf_dfConta.sort_values(by='OwnerId')
#sf_dfConta.to_csv('base_cliente_sfe_luan.csv',sep=';',index=False)
# Out:
#                     Id Codigo_do_Cliente_SAP__c  \
# 0   001F000000g9a5zIAA               0000075710
# 35  0014z00001iJw1dAAC               0003918848
# 31  0014z00001iJjXcAAK               0003916735
# 27  001A000000d7JvPIAU               0003901735
# 21  0011Y00002s23BbQAI               0003737673
# 18  0011Y00002kpYicQAE               0003683570
# 17  0012A00002NJuAzQAL               0003650979
# 16  0012A00002NJ5s8QAD               0003649268
# 15  0012A00002MasFpQAJ               0003643011
# 14  0012A00002LZ9eqQAD               0003637036
# 13  0012A00002JOly1QAD               0003629027
# 12  0012A00002E27pIQAR               0003596816
# 24  0011Y00003CvMeCQAV               0003801524
# 10  001F000001otEqaIAE               0002672489
# 9   001F000001H2zt1IAB               0001963727
# 7   001F000001GLNQrIAP               0001293204
# 6   001F000000p6qlrIAA               0001206105
# 5   001A000000d7AHdIAM               0001085274
# 4   001A000000d7LOtIAM               0001072001
# 1   001A000000d7kC1IAI               0000075760
# 3   001A000000d7bScIAI               0001061173
# 11  001F000001rDtdwIAC               0003490451
# 46  0014z00001kHFqqAAG               0003948298
# 45  0014z00001iJ0oMAAS               0003934408
# 40  0014z00001iLsA6AAK               0003925532
# 39  0014z00001iLl4WAAS               0003925149
# 36  0014z00001iKpVLAA0               0003920246
# 34  0014z00001iKBlBAAW               0003917874
# 33  0014z00001iKNEPAA4               0003917795
# 48  0014z00001kKdMWAA0               0003953326
# 47  0014z00001kKLLsAAO               0003951770
# 29  0014z00001hYhe5AAC               0003911350
# 23  0011Y000031mjiGQAQ               0003797915
# 32  0014z00001iKCyxAAG               0003917204
# 26  0014z00001hWWk5AAG               0003901676
# 37  0014z00001iLJTnAAO               0003922916
# 41  0014z00001iMSkgAAG               0003927816
# 28  0014z00001hXsACAA0               0003908847
# 8   001F000001h8GvtIAE               0001959482
# 19  0011Y00002u9OPCQA2               0003721858
# 44  0014z00001jT86MAAS               0003933725
# 43  0014z00001jT87AAAS               0003933496
# 22  0011Y000037BSpFQAW               0003775920
# 20  0011Y00002uriPEQAY               0003735413
# 38  0014z00001iJ4k2AAC               0003924725
# 25  0014z00001eDRZCAA4               0003857600
# 2   001A000000d7ge3IAA               0000996371
# 42  0014z00001iMkBKAA0               0003928641
# 30  0014z00001hYEPsAAO               0003913457
#
#                                    Name UFCapex__c  \
# 0   BOA HORA C DE TRAT DE RESIDUOS LTDA         SP
# 35              IVAN FERNANDES DO PRADO         SP
# 31       ALM PADARIA E CONFEITARIA LTDA         SP
# 27             SUPERMERCADO NEVADA LTDA         SP
# 21           ARGOS INDUSTRIAL EIRELI ME         SP
# 18   RESTAURANTE LANC CAMPO JORDAO LTDA         SP
# 17                      INDEPENDENTE FC         SP
# 16      GIPI COMERCIO DE ALIMENTOS LTDA         SP
# 15            EDNEI ROGERIO RECEDIVE ME         SP
# 14  FORTALEZA ANODIZACAO E PINTURA LTDA         SP
# 13  UDLOG ARMAZENS GERAIS TRANS E LOGIS         SP
# 12    CORES E BRILHO LAVANDERIA LTDA ME         SP
# 24                          LUANA BANIN         SP
# 10     VALDECI J FREIRE PAES E DOCES ME         SP
# 9    ROSANA BERNARDES DA SILVA PIZZARIA         SP
# 7                    RESERVA BELO VERDE         SP
# 6   INDUSTRIA E COMERCIO DE PECAS MRS L         SP
# 5                  TRAMA MOTEL LTDA EPP         SP
# 4         HB CHINA RESTAURANTE LTDA EPP         SP
# 1   J D LANCH PIZZARIA E RESTAURANTE LT         SP
# 3   CGE SOCIED FABRICADORA DE PCS PLAST         SP
# 11            OURO VERDE CHEMICALS LTDA         SP
# 46   ADAILTON P DA TRINDADE 01955318506         SP
# 45  JANDERSON LEANDRO ALENCAR SANTOS 45         SP
# 40  HOSPITAL VETERINARIO ANIMANIAC S LT         SP
# 39                 PIZZARIA MATIAS LTDA         SP
# 36  RESTAURANTE PIZ NOVA FATILITTE LTDA         SP
# 34               ANDRE FELIPE TERRACUSO         SP
# 33              KARINA RIBEIRO CUSTODIO         SP
# 48              FLV 7 RESTAURANTES LTDA         SP
# 47  ERMANO BENEDITO DOS SANTOS FILHO 12         SP
# 29        LA TOSCANELLI PIZZARIA EIRELI         SP
# 23        ION INDUSTRIA E COMERCIO LTDA         SP
# 32  POINT DOS REBOQUES E ACESSORIOS EIR         SP
# 26               PORKS PG BREW PUB LTDA         SP
# 37                   JFBM PIZZARIA LTDA         SP
# 41  VINICIUS DA SILVA PEREIRA 518825508         SP
# 28                DSM HAMBURGUERIA LTDA         SP
# 8           SUPERMERCADO ROSSI NEW LTDA         SP
# 19  EXPRESSO T PERFIS E ACES ALUMINIO E         SP
# 44            LOVE TABOAO PIZZARIA LTDA         SP
# 43  PIZZARIA IMPERIO PARQUE MARABA LTDA         SP
# 22   PANIFICADORA RAINHA DO TABOAO LTDA         SP
# 20                    TLC LAVANDERIA SA         SP
# 38     MADIA COMERCIO DE REFEICOES LTDA         SP
# 25     MADIA COMERCIO DE REFEICOES LTDA         SP
# 2   BUFALO IND E COM DE PROD QUIMICOS L         SP
# 42  R. C. DOS SANTOS COMERCIO DE REFEIC         SP
# 30     MADIA COMERCIO DE REFEICOES LTDA         SP
#
#    Estabelecimento_Unidade_de_Negocio_SHV__c Grupo_de_Contas2__c  \
# 0                         a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 35                        a0BA000000Bkul4MAB  a17F000000R17A2IAJ
# 31                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 27                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 21                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 18                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 17                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 16                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 15                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 14                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 13                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 12                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 24                        a0BA000000Bkul4MAB  a17F000000R17A2IAJ
# 10                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 9                         a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 7                         a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 6                         a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 5                         a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 4                         a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 1                         a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 3                         a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 11                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 46                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 45                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 40                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 39                        a0BA000000BkukoMAB  a17F000000R17A3IAJ
# 36                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 34                        a0BA000000Bkul4MAB  a17F000000R17A2IAJ
# 33                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 48                        a0BA000000BkukoMAB  a17F000000R17A3IAJ
# 47                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 29                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 23                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 32                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 26                        a0BA000000BkulCMAR  a17F000000R17A3IAJ
# 37                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 41                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 28                        a0BA000000BkukoMAB  a17F000000R17A3IAJ
# 8                         a0BA000000BkukoMAB  a17F000000R17A3IAJ
# 19                        a0BA000000BkukoMAB  a17F000000R17A3IAJ
# 44                        a0BA000000BkukoMAB  a17F000000R17A3IAJ
# 43                        a0BA000000BkukoMAB  a17F000000R17A3IAJ
# 22                        a0BA000000BkukoMAB  a17F000000R17A3IAJ
# 20                        a0BA000000BkukoMAB  a17F000000R17A3IAJ
# 38                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 25                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 2                         a0BA000000BkukoMAB  a17F000000R17A3IAJ
# 42                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
# 30                        a0BA000000Bkul4MAB  a17F000000R17A3IAJ
#
#    Grupo_de_Contas__c             OwnerId CodigoClienteSAPRecebedor_DFV__c
# 0                None  0052A000009L7J2QAK                       0000075710
# 35               None  0052A000009L7J2QAK                       0003918848
# 31               None  0052A000009L7J2QAK                       0003916735
# 27               None  0052A000009L7J2QAK                       0003901735
# 21               None  0052A000009L7J2QAK                       0003737673
# 18               None  0052A000009L7J2QAK                       0003683570
# 17               None  0052A000009L7J2QAK                       0003650979
# 16               None  0052A000009L7J2QAK                       0003649268
# 15               None  0052A000009L7J2QAK                       0003643011
# 14               None  0052A000009L7J2QAK                       0003637036
# 13               None  0052A000009L7J2QAK                       0003629027
# 12               None  0052A000009L7J2QAK                       0003596816
# 24               None  0052A000009L7J2QAK                       0003801524
# 10               None  0052A000009L7J2QAK                       0002672489
# 9                None  0052A000009L7J2QAK                       0001963727
# 7                None  0052A000009L7J2QAK                       0001293204
# 6                None  0052A000009L7J2QAK                       0001206105
# 5                None  0052A000009L7J2QAK                       0001085274
# 4                None  0052A000009L7J2QAK                       0001072001
# 1                None  0052A000009L7J2QAK                       0000075760
# 3                None  0052A000009L7J2QAK                       0001061173
# 11               None  0052A000009L7J2QAK                       0003490451
# 46               None  0054z00000ALBbtAAH                       0003948298
# 45               None  0054z00000ALBbtAAH                       0003934408
# 40               None  0054z00000ALBbtAAH                       0003925532
# 39               None  0054z00000ALBbtAAH                       0003925149
# 36               None  0054z00000ALBbtAAH                       0003920246
# 34               None  0054z00000ALBbtAAH                       0003917874
# 33               None  0054z00000ALBbtAAH                       0003917795
# 48               None  0054z00000ALBbtAAH                       0003949490
# 47               None  0054z00000ALBbtAAH                       0003951770
# 29               None  0054z00000ALBbtAAH                       0003911350
# 23               None  005F00000043cxYIAQ                       0003797915
# 32               None  005F0000004VfirIAC                       0003917204
# 26               None  005F0000004VfirIAC                       0003901676
# 37               None  005F0000004VfirIAC                       0003922916
# 41               None  005F0000004VfirIAC                       0003927816
# 28               None  005F0000006F0eaIAC                       0003908847
# 8                None  005F0000006F0eaIAC                       0001959482
# 19               None  005F0000006F0eaIAC                       0003721858
# 44               None  005F0000006F0eaIAC                       0003933725
# 43               None  005F0000006F0eaIAC                       0003933496
# 22               None  005F0000006F0eaIAC                       0003775920
# 20               None  005F0000006F0eaIAC                       0003735413
# 38               None  005F0000006F0eaIAC                       0003924725
# 25               None  005F0000006F0eaIAC                       0003857612
# 2                None  005F0000006F0eaIAC                       0000996371
# 42               None  005F0000006F0eaIAC                       0003928641
# 30               None  005F0000006F0eaIAC                       0003913472

# %%
dfclientesfe = pd.read_csv('C:\\Temp\\contas_sfe.txt',names=['CodCliente'],dtype={'CodCliente':'str'})
dfclientesfe.info()

# %%
queryCentro = f"""SELECT Id
, Name
, Codigo_do_Estabelecimento__c
, Unidade_de_negocio__c
, Area__c
, Ativo__c
, Codigo_Centro_Fornecedor__c 
FROM Estabelecimento__c
"""
sf_dataCentro = sf.query_all(queryCentro)

sf_dataCentro = pd.DataFrame(sf_dataCentro['records']).drop(columns='attributes')
sf_dataCentro[sf_dataCentro['Codigo_do_Estabelecimento__c'].isin(['1285','1821'])]
#sf_dfConta.to_csv('base_cliente_sfe_uat.csv',sep=';',index=False)

# %%
sf_dataCentro[sf_dataCentro['Id'].isin(['a0B4z00001PwiLwEAJ'])]

# %%
resultAmostraClienteSFE = pd.merge((pd.merge(left=dfclientesfe
                              , right=sf_dfConta
                              , left_on='CodCliente'
                              , right_on='Codigo_do_Cliente_SAP__c'  
                              , how='left'
                                    )[['CodCliente','Estabelecimento_Unidade_de_Negocio_SHV__c']]
                          ), right=sf_dataCentro
                          , left_on='Estabelecimento_Unidade_de_Negocio_SHV__c'
                          , right_on='Id'
                          , how='left'
                                )[['CodCliente','Codigo_do_Estabelecimento__c']]

resultAmostraClienteSFE.to_csv('base_cliente_621.csv',sep=';')

# %%
resultAmostraClienteConsultor = pd.merge(left=sf_dfConta
                              , right=sf_dataCentro
                              , left_on='Estabelecimento_Unidade_de_Negocio_SHV__c'
                              , right_on='Id'                                                                                              
                                    )[['Codigo_do_Cliente_SAP__c','Codigo_do_Estabelecimento__c','Name_y']]

resultAmostraClienteConsultor

# %%
queryArea_de_Vendas = f""" SELECT 
Id
,Name
,Empresa__c
,Id_ODS__c
,Setor_de_Atividade__c
,Grupo_de_Preco__c
,Conta__c
,Canal_de_Distribuicao__c
,Bloqueio__c
,CreatedDate
FROM Area_de_Vendas__c
where Conta__c IN (
'0011Y00002s2PkqQAE',
'0011Y00002u9yWKQAY',
'0012A00001udqxbQAA',
'0014z00001hWuXGAA0',
'0014z00001hX1GiAAK',
'0014z00001hXHQvAAO',
'0014z00001hXJi7AAG',
'0014z00001hXchHAAS',
'0014z00001hYJE9AAO',
'0014z00001hYWT2AAO',
'0014z00001iJLqlAAG',
'0014z00001iJsQkAAK',
'0014z00001iKX9bAAG',
'0014z00001iKs66AAC',
'0014z00001iLOfWAAW',
'0014z00001iM364AAC',
'0014z00001iM77bAAC',
'0014z00001jTQKAAA4',
'0014z00001jV1MpAAK',
'0014z00001jVRAyAAO',
'0014z00001lsRiMAAU',
'0014z00001nJNnHAAW',
'001A000000d7LXAIA2',
'001A000000d7PWrIAM',
'001A000000d7Ru2IAE',
'001A000000d7arZIAQ',
'001A000000d7fm2IAA',
'001A000000d7iuAIAQ',
'001A000000dGZFFIA4',
'001F000000j7cFsIAI',
'001F000000j7eVXIAY',
'001F000000j7gggIAA',
'001F000000lXXz2IAG',
'001F000000marGHIAY',
'001F000000n6yuHIAQ',
'001F000000n7EBBIA2',
'001F000000o1DMOIA2',
'001F000001NooSKIAZ',
'001F000001TJCoQIAX',
'001F000001VdPCuIAN',
'001F000001VevDcIAJ',
'001F000001fbMtcIAE')

"""
sf_dataArea_de_Vendas = sf.query_all(queryArea_de_Vendas)

# %%
sf_dataArea_de_Vendas = pd.DataFrame(sf_dataArea_de_Vendas['records']).drop(columns='attributes')
sf_dataArea_de_Vendas
sf_dataArea_de_Vendas.to_csv('base_areaVendas_sfe_uat.csv',sep=';',index=False)

# %%
queryConsultor = f"""SELECT Id, Username, Name FROM User
"""
sf_dataConsultor = sf.query_all(queryConsultor)

sf_dfConsultor = pd.DataFrame(sf_dataConsultor['records']).drop(columns='attributes')

sf_dfConsultor[sf_dfConsultor['Id']=='0054z000009JvyMAAS']
sf_dfConsultor[sf_dfConsultor['Id']=='0054z000008nCT6AAM']
# Out:
#                       Id                            Username  \
# 3279  0054z000008nCT6AAM  gislaine.souza@supergasbras.com.br
#
#                           Name
# 3279  Gislaine Soares De Souza

# %%
resultAmostraClienteConsultor = pd.merge(left=sf_dfConta
                              , right=sf_dfConsultor
                              , left_on='OwnerId'
                              , right_on='Id'                                                                                              
                                    )[['Id_x','Codigo_do_Cliente_SAP__c','Name_x','Username','Name_y']]

resultAmostraClienteConsultor.groupby(['Name_y'],as_index=False).agg(Qtd=('Name_y','count'))

resultAmostraClienteConsultor.sort_values(by='Codigo_do_Cliente_SAP__c').to_csv('base_cliente_consultores_henrique.csv',sep=';',index=False)

# %%
#queryGrupoConta = f""" SELECT 
#Id
#,Name
#,OwnerId
#,CreatedById
#,LastModifiedById
#FROM Grupo_de_Conta__c
#"""
#sf_dataGrupoConta = sf.query_all(queryGrupoConta)

#sf_dfGrupoConta = pd.DataFrame(sf_dataGrupoConta['records']).drop(columns='attributes')

#sf_dfGrupoConta[sf_dfGrupoConta['Id']=='a17F000000R17A3IAJ']

# %%
#sf.Account.update('0018D00000HARkyQAH',{'Grupo_de_Contas2__c': 'a17F000000R17A3IAJ'})

# %%
#contact = sf.Account.get('0018D00000HARkmQAH')
#contact

# %%
#sf_dfConta = pd.DataFrame(sf_dataConta['records']).drop(columns='attributes')
#sf_dfConta.count()
##sf_dfConta.to_csv('arquivo_clientes_sae.csv',sep=';',index=False)

# %%
#sf_dfConta[sf_dfConta['Codigo_do_Cliente_SAP__c']=='0003901683']

# %%
#z\xczaczxsdfsdfsdfsdf

# %%
queryArea_de_Vendas = f""" SELECT 
Id
,Name
,Empresa__c
,Id_ODS__c
,Setor_de_Atividade__c
,Grupo_de_Preco__c
,Conta__c
,Canal_de_Distribuicao__c
,Bloqueio__c
,CreatedDate
FROM Area_de_Vendas__c
where Conta__c = '001A000000d7IiPIAU'

"""
sf_dataArea_de_Vendas = sf.query_all(queryArea_de_Vendas)

# %%
sf_dataArea_de_Vendas = pd.DataFrame(sf_dataArea_de_Vendas['records']).drop(columns='attributes')
sf_dataArea_de_Vendas
#sf_dataArea_de_Vendas.to_csv('base_areaVendas_sfe_uat.csv',sep=';',index=False)

# %%
resultClienteAreaVenda = pd.merge(left=sf_dfConta
                              , right=sf_dataArea_de_Vendas
                              , left_on='Id'
                              , right_on='Conta__c'                                                                                              
                                    )[['Codigo_do_Cliente_SAP__c','Name_x','Conta__c','Empresa__c','Bloqueio__c','CreatedDate']]

resultClienteAreaVenda

# %%
arquivoCliente = 'base_cliente_sfe_uat.csv'

dfClienteSFE_JANAINA = pd.read_csv(arquivoCliente, sep=';',low_memory=False)

dfClienteSFE_JANAINA[dfClienteSFE_JANAINA['Codigo_do_Cliente_SAP__c'].isin(['0003951669',
'0003951668',
'0003951670',
'0003951671',
'0003951672',
'0003951673',
'0003951674',
'0003951675',
'0003951676',
'0003951677',
'0003951678',
'0003951679',
'0003951680'])].to_csv('clientes_janaina.csv',sep=';',index=False)

# %%
baseClienteClonado = dfClienteSFE_JANAINA[dfClienteSFE_JANAINA['Codigo_do_Cliente_SAP__c'].isin(['0003951669',
'0003951668',
'0003951670',
'0003951671',
'0003951672',
'0003951673',
'0003951674',
'0003951675',
'0003951676',
'0003951677',
'0003951678',
'0003951679',
'0003951680'])]

resultAmostra = pd.merge(left=baseClienteClonado
                              , right=sf_dataArea_de_Vendas
                              , left_on='Id'
                              , right_on='Conta__c'                                                                                              
                                    )#[['IDTSFECLIENTE','CLIENTE SAP','idtsfecentro','Estabelecimento_Unidade_de_Negocio_SHV__c']]

resultAmostra

#.to_csv('clientes_area_venda_janaina.csv',sep=';',index=False)

# %%
arquivoBaseCentros = 'centros_incorportacao_mic_super.csv'

dfBaseCentros = pd.read_csv(arquivoBaseCentros, sep=';',low_memory=False)

dfBaseCentros

# %%
result = pd.merge(left=sf_dfConta
                              , right=dfBaseCentros
                              , left_on='Estabelecimento_Unidade_de_Negocio_SHV__c'
                              , right_on='IDTSFECentro'                                                                                              
                                    )
                  
result[['Id','Codigo_do_Cliente_SAP__c','Estabelecimento_Unidade_de_Negocio_SHV__c','CodCentro']].sort_values(by='CodCentro')

# %%
arquivoIsabela = 'Extração SF Contas nos Centros antigos.xlsx'

dfClienteIsabele = pd.read_excel(arquivoIsabela)

dfClienteIsabele

# %%
dfAmostra = dfClienteIsabele[dfClienteIsabele['seq'] <= 200]

# %%
arquivoBaseClienteSalesforce = 'base_cliente_sfe_uat.csv'

dfBaseClienteSalesforce = pd.read_csv(arquivoBaseClienteSalesforce, sep=';',low_memory=False)

dfBaseClienteSalesforce

# %%
resultAmostra = pd.merge(pd.merge(pd.merge(left=dfAmostra
                              , right=dfBaseClienteSalesforce
                              , left_on='IDTSFECLIENTE'
                              , right_on='Id'                                                                                              
                                    ), right=dfBaseCentros
                              , left_on='Estabelecimento_Unidade_de_Negocio_SHV__c'
                              , right_on='IDTSFECentro'
                        ), right=dfBaseCentros
                              , left_on='idtsfecentro'
                              , right_on='IDTSFECentro')[['IDTSFECLIENTE'
                                                          ,'CLIENTE SAP'
                                                          ,'idtsfecentro'
                                                          ,'CodCentro_y'
                                                          ,'Estabelecimento_Unidade_de_Negocio_SHV__c'
                                                          ,'CodCentro_x']]

resultAmostra.loc[resultAmostra['CodCentro_x'] == resultAmostra['CodCentro_y'], 'Comparacao'] = 'Não Mudou Centro'
resultAmostra.loc[resultAmostra['CodCentro_x'] != resultAmostra['CodCentro_y'], 'Comparacao'] = 'Mudou Centro'

resultAmostra.groupby(['Comparacao'],as_index=False).agg(Qtd=('Comparacao','count'))

# %%
dfcliente = pd.read_csv('arquivo_clientes_sae.csv', sep=';',dtype={'Id':'str',
'OwnerId':'str',
'Codigo_do_Cliente_SAP__c':'str',
'Name':'str',
'UFCapex__c':'str'	,
'Cidade__c':'str',
'CodigoClienteSAPRecebedor_DFV__c':'str',
'Codigo_Parceiro_Negocio__c':'str'})


dfcliente

# %%
dfcliente_nao_integrados = pd.read_csv('clientes_nao_integrados.csv', sep=';',dtype={'Codigo_do_Cliente_SAP__c':'str'})


dfcliente_nao_integrados

# %%
result = pd.merge(left=dfcliente_nao_integrados
                              , right=dfcliente
                              , left_on='Codigo_do_Cliente_SAP__c'
                              , right_on='Codigo_do_Cliente_SAP__c'                                                                                              
                                    )

# %%
result

# %%
dfbaseEmpregado = pd.read_csv('base_empregado.csv', sep=';',dtype={'IdtSFEEmpregado':'str', 
                                                                  'CodEmpregado':'str',
                                                                  'NomConsultor':'str'}
                             ,names=['IdtSFEEmpregado','CodEmpregado','NomConsultor']
                             ,header=0)


dfbaseEmpregado

# %%
resultFinal = pd.merge(left=result
                              , right=dfbaseEmpregado
                              , left_on='OwnerId'
                              , right_on='IdtSFEEmpregado'                                                                                              
                                    )[['Codigo_do_Cliente_SAP__c'
             ,'Id'
             ,'OwnerId'
             ,'CodEmpregado'
             ,'NomConsultor'
             ,'Name'
             ,'UFCapex__c'
             ,'Cidade__c'
             ,'CodigoClienteSAPRecebedor_DFV__c'
             ,'Codigo_Parceiro_Negocio__c'
]].sort_values(by='Codigo_do_Cliente_SAP__c')

# %%
resultFinal.to_csv('arquivo_final.csv',sep=';',index=False)

# %%
asdasdasdasdasdasd

# %%
resultFinal[resultFinal['Codigo_do_Cliente_SAP__c']=='0003925333']

# %%
queryConta = f""" SELECT Id, Name FROM user where Id In ('005F0000001vqBbIAI')"""
sf_dataConta = sf.query_all(queryConta)

# %%
sf_dfConta = pd.DataFrame(sf_dataConta['records']).drop(columns='attributes')
sf_dfConta

# %%
adsdsdadsd

# %%
arquivo = 'C:\\Temp\\EXTCONTACONTRATO_20220502171614.csv'

df = pd.read_csv(arquivo, sep=';',error_bad_lines=False,engine='python')

# %%
df[df['Parceiro de Negocio'] == 42570]

# %%
df[df['Codigo do cliente Datasul'] =='0001051639']

# %%
queryMCTQ = f""" SELECT Id
,Origin
,ParentId
,CaseNumber
,AccountId
,CreatedDate
,CreatedById
,Status
,Description
,ClosedDate
,Tempo_de_Duracao__c	
,Numero_do_Protocolo__c

FROM Case 

WHERE Origin IN ('RCC' , 'Atendimento pela URA')

and CaseNumber = '01694400'"""
sf_dataMCTQ = sf.query_all(queryMCTQ)
sf_dfMCTQ = pd.DataFrame(sf_dataMCTQ['records']).drop(columns='attributes')
sf_dfMCTQ

# %%
AnoMes = 2022
#print(AnoMes)
queryCPQ = f""" SELECT 
    Id
    ,IdCapex_DFV__c
    ,SBQQ__Account__c
    FROM SBQQ__QUOTE__C
    WHERE IdCapex_DFV__c in (
'4100012805'
)
"""
#print(query)

sf_dataCPQ = sf.query_all(queryCPQ)

# %%
sf_dfCPQ = pd.DataFrame(sf_dataCPQ['records']).drop(columns='attributes')
sf_dfCPQ

# %%
queryCLT = f""" SELECT 
    Id
    ,Name
    ,Data_de_aprovacao_do_CAPEX_no_SFE__c
    FROM Capex__c
    WHERE Name in ( '4000030669' )
"""
sf_dataCLT = sf.query_all(queryCLT)

sf_dfCLT = pd.DataFrame(sf_dataCLT['records']).drop(columns='attributes')

sf_dfCLT

# %%
queryAccount = f""" SELECT 
    Codigo_do_Cliente_SAP__c
    ,Status_da_Conta__c
    ,OwnerId
    ,CodigoClienteSAPRecebedor_DFV__c
    ,Id
    FROM account
    WHERE Codigo_do_Cliente_SAP__c in ('0003921820')
"""
sf_dataAccount = sf.query_all(queryAccount)

sf_dfAccount = pd.DataFrame(sf_dataAccount['records']).drop(columns='attributes')

sf_dfAccount

# %%
queryAreaVenda = f""" SELECT 
    Id,Id_ODS__c,Conta__c,Bloqueio__c,Setor_de_Atividade__c
    FROM Area_de_Vendas__c
    Where Conta__c = '0014z00001iLLbjAAG'
"""
sf_dataAreaVenda = sf.query_all(queryAreaVenda)

sf_dfAreaVenda = pd.DataFrame(sf_dataAreaVenda['records']).drop(columns='attributes')

sf_dfAreaVenda

# %%
sf_df.groupby(['OwnerId']).count()

# %%
sf_dataGrupoConta = sf.query_all("""
SELECT Id, Codigo_do_Grupo_de_Conta__c,Name

FROM Grupo_de_Conta__c
""")

# %%
sf_dataRecordType = sf.query_all("""
SELECT Id, Name

FROM User

where id = '005F0000003soctIAA'
""")

# %%
sf_dfRecordType = pd.DataFrame(sf_dataRecordType['records']).drop(columns='attributes')

sf_dfRecordType

# %%
df_zvmc = pd.merge(sf_df, sf_dfRecordType, left_on = 'RecordTypeId', right_on = 'Id') \
.merge(sf_dfGrupoConta, left_on = 'Grupo_de_Contas2__c', right_on = 'Id')

# %%
df_filtrado = df_zvmc[['Id_x','Codigo_do_Cliente_SAP__c','Name_x','Name_y','Codigo_do_Grupo_de_Conta__c','Name']]

df_filtrado.rename(columns={'Id_x':'IdSFEConta','Name_x':'Conta','Name_y':'TipoDeRegistroDaConta','Codigo_do_Grupo_de_Conta__c':'CodGrupoConta','Name':'NomGrupoConta'},inplace=True)

# %%
df_filtrado.to_csv('cliente_zvmc.csv',index=False,sep=';')

# %%
arquivo = 'f1794978-671d-b385-b13d-9ba7c8704def_0.txt'

df = pd.read_csv(arquivo, sep=',')

# %%
df.info()

# %%
df.groupby(['Message']).count()

# %%
arquivo = '2da2bfcf-fa18-33d8-e914-a31115c68da9_0.txt'

df = pd.read_csv(arquivo, sep=',')

# %%
df.groupby(['Message']).count()

# %%
queryCaso = f"""SELECT 
Id
,Codigo_do_Caso__c
,Type,Subtipo_do_Caso__c
,Canal_de_Venda__c
,Origin
,Priority
,Status
,Data_de_Vencimento__c
,Subject
,Description
,idRespostaQuestao__c
,AccountId
,CreatedDate
,CreatedById
,CaseNumber
FROM Case 
where Origin = 'Checklist de Abastecimento'
and CreatedDate >= 2022-11-29T00:00:03Z"""
sf_dataCaso = sf.query_all(queryCaso)

sf_dfCaso = pd.DataFrame(sf_dataCaso['records']).drop(columns='attributes')
sf_dfCaso
# Out:
#                        Id Codigo_do_Caso__c       Type Subtipo_do_Caso__c  \
# 0      5008D000003Vk8JQAS           1704476  Checklist        Instalações
# 1      5008D000003Vk8KQAS           1704477  Checklist        Instalações
# 2      5008D000003Vk8LQAS           1704478  Checklist          Comercial
# 3      5008D000003Vk8MQAS           1704479  Checklist          Comercial
# 4      5008D000003Vk8NQAS           1704480  Checklist        Instalações
# ...                   ...               ...        ...                ...
# 42854  5008D000003W806QAC           1748209  Checklist                RCC
# 42855  5008D000003W80GQAS           1748210  Checklist        Instalações
# 42856  5008D000003W80LQAS           1748211  Checklist        Instalações
# 42857  5008D000003W80VQAS           1748212  Checklist        Instalações
# 42858  5008D000003W80aQAC           1748213  Checklist        Instalações
#
#       Canal_de_Venda__c                      Origin Priority   Status  \
# 0                Granel  Checklist de Abastecimento    Média   Aberto
# 1                Granel  Checklist de Abastecimento    Média   Aberto
# 2                Granel  Checklist de Abastecimento    Média   Aberto
# 3                Granel  Checklist de Abastecimento    Média   Aberto
# 4                Granel  Checklist de Abastecimento    Média   Aberto
# ...                 ...                         ...      ...      ...
# 42854            Granel  Checklist de Abastecimento    Média  Fechado
# 42855            Granel  Checklist de Abastecimento    Média   Aberto
# 42856            Granel  Checklist de Abastecimento    Média   Aberto
# 42857            Granel  Checklist de Abastecimento    Média   Aberto
# 42858            Granel  Checklist de Abastecimento    Média   Aberto
#
#       Data_de_Vencimento__c                               Subject  \
# 0                      None        Placa de Idenficação do Tanque
# 1                      None  Mang de Abast passa por local seguro
# 2                      None                 Local para Estacionar
# 3                      None                 Local para Estacionar
# 4                      None  Mang de Abast passa por local seguro
# ...                     ...                                   ...
# 42854                  None                            Extintores
# 42855                  None                                Portão
# 42856                  None                             Magnetron
# 42857                  None                 Mangueira do Pit Stop
# 42858                  None                                Portão
#
#                                              Description idRespostaQuestao__c  \
# 0      * Nota SAP: 000014870838\n * Data Entrada: 10...  000014870838 - 0007
# 1      * Nota SAP: 000014893369\n * Data Entrada: 17...  000014893369 - 0023
# 2      * Nota SAP: 000014634621\n * Data Entrada: 01...  000014634621 - 0022
# 3      * Nota SAP: 000014458782\n * Data Entrada: 03...  000014458782 - 0022
# 4      * Nota SAP: 000014458782\n * Data Entrada: 03...  000014458782 - 0023
# ...                                                  ...                  ...
# 42854  * Nota SAP: 000015032888\n * Data Entrada: 29...  000015032888 - 0004
# 42855  * Nota SAP: 000014159094\n * Data Entrada: 09...  000014159094 - 0005
# 42856  * Nota SAP: 000014221538\n * Data Entrada: 05...  000014221538 - 0010
# 42857  * Nota SAP: 000015034567\n * Data Entrada: 29...  000015034567 - 0019
# 42858  * Nota SAP: 000014207504\n * Data Entrada: 28...  000014207504 - 0005
#
#                 AccountId                   CreatedDate         CreatedById  \
# 0      0011Y00002dubkEQAQ  2022-11-29T20:18:15.000+0000  0052A000009LHLmQAO
# 1      0011Y00002dubkEQAQ  2022-11-29T20:18:15.000+0000  0052A000009LHLmQAO
# 2      0011Y00002dubSUQAY  2022-11-29T20:18:15.000+0000  0052A000009LHLmQAO
# 3      0011Y00002duC1BQAU  2022-11-29T20:18:15.000+0000  0052A000009LHLmQAO
# 4      0011Y00002duC1BQAU  2022-11-29T20:18:15.000+0000  0052A000009LHLmQAO
# ...                   ...                           ...                 ...
# 42854  0014z00001f6dU9AAI  2022-11-30T12:20:46.000+0000  0052A000009LHLmQAO
# 42855  0014z00001f6RUYAA2  2022-11-30T12:21:01.000+0000  0052A000009LHLmQAO
# 42856  0014z00001f7XeEAAU  2022-11-30T12:21:13.000+0000  0052A000009LHLmQAO
# 42857  0014z00001fCKzUAAW  2022-11-30T12:21:25.000+0000  0052A000009LHLmQAO
# 42858  0014z00001g2UBZAA2  2022-11-30T12:21:38.000+0000  0052A000009LHLmQAO
#
#       CaseNumber
# 0       01705478
# 1       01705479
# 2       01705480
# 3       01705481
# 4       01705482
# ...          ...
# 42854   01749211
# 42855   01749212
# 42856   01749213
# 42857   01749214
# 42858   01749215
#
# [42859 rows x 16 columns]

# %%
queryConta = f""" SELECT 
Id
,Codigo_do_Cliente_SAP__c
FROM Account
"""
sf_dataConta = sf.query_all(queryConta)
sf_dfConta = pd.DataFrame(sf_dataConta['records']).drop(columns='attributes')
sf_dfConta
# Out:
#                          Id Codigo_do_Cliente_SAP__c
# 0        0011Y00002dtAW6QAM               0003680100
# 1        0011Y00002dtAooQAE               0003680148
# 2        0011Y00002dtCgXQAU               0003680101
# 3        0011Y00002dtCobQAE               0003680122
# 4        0011Y00002dtCpKQAU                  3680124
# ...                     ...                      ...
# 2031786  001F000001tOgReIAK               0003544178
# 2031787  001F000001tOgRjIAK               0003544179
# 2031788  001F000001tOhSbIAK               0003544305
# 2031789  001F000001tOhUXIA0               0003545206
# 2031790  001F000001tOhW4IAK               0003544203
#
# [2031791 rows x 2 columns]

# %%
resultFinal = pd.merge(left=sf_dfCaso
                              , right=sf_dfConta
                              , left_on='AccountId'
                              , right_on='Id'                                                                                              
                                    )

# %%
resultFinal.to_csv('base_casos_hml.csv', index=False, sep=';', encoding='latin-1')
