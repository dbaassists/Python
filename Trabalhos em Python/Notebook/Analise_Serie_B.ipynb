# %%
import pandas as pd

# %%
dados = [   
['Brusque',1,0,'Guarani',1],
['Vasco',1,1,'Vila Nova',1],
['Bahia',2,0,'Cruzeiro',1],
['Chapecoense',1,1,'Ituano',1],
['Ponte Preta',0,0,'Grêmio',1],
['Sport',1,0,'Sampaio Corrêa',1],
['Tombense',1,1,'Operário-PR',1],
['Londrina',2,0,'Náutico',1],
['Novorizontino',3,1,'CRB',1],
['CSA',1,1,'Criciúma',1],
['Vila Nova',0,0,'Novorizontino',2],
['Cruzeiro',1,0,'Brusque',2],
['Criciúma',1,0,'Londrina',2],
['Grêmio',0,1,'Chapecoense',2],
['Náutico',0,1,'Bahia',2],
['Operário-PR',2,0,'Ponte Preta',2],
['Ituano',0,0,'CSA',2],
['Sampaio Corrêa',1,1,'Tombense',2],
['Guarani',0,0,'Sport',2],
['CRB',1,1,'Vasco',2],
['Grêmio',3,1,'Guarani',3],
['Londrina',1,1,'Novorizontino',3],
['CSA',1,1,'Bahia',3],
['Chapecoense',0,0,'Vasco',3],
['Criciúma',1,1,'Sport',3],
['Ponte Preta',1,0,'CRB',3],
['Sampaio Corrêa',3,1,'Brusque',3],
['Ituano',3,1,'Vila Nova',3],
['Tombense',1,1,'Cruzeiro',3],
['Náutico',2,0,'Operário-PR',3],
['Sport',1,0,'Ituano',4],
['Novorizontino',0,3,'Chapecoense',4],
['Brusque',2,0,'CSA',4],
['Vila Nova',1,1,'Tombense',4],
['Bahia',1,0,'Sampaio Corrêa',4],
['Cruzeiro',1,0,'Londrina',4],
['CRB',1,2,'Náutico',4],
['Operário-PR',0,1,'Grêmio',4],
['Guarani',1,0,'Criciúma',4],
['Vasco',1,0,'Ponte Preta',4],
['Londrina',2,2,'Vila Nova',5],
['Ituano',1,0,'Bahia',5],
['CSA',1,0,'Sport',5],
['Grêmio',2,0,'CRB',5],
['Sampaio Corrêa',1,1,'Operário-PR',5],
['Chapecoense',0,2,'Cruzeiro',5],
['Ponte Preta',2,0,'Brusque',5],
['Criciúma',1,1,'Novorizontino',5],
['Tombense',1,1,'Vasco',5],
['Náutico',1,1,'Guarani',5],
['Bahia',4,0,'Londrina',6],
['Brusque',0,0,'Chapecoense',6],
['Vila Nova',2,0,'Náutico',6],
['Sport',2,0,'Tombense',6],
['Operário-PR',2,0,'Criciúma',6],
['Novorizontino',2,1,'Ituano',6],
['Vasco',1,0,'CSA',6],
['Guarani',0,0,'Ponte Preta',6],
['Cruzeiro',1,0,'Grêmio',6],
['CRB',2,1,'Sampaio Corrêa',6],
['Ponte Preta',0,1,'Novorizontino',7],
['Chapecoense',0,1,'Sport',7],
['Criciúma',3,0,'CRB',7],
['Londrina',2,1,'Brusque',7],
['Tombense',1,1,'Guarani',7],
['Sampaio Corrêa',2,0,'Vila Nova',7],
['CSA',0,0,'Operário-PR',7],
['Náutico',0,1,'Cruzeiro',7],
['Vasco',1,0,'Bahia',7],
['Ituano',1,1,'Grêmio',7],
['Novorizontino',0,0,'Sport',8],
['CRB',1,0,'Londrina',8],
['Grêmio',0,0,'Criciúma',8],
['Grêmio',3,0,'Brusque',38],
['Náutico',0,1,'Ponte Preta',38],
['Criciúma',2,0,'Tombense',38],
['Sampaio Corrêa',2,1,'Londrina',38],
['Guarani',1,0,'Chapecoense',38],
['CRB',1,2,'Bahia',38],
['Ituano',0,1,'Vasco',38],
['Operário-PR',0,3,'Novorizontino',38],
['Cruzeiro',3,2,'CSA',38],
['Vila Nova',0,0,'Sport',38],
]


brasileirao_serie_b = pd.DataFrame(dados, columns=['NomTimeMandante'
                                                   ,'PlacarMandante'
                                                   ,'PlacarVisitante'
                                                   ,'NomTimeVisitante'
                                                   ,'NumRodada'])
brasileirao_serie_b['VTM'] = 0
brasileirao_serie_b['EPT'] = 0
brasileirao_serie_b['VTV'] = 0

# %%
brasileirao_serie_b.loc[brasileirao_serie_b['PlacarMandante'] > brasileirao_serie_b['PlacarVisitante'], 'VTM'] = 1
brasileirao_serie_b.loc[brasileirao_serie_b['PlacarMandante'] == brasileirao_serie_b['PlacarVisitante'], 'EPT'] = 1
brasileirao_serie_b.loc[brasileirao_serie_b['PlacarMandante'] < brasileirao_serie_b['PlacarVisitante'], 'VTV'] = 1

# %%
dfEmpate1 = brasileirao_serie_b[brasileirao_serie_b['EPT']==1][['NomTimeMandante','NumRodada','EPT']]
dfEmpate1['NumEmpate'] = 1
dfEmpate1['NumVitoria'] = 0
dfEmpate1.rename(columns={'NomTimeMandante': 'NomTime'},inplace=True)

dfEmpate2 = brasileirao_serie_b[brasileirao_serie_b['EPT']==1][['NomTimeVisitante','NumRodada','EPT']]
dfEmpate2['NumEmpate'] = 1
dfEmpate2['NumVitoria'] = 0
dfEmpate2.rename(columns={'NomTimeVisitante': 'NomTime'},inplace=True)

dfVitoriaMandante = brasileirao_serie_b[brasileirao_serie_b['VTM']==1][['NomTimeMandante','NumRodada','VTM']]
dfVitoriaMandante['NumEmpate'] = 0
dfVitoriaMandante['NumVitoria'] = 1
dfVitoriaMandante.rename(columns={'NomTimeMandante': 'NomTime'},inplace=True)

dfVitoriaVisitante = brasileirao_serie_b[brasileirao_serie_b['VTV']==1][['NomTimeVisitante','NumRodada','VTV']]
dfVitoriaVisitante['NumEmpate'] = 0
dfVitoriaVisitante['NumVitoria'] = 1
dfVitoriaVisitante.rename(columns={'NomTimeVisitante': 'NomTime'},inplace=True)

# %%
df2 = brasileirao_serie_b[['NomTimeVisitante','PlacarVisitante','PlacarMandante','NumRodada']]
df2.rename(columns={'NomTimeVisitante': 'NomTime','PlacarVisitante':'GP','PlacarMandante':'GC'},inplace=True)


df1 = brasileirao_serie_b[['NomTimeMandante','PlacarMandante','PlacarVisitante','NumRodada']]
df1.rename(columns={'NomTimeMandante': 'NomTime','PlacarMandante':'GP','PlacarVisitante':'GC'},inplace=True)

dfGP_GC = pd.merge(df1
            , df2
            , how='outer')

dfGP_GC = dfGP_GC.groupby(['NomTime'],as_index=False).agg(GP=('GP','sum'),GC=('GC','sum'))

dfGP_GC['SG'] = dfGP_GC['GP'] - dfGP_GC['GC']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
dfVitoriaMandante['NumPontosRodada'] = dfVitoriaMandante['VTM'] * 3
dfVitoriaVisitante['NumPontosRodada'] = dfVitoriaVisitante['VTV'] * 3
dfEmpate1['NumPontosRodada'] = dfEmpate1['EPT'] 
dfEmpate2['NumPontosRodada'] = dfEmpate2['EPT']

# %%
dfTabelaCampeonato = pd.merge(
                        (pd.merge(
                        (pd.merge(dfEmpate1
                              , dfEmpate2
                                  , how = 'outer'))
                        ,dfVitoriaMandante
                        , how = 'outer'))
                        ,dfVitoriaVisitante
                        , how = 'outer')[['NomTime','NumRodada','NumVitoria','NumEmpate','NumPontosRodada']]

# %%
dfApuracao = pd.DataFrame()
dfApuracaoLinha = pd.DataFrame()
dfLinha = pd.DataFrame()

dfTabelaCampeonato.sort_values(by=['NumRodada','NomTime'],inplace=True)

dfTabelaCampeonato['Posicao'] = dfTabelaCampeonato.sort_values(by=['NomTime','NumRodada'],ascending=True).groupby(['NomTime']).cumcount() + 1

dfTabelaCampeonato.sort_values(by=['NomTime','Posicao'],ascending=True, inplace = True)

for listaNomTime in dfTabelaCampeonato['NomTime'].unique():
    
    for listaPosicao in dfTabelaCampeonato[dfTabelaCampeonato['NomTime']==listaNomTime]['Posicao']:
    
        dfLinha = dfTabelaCampeonato[(dfTabelaCampeonato['NomTime']==listaNomTime)
                                    & (dfTabelaCampeonato['Posicao']==listaPosicao)][['NomTime','NumRodada','NumPontosRodada','Posicao']]

        if listaPosicao == 1:
            
            dfLinha['PontoRodadaAnterior'] = 0

            dfLinha['TotalPontoRodada'] = dfLinha['NumPontosRodada'].astype(int)
        
            dfApuracao = pd.concat([dfApuracao, dfLinha])
            
            dfApuracao['TotalPontoRodada'].fillna(0, inplace=True)                        
            
        else:

            dfApuracaoLinha = dfApuracao[(dfApuracao['NomTime']==listaNomTime) 
                                         & (dfApuracao['Posicao']==listaPosicao)][['NomTime'
                                                                                   ,'NumRodada'
                                                                                   ,'NumPontosRodada'
                                                                                   ,'PontoRodadaAnterior'
                                                                                   ,'Posicao']]
            
            dfApuracaoLinha2 = dfTabelaCampeonato[(dfTabelaCampeonato['NomTime']==listaNomTime)
                                    & (dfTabelaCampeonato['Posicao']==listaPosicao)][['NomTime'
                                                                                      ,'NumRodada'
                                                                                      ,'NumPontosRodada'
                                                                                      ,'Posicao']]
            
            dfLinha['PontoRodadaAnterior'] = int(dfApuracao[(dfApuracao['NomTime']==listaNomTime) 
                                                            & (dfApuracao['Posicao']==listaPosicao-1)]['TotalPontoRodada'])
            
            dfLinha['NumPontosRodada'] = dfApuracaoLinha2['NumPontosRodada']
            dfLinha['NumRodada'] = dfApuracaoLinha2['NumRodada']
            dfLinha['Posicao'] = dfApuracaoLinha2['Posicao']
            dfLinha['TotalPontoRodada'] = int(dfLinha['PontoRodadaAnterior']) + int(dfLinha['NumPontosRodada'])
            
            dfApuracao = pd.concat([dfApuracao, dfLinha])

dfApuracao[dfApuracao['NomTime']=='Bahia']
# Out:
#     NomTime  NumRodada  NumPontosRodada  Posicao  PontoRodadaAnterior  \
# 243   Bahia          1                3        1                    0
# 432   Bahia          2                3        2                    3
# 132   Bahia          3                1        3                    6
# 257   Bahia          4                3        4                    7
# 265   Bahia          6                3        5                   10
# 279   Bahia          8                3        6                   13
# 288   Bahia         10                3        7                   16
# 293   Bahia         11                3        8                   19
# 452   Bahia         12                3        9                   22
# 460   Bahia         15                3       10                   25
# 57    Bahia         16                1       11                   28
# 179   Bahia         17                1       12                   29
# ...

# %%
TabelaCampeonatoBrasileiroSerieB = dfTabelaCampeonato.groupby(['NomTime'],as_index=False).agg(Pontos=('NumPontosRodada','sum')
                                                          ,Vitorias=('NumVitoria','sum')
                                                          ,Empates=('NumEmpate','sum')
                                                          ).sort_values(by='Pontos',ascending=False)


TabelaCampeonatoBrasileiroSerieB['Jogos'] = dfTabelaCampeonato['NumRodada'].max()

TabelaCampeonatoBrasileiroSerieB['Derrotas'] = TabelaCampeonatoBrasileiroSerieB['Jogos'] - (
                                                        TabelaCampeonatoBrasileiroSerieB['Vitorias'] 
                                                        + TabelaCampeonatoBrasileiroSerieB['Empates']
                                                        )

TabelaCampeonatoBrasileiroSerieB['Posicao'] = TabelaCampeonatoBrasileiroSerieB.sort_values(by='Pontos',ascending=False).groupby(['Jogos']).cumcount() + 1

TabelaCampeonatoBrasileiroSerieB.sort_values(by=['Pontos'],ascending=False, inplace = True)

TabelaCampeonatoBrasileiroSerieB = pd.merge(left=TabelaCampeonatoBrasileiroSerieB
                                            , right=dfGP_GC
                                            , left_on='NomTime'
                                            , right_on='NomTime'
                                            )[['Posicao','NomTime','Jogos','Pontos','Vitorias','Empates','Derrotas','GP','GC','SG']]

TabelaCampeonatoBrasileiroSerieB['%'] = round(((TabelaCampeonatoBrasileiroSerieB['Pontos'] / (TabelaCampeonatoBrasileiroSerieB['Jogos'] * 3)) * 100),2)

TabelaCampeonatoBrasileiroSerieB.loc[(TabelaCampeonatoBrasileiroSerieB['Posicao'] >= 1) & (TabelaCampeonatoBrasileiroSerieB['Posicao'] <= 4), 'Situacao'] = 'Classificado Série A'
TabelaCampeonatoBrasileiroSerieB.loc[(TabelaCampeonatoBrasileiroSerieB['Posicao'] >= 5) & (TabelaCampeonatoBrasileiroSerieB['Posicao'] <= 16), 'Situacao'] = 'Série B - 2023'
TabelaCampeonatoBrasileiroSerieB.loc[(TabelaCampeonatoBrasileiroSerieB['Posicao'] >= 17) & (TabelaCampeonatoBrasileiroSerieB['Posicao'] <= 20), 'Situacao'] = 'Rebaixado Série C'

TabelaCampeonatoBrasileiroSerieB
# Out:
#     Posicao         NomTime  Jogos  Pontos  Vitorias  Empates  Derrotas  GP  \
# 0         1        Cruzeiro     38      78        23        9         6  57
# 1         2          Grêmio     38      65        17       14         7  50
# 2         3           Bahia     38      62        17       11        10  43
# 3         4           Vasco     38      62        17       11        10  48
# 4         5  Sampaio Corrêa     38      58        16       10        12  48
# 5         6          Ituano     38      57        15       12        11  42
# 6         7           Sport     38      57        15       12        11  37
# 7         8        Criciúma     38      56        14       14        10  43
# 8         9        Londrina     38      53        14       11        13  36
# 9        10         Guarani     38      51        13       12        13  33
# 10       11             CRB     38      50        13       11        14  35
# ...
