# %%
import pandas as pd
from io import StringIO
import csv

# %%
caminho = 'C:\\Temp\\ZCON005\\ZCON005_Background.txt'

df = pd.read_fwf(caminho,widths=[1000]*1,header=None)

#zcon005 = pd.read_csv(caminho, header=None)

# %%
df.drop(range(0,11),inplace=True)

# %%
df.to_csv('C:\\Temp\\ZCON005\\zcon005.csv',index=False)

# %%
caminho = 'C:\\Temp\\ZCON005\\zcon005.csv'

zcon005 = pd.read_csv(caminho, header=0, names=['Geral'])

# %%
zcon005.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570 entries, 0 to 569
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Geral   570 non-null    object
# dtypes: object(1)
# memory usage: 4.6+ KB

# %%
zcon005 = zcon005.sort_values(by='Geral',ascending=False)

# %%
zcon005.to_csv('C:\\Temp\\ZCON005\\zcon005.csv',index=False,quoting=csv.QUOTE_NONE,escapechar='\\')
#zcon005.reset_index()

# %%
#zcon005[zcon005['Geral'][0:6] == '|1001|']

#zcon005.loc[zcon005['Geral'][1:5] == '1001']

zcon005_2 = pd.read_csv('C:\\Temp\\ZCON005\\zcon005.csv', header=0,sep='|')

# %%
zcon005_2.head(40)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Geral
# ...

# %%
zcon005_2.head(50)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Geral
# ...
