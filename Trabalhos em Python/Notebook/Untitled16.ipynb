# %%
import warnings
import pandas as pd
from pandas.core.common import SettingWithCopyWarning
import numpy as np
import json

# %%
pd.options.display.max_rows = 999
pd.options.display.max_columns=999
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)
pd.set_option("expand_frame_repr", False)

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

pd.set_option('max_colwidth', -1)
# Out:
# C:\Users\gabriel.quintella\AppData\Local\Temp\ipykernel_22680\646672626.py:10: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('max_colwidth', -1)

# %%
arquivo = 'C:\\Temp\\LogSFE\\68521734-fda6-523e-8ce0-afbbd3b47072_0.txt'

df = pd.read_csv(arquivo)

df

#df.to_csv('C:\\Temp\\LogSFE\\log.csv')
# Out:
#                        Timestamp    Level   OperationName                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          OperationItem                                                      
# ...

# %%
dz = df['OperationItem'].str.split(',', 100, expand=True)

# %%
dz['mensage'] = df['Message'].str[:51]

# %%
dz[[6,'mensage']].to_csv('C:\\Temp\\LogSFE\\log.csv')

# %%
dz['mensage'] = dz['mensage'].str.rstrip('\n')

# %%
dz['mensage'].str[:51]
# Out:
# 0      CANNOT_INSERT_UPDATE_ACTIVATE_ENTITY:AccountTrigger
# 1      CANNOT_INSERT_UPDATE_ACTIVATE_ENTITY:AccountTrigger
# 2      CANNOT_INSERT_UPDATE_ACTIVATE_ENTITY:AccountTrigger
# 3      CANNOT_INSERT_UPDATE_ACTIVATE_ENTITY:AccountTrigger
# 4      CANNOT_INSERT_UPDATE_ACTIVATE_ENTITY:AccountTrigger
# 5      CANNOT_INSERT_UPDATE_ACTIVATE_ENTITY:AccountTrigger
# 6      CANNOT_INSERT_UPDATE_ACTIVATE_ENTITY:AccountTrigger
# 7      CANNOT_INSERT_UPDATE_ACTIVATE_ENTITY:AccountTrigger
# 8      CANNOT_INSERT_UPDATE_ACTIVATE_ENTITY:AccountTrigger
# 9      CANNOT_INSERT_UPDATE_ACTIVATE_ENTITY:AccountTrigger
# 10     CANNOT_INSERT_UPDATE_ACTIVATE_ENTITY:AccountTrigger
# 11     CANNOT_INSERT_UPDATE_ACTIVATE_ENTITY:AccountTrigger
# 12     CANNOT_INSERT_UPDATE_ACTIVATE_ENTITY:AccountTrigger
# 13     CANNOT_INSERT_UPDATE_ACTIVATE_ENTITY:AccountTrigger
# 14     CANNOT_INSERT_UPDATE_ACTIVATE_ENTITY:AccountTrigger
# 15     CANNOT_INSERT_UPDATE_ACTIVATE_ENTITY:AccountTrigger
# ...
