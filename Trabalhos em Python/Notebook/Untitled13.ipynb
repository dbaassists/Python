# %%
import tabula

# %% [markdown]
# pip install tabula-py

# %%
arquivo = 'C:\\Temp\\pesquisa\\BR002442022_418382_bairro_municipio.pdf'

lista_tabela = tabula.read_pdf(arquivo, pages='all')

# %%
display(lista_tabela)
# Out:
# [   Unnamed: 0 Unnamed: 1             Unnamed: 2     Total de
#  0      REGIÃO     ESTADO              MUNICÍPIO          NaN
#  1         NaN        NaN                    NaN  Entrevistas
#  2         NaN        NaN          Coité do Nóia            1
#  3         NaN        NaN        Delmiro Gouveia            1
#  4         NaN        NaN          Joaquim Gomes            1
#  5         NaN        NaN                 Maceió            9
#  6         NaN        NaN          Major Isidoro            1
#  7         NaN        NaN              Maribondo            1
#  8         NaN        NaN  Olho d'Água do Casado            1
#  9         NaN    ALAGOAS    Palmeira dos Índios            1
#  10        NaN        NaN                 Penedo            1
#  11        NaN        NaN              Piaçabuçu            1
#  12        NaN        NaN   Poço das Trincheiras            1
#  13        NaN        NaN     Santana do Ipanema            1
# ...
