# %%
import warnings
import pandas as pd
from pandas.core.common import SettingWithCopyWarning
import numpy as np
import json
import os

# %%
pd.options.display.max_rows = 999
pd.options.display.max_columns=999
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# %%
arquivoItem = 'C:\\Temp\\OP_OGMO01.20220731.204641'

dfItem = pd.read_csv(arquivoItem, header=None, sep=';',low_memory=False)

dfItem.rename(columns={0:'CodRelatorio', 1:'CodItem',4:'Dta'}, inplace=True)

#dfItem = dfItem[['CodRelatorio', 'CodItem']]

dfItem.groupby(['Dta']).agg(qtd=('CodRelatorio','count')).reset_index().sort_values(by=['qtd'],ascending=False)
# Out:
#           Dta    qtd
# 109  20220729  22076
# 110  20220730   7668
# 112  20220801   7166
# 108  20220728   5149
# 107  20220727    870
# 106  20220726    399
# 88   20220701    198
# 10   20200203    192
# 105  20220725    185
# 113  20220802    109
# 111  20220731     95
# 103  20220722     52
# 11   20200204     46
# 94   20220712     39
# 101  20220720     37
# 92   20220708     34
# 126  20220830     30
# 56   20220401     29
# 57   20220404     28
# 95   20220713     24
# 96   20220714     24
# 93   20220711     22
# 9    20190904     22
# 91   20220707     19
# 102  20220721     18
# 34   20210326     18
# 115  20220804     17
# 55   20220329     16
# 52   20220321     14
# 87   20220629     14
# 104  20220723     13
# 35   20210329     12
# 41   20211130     12
# 60   20220413     12
# 54   20220328     10
# 48   20220223     10
# 66   20220503     10
# 14   20200506     10
# 100  20220719     10
# 36   20210406     10
# 43   20211226      9
# 25   20201009      8
# ...
