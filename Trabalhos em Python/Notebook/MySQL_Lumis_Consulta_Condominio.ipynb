# %%
import warnings
import pandas as pd
import sqlalchemy
import pymysql
from pandas.core.common import SettingWithCopyWarning
import numpy as np
import json

# %%
pd.options.display.max_rows = 999
pd.options.display.max_columns=999
pd.options
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# %%
usuario = 'shvuser'
senha = 'IAn8DNWUKb'
ip_servidor = '172.31.39.250'
porta = '3306'
banco = 'LUMIS_SUPER'

enginemysql = sqlalchemy.create_engine(f'mysql+pymysql://{usuario}:{senha}@{ip_servidor}:{porta}/{banco}')

df = pd.read_sql_table('sgi_condominio',enginemysql)

df.head(3)
# Out:
#    id   codigo centro                               nome  \
# 0   1  1157423    C2A       CONDOMINIO EDIFICIO ANTARES;
# 1   2  1886797    C2A             CONDOMINIO MONTPELIER;
# 2   3  1889980    C2A  CONDOMINIO EDIFICIO NILO PECANHA;
#
#                logradouro  numero complemento             bairro       cep  \
# 0  RUA MADRE BARBARA MAIX   365.0              JARDIM ITU SABARA  91225200
# 1  RUA FELIPE DE OLIVEIRA  1260.0                     PETROPOLIS  90630000
# 2      AV DR NILO PECANHA   620.0                     PETROPOLIS  90470000
#
#          cidade   uf   origem        data_criacao  ultima_atualizacao  \
# 0  PORTO ALEGRE  RS   SAP CCS 2020-08-27 07:01:24 2020-08-27 07:01:24
# 1  PORTO ALEGRE  RS   SAP CCS 2019-11-11 01:19:03 2019-11-11 01:19:03
# 2  PORTO ALEGRE  RS   SAP CCS 2020-09-26 07:01:28 2020-09-26 07:01:28
#
#   id_sales_force planilha_enviada data_envio_planilha  cnpj flag_ativo
# 0           None             None                 NaT  None          S
# ...

# %%
df[df['codigo'].isin(['3977510'])]
# Out:
#         id   codigo centro                                    nome logradouro  \
# 4464  5883  3977510    BDF  CONVENCAO ADMIN DO BLOCO I DA SQS 207;    SQS 207
#
#       numero       complemento   bairro       cep    cidade   uf   origem  \
# 4464     NaN  BLOCO I PORTARIA  ASA SUL  70253090  BRASILIA  DF   SAP CCS
#
#             data_criacao  ultima_atualizacao id_sales_force planilha_enviada  \
# 4464 2022-12-16 17:41:25 2022-12-16 17:41:25           None             None
#
#      data_envio_planilha  cnpj flag_ativo
# 4464                 NaT  None          S

# %%
colunas = ['Codigo da Instalacao',
'Tipo de categoria da instalacao',
'Tipo de Instalacao',
'Quantidade de Tanques',
'Capacidade de instalacao',
'Objeto de Ligacao',
'Codigo Local Instalacao Superior',
'Rua do Objeto de Ligacao',
'Numero do Objeto de ligacao',
'Bairro de residencia do objeto de ligacao',
'Complemento do objeto de ligacao',
'Codigo Postal do Objeto de Ligacao',
'Cidade do Objeto de Ligacao',
'Pais do Objeto de Ligacao',
'Regiao do Objeto de Ligacao',
'Apto/Sala do Local de Consumo',
'BL/Loja do Local de Consumo',
'Fator de Conversao da Categoria de Tarifa',
'Fator de Conversao do Operando da Instalacao',
'Preco da Instalacao',
'Preco do Condominio',
'Tipo do Preco',
'Unidade de Leitura',
'Conjunto de Contrato',
'Centro',
'Status da Instalacao',
'Status da Suspensao',
'Contrato',
'Codigo de eliminacao',
'Data da atualizacao'
]
dtype = {'Codigo da Instalacao':'str',
'Tipo de categoria da instalacao':'str',
'Tipo de Instalacao':'str',
'Quantidade de Tanques':'str',
'Capacidade de instalacao':'str',
'Objeto de Ligacao':'str',
'Codigo Local Instalacao Superior':'str',
'Rua do Objeto de Ligacao':'str',
'Numero do Objeto de ligacao':'str',
'Bairro de residencia do objeto de ligacao':'str',
'Complemento do objeto de ligacao':'str',
'Codigo Postal do Objeto de Ligacao':'str',
'Cidade do Objeto de Ligacao':'str',
'Pais do Objeto de Ligacao':'str',
'Regiao do Objeto de Ligacao':'str',
'Apto/Sala do Local de Consumo':'str',
'BL/Loja do Local de Consumo':'str',
'Fator de Conversao da Categoria de Tarifa':'str',
'Fator de Conversao do Operando da Instalacao':'str',
'Preco da Instalacao':'str',
'Preco do Condominio':'str',
'Tipo do Preco':'str',
'Unidade de Leitura':'str',
'Conjunto de Contrato':'str',
'Centro':'str',
'Status da Instalacao':'str',
'Status da Suspensao':'str',
'Contrato':'str',
'Codigo de eliminacao':'str',
'Data da atualizacao':'str'
        }

# %%
arquivoInstaacaoCCS = 'EXTDADOSINSTALACAO_20220622200731.csv'


condominiosInstalacoes = pd.read_csv(arquivoInstaacaoCCS,sep=';',low_memory=False,names=colunas, dtype=dtype,index_col=False)

# %%
condominiosInstalacoes[condominiosInstalacoes['Codigo Local Instalacao Superior']=='3835856']
# Out:
#       Codigo da Instalacao Tipo de categoria da instalacao Tipo de Instalacao  \
# 90570           0000069340                               P                PLD
#
#       Quantidade de Tanques Capacidade de instalacao Objeto de Ligacao  \
# 90570                     3                 1.362,00             OLC2A
#
#       Codigo Local Instalacao Superior Rua do Objeto de Ligacao  \
# 90570                          3835856                  RUA FAB
#
#       Numero do Objeto de ligacao Bairro de residencia do objeto de ligacao  \
# 90570                         403                  NOSSA SENHORA DAS GRACAS
#
#       Complemento do objeto de ligacao Codigo Postal do Objeto de Ligacao  \
# 90570                              NaN                          92110-030
#
#       Cidade do Objeto de Ligacao Pais do Objeto de Ligacao  \
# 90570                      CANOAS                        BR
#
#       Regiao do Objeto de Ligacao Apto/Sala do Local de Consumo  \
# ...

# %%
arquivoCondominioCCS = 'EXTCONDOMINIO_20220622200016.csv'


condominios = pd.read_csv(arquivoCondominioCCS,sep=';',low_memory=False,index_col=False)

condominios
# Out:
#       Codigo Local de Instalacao Superior  \
# 0                                 1004695
# 1                                 1019633
# 2                                 1030488
# 3                                 1032701
# 4                                 1032773
# ...                                   ...
# 6294                              3943787
# 6295                              3945295
# 6296                               912428
# 6297                               919174
# 6298                               959824
#
#                            Nome do Condominio  Unnamed: 2
# 0            CONDOMINIO DO BLOCO F DA SQN 115         NaN
# 1            CONDOMINIO DO BLOCO A DA SQS 113         NaN
# 2         CONDOMINIO DO EDIFICIO SANT LAURENT         NaN
# 3            CONDOMINIO DO BLOCO F DA SQS 312         NaN
# 4     CONDOMINIO RESIDENCIAL DA SQSW 104 BL J         NaN
# ...                                       ...         ...
# ...

# %%
dtypeCli= {'CUSTOMER':'str',       
'ACCNT_GRP':'str',     
'ADDR_NUMBR':'str',    
'AF_CUSTDC':'str',     
'AF_CUSTID':'str',     
'/BIC/CH_LATIT':'str', 
'APO_LOCNO':'str',     
'BPARTNER':'str',      
'CITY':'str',          
'CITY_2':'str',        
'COUNTRY':'str',       
'CUST_CLASS':'str',    
'CUST_MKT':'str',      
'CUS_F_CONS':'str',    
'DBDUNS_NUM':'str',    
'FAX_NUM':'str',       
'FISCVARNT':'str',     
'ID_TXNUMB3':'str',    
'ID_XCPD':'str',       
'INDUSTRY':'str',      
'IND_CODE_1':'str',    
'IND_CODE_2':'str',    
'IND_CODE_3':'str',    
'IND_CODE_4':'str',    
'IND_CODE_5':'str',    
'KEYACCOUNT':'str',    
'/BIC/CH_LONG':'str',  
'NAME':'str',          
'NAME2':'str',         
'NAME3':'str',         
'NIELSEN_ID':'str',    
'OUTL_TYPE':'str',     
'PCOMPANY':'str',      
'PHONE':'str',         
'PLANT':'str',         
'POBOX':'str',         
'POBOX_LOC':'str',     
'POSTAL_CD':'str',     
'POSTCD_BOX':'str',    
'POSTCD_GIS':'str',    
'PRECISID':'str',      
'REGION':'str',        
'SORTL':'str',         
'SRCID':'str',         
'STREET':'str',        
'TAX_NUMB':'str',      
'TAX_NUMB2':'str',     
'USAGE_IND':'str',     
'VENDOR':'str',        
'VISIT_RYT':'str',     
'DB_MATCH':'str',      
'CREATEDON':'str',     
'/BIC/CH_ZAUT_A':'str',
'/BIC/CH_ZINSCR':'str',
'/BIC/CH_ZDAT_A':'str',
'/BIC/CH_ZINST':'str', 
'/BIC/CH_ZANT':'str',  
'/BIC/CH_ZCAPEX':'str',
'/BIC/CH_ZCORP':'str', 
'/BIC/CH_ZKEYAC':'str',
'/BIC/CH_ZORG_P':'str',
'/BIC/CH_ZFLT':'str',  
'/BIC/CH_ZFLTEX':'str',
'/BIC/CH_ZECOD':'str', 
'/BIC/CH_ZSMG':'str',  
'/BIC/CH_ZTPC':'str',  
'/BIC/CH_ZGERAD':'str',
'/BIC/CH_ZCALD':'str', 
'/BIC/CH_ZFORN':'str', 
'/BIC/CH_ZUSINA':'str',
'/BIC/CH_ZVDNSP':'str',
'/BIC/CH_ZCOZIN':'str',
'/BIC/CH_ZMRA':'str',
'/BIC/CH_ZTERRI':'str',
'/BIC/CH_ZORDEM':'str',
'/BIC/CH_ZMESOR':'str',
'/BIC/CH_ZDESD':'str',
'/BIC/CH_ZATIV':'str',
'/BIC/CH_ZINAT':'str',
'/BIC/CH_KDGRP':'str',
'/BIC/CH_LOEVM':'str',
'/BIC/CH_RPMKR':'str',
'/BIC/CH_LZONE':'str',
'/BIC/CH_AUFSD':'str',
'/BIC/CH_NAMC4':'str',
'/BIC/CH_CNAE':'str',
'/BIC/CH_SFORCE':'str',
'/BIC/CH_DEAR5':'str',
'/BIC/CH_KONZS':'str',
'/BIC/CH_STCD5':'str',
'/BIC/CH_SUFRA':'str',
'/BIC/CH_ALTID':'str',
'/BIC/CH_STKZN':'str',
'/BIC/CH_STKZU':'str'}

colCli = ['CUSTOMER'       
,'ACCNT_GRP'     
,'ADDR_NUMBR'    
,'AF_CUSTDC'     
,'AF_CUSTID'     
,'/BIC/CH_LATIT' 
,'APO_LOCNO'     
,'BPARTNER'      
,'CITY'          
,'CITY_2'        
,'COUNTRY'       
,'CUST_CLASS'    
,'CUST_MKT'      
,'CUS_F_CONS'    
,'DBDUNS_NUM'    
,'FAX_NUM'       
,'FISCVARNT'     
,'ID_TXNUMB3'    
,'ID_XCPD'       
,'INDUSTRY'      
,'IND_CODE_1'    
,'IND_CODE_2'    
,'IND_CODE_3'    
,'IND_CODE_4'    
,'IND_CODE_5'    
,'KEYACCOUNT'    
,'/BIC/CH_LONG'  
,'NAME'          
,'NAME2'         
,'NAME3'         
,'NIELSEN_ID'    
,'OUTL_TYPE'     
,'PCOMPANY'      
,'PHONE'         
,'PLANT'         
,'POBOX'         
,'POBOX_LOC'     
,'POSTAL_CD'     
,'POSTCD_BOX'    
,'POSTCD_GIS'    
,'PRECISID'      
,'REGION'        
,'SORTL'         
,'SRCID'         
,'STREET'        
,'TAX_NUMB'      
,'TAX_NUMB2'     
,'USAGE_IND'     
,'VENDOR'        
,'VISIT_RYT'     
,'DB_MATCH'      
,'CREATEDON'     
,'/BIC/CH_ZAUT_A'
,'/BIC/CH_ZINSCR'
,'/BIC/CH_ZDAT_A'
,'/BIC/CH_ZINST' 
,'/BIC/CH_ZANT'  
,'/BIC/CH_ZCAPEX'
,'/BIC/CH_ZCORP' 
,'/BIC/CH_ZKEYAC'
,'/BIC/CH_ZORG_P'
,'/BIC/CH_ZFLT'  
,'/BIC/CH_ZFLTEX'
,'/BIC/CH_ZECOD' 
,'/BIC/CH_ZSMG'  
,'/BIC/CH_ZTPC'  
,'/BIC/CH_ZGERAD'
,'/BIC/CH_ZCALD' 
,'/BIC/CH_ZFORN' 
,'/BIC/CH_ZUSINA'
,'/BIC/CH_ZVDNSP'
,'/BIC/CH_ZCOZIN'
,'/BIC/CH_ZMRA'
,'/BIC/CH_ZTERRI'
,'/BIC/CH_ZORDEM'
,'/BIC/CH_ZMESOR'
,'/BIC/CH_ZDESD'
,'/BIC/CH_ZATIV'
,'/BIC/CH_ZINAT'
,'/BIC/CH_KDGRP'
,'/BIC/CH_LOEVM'
,'/BIC/CH_RPMKR'
,'/BIC/CH_LZONE'
,'/BIC/CH_AUFSD'
,'/BIC/CH_NAMC4'
,'/BIC/CH_CNAE'
,'/BIC/CH_SFORCE'
,'/BIC/CH_DEAR5'
,'/BIC/CH_KONZS'
,'/BIC/CH_STCD5'
,'/BIC/CH_SUFRA'
,'/BIC/CH_ALTID'
,'/BIC/CH_STKZN'
,'/BIC/CH_STKZU']

# %%
arquivoClienteECC = '0CUSTOMER_ATTR.20220622.201852'

clienteECC = pd.read_csv(arquivoClienteECC
                         ,sep=';'
                         ,error_bad_lines=False
                         ,engine='python'
                         ,index_col=False
                        ,names=colCli
                        ,dtype=dtypeCli)

clienteECC
# Out:
# Skipping line 372194: field larger than field limit (131072)
#           CUSTOMER ACCNT_GRP  ADDR_NUMBR AF_CUSTDC AF_CUSTID /BIC/CH_LATIT  \
# 0              NaN       NaN         NaN       NaN       NaN           NaN
# 1       0000000001      Z002  0000630221       NaN       NaN           NaN
# 2       0000000002      Z002  0000855690       NaN       NaN           NaN
# 3       0000000003      Z002  0000857332       NaN       NaN           NaN
# 4       0000000006      Z002  0000629603       NaN       NaN           NaN
# ...            ...       ...         ...       ...       ...           ...
# 664152       Z1431      ZSGB  0000902687       NaN       NaN           NaN
# 664153       Z1521      ZSGB  0000903458       NaN       NaN           NaN
# 664154       Z1721      ZSGB  0000903443       NaN       NaN           NaN
# 664155       Z1821      ZSGB  0000903557       NaN       NaN           NaN
# 664156       Z2021      ZSGB  0000903464       NaN       NaN           NaN
#
# ...

# %%
clienteECC[clienteECC['CUSTOMER']=='0003835856']
# Out:
#           CUSTOMER ACCNT_GRP  ADDR_NUMBR AF_CUSTDC AF_CUSTID /BIC/CH_LATIT  \
# 538903  0003835856      Z002  0004583539       NaN       NaN           NaN
#
#        APO_LOCNO BPARTNER             CITY       CITY_2 COUNTRY CUST_CLASS  \
# 538903       NaN      NaN  SAPUCAIA DO SUL  VILA JARDIM      BR          C
#
#        CUST_MKT CUS_F_CONS DBDUNS_NUM FAX_NUM FISCVARNT ID_TXNUMB3 ID_XCPD  \
# 538903      NaN        NaN  000000000     NaN       NaN     ISENTO     NaN
#
#        INDUSTRY IND_CODE_1 IND_CODE_2 IND_CODE_3 IND_CODE_4 IND_CODE_5  \
# 538903     0002       0012        NaN        NaN        NaN        NaN
#
#        KEYACCOUNT /BIC/CH_LONG                          NAME  \
# 538903        NaN          NaN  GIUNCIONE INCORPORACOES LTDA
#
#                                NAME2 NAME3 NIELSEN_ID OUTL_TYPE PCOMPANY  \
# 538903  GIUNCIONE INCORPORACOES LTDA   NaN         02       NaN      NaN
#
#                  PHONE PLANT  POBOX POBOX_LOC  POSTAL_CD POSTCD_BOX  \
# ...

# %%
dtypeCliEnd = {'ADDR_NUMBR':'str',
'DATEFROM':'str',
'/BIC/CH_NATION':'str',
'RECORDMODE':'str',
'COUNTRY':'str',
'DATETO':'str',
'FAX_NUMBER':'str',
'HOUSE_NUM1':'str',
'HOUSE_NUM2':'str',
'LANGU':'str',
'REGION':'str',
'ROOM_NUM':'str',
'STR_SUPPL1':'str',
'STR_SUPPL2':'str',
'STR_SUPPL3':'str',
'TEL_NUMBER':'str',
'TIME_ZONE':'str',
'/BIC/CH_ADDID':'str',
'/BIC/CH_ADDRGR':'str',
'/BIC/CH_ADDROR':'str',
'/BIC/CH_BUILDI':'str',
'/BIC/CH_CITY1':'str',
'/BIC/CH_CITY2':'str',
'/BIC/CH_CITYC':'str',
'/BIC/CH_CITYC2':'str',
'/BIC/CH_CITYH':'str',
'/BIC/CH_CITYP':'str',
'/BIC/CH_CKSTAT':'str',
'/BIC/CH_COMM10':'str',
'/BIC/CH_COMM11':'str',
'/BIC/CH_COMM12':'str',
'/BIC/CH_COMM13':'str',
'/BIC/CH_COMM2':'str',
'/BIC/CH_COMM3':'str',
'/BIC/CH_COMM4':'str',
'/BIC/CH_COMM5':'str',
'/BIC/CH_COMM6':'str',
'/BIC/CH_COMM7':'str',
'/BIC/CH_COMM8':'str',
'/BIC/CH_COMM9':'str',
'/BIC/CH_COUNTY':'str',
'/BIC/CH_DEFLT':'str',
'/BIC/CH_ERRST':'str',
'/BIC/CH_EXT01':'str',
'/BIC/CH_EXT02':'str',
'/BIC/CH_EXTENF':'str',
'/BIC/CH_EXTENS':'str',
'/BIC/CH_FLAGGR':'str',
'/BIC/CH_FLOOR':'str',
'/BIC/CH_FRMTR':'str',
'/BIC/CH_GEGUID':'str',
'/BIC/CH_HOMECT':'str',
'/BIC/CH_HOUSN3':'str',
'/BIC/CH_IDCAT':'str',
'/BIC/CH_LANGCR':'str',
'/BIC/CH_LOCT':'str',
'/BIC/CH_MCCIT1':'str',
'/BIC/CH_MCCOUN':'str',
'/BIC/CH_MCNAM1':'str',
'/BIC/CH_MCSTR1':'str',
'/BIC/CH_MCTOWN':'str',
'/BIC/CH_NAME1':'str',
'/BIC/CH_NAME2':'str',
'/BIC/CH_NAME3':'str',
'/BIC/CH_NAME4':'str',
'/BIC/CH_NAMEC':'str',
'/BIC/CH_NAMET':'str',
'/BIC/CH_NOTUSE':'str',
'/BIC/CH_NOTUSS':'str',
'/BIC/CH_PCOD1X':'str',
'/BIC/CH_PCOD2X':'str',
'/BIC/CH_PCOD3X':'str',
'/BIC/CH_PCODE1':'str',
'/BIC/CH_PCODE2':'str',
'/BIC/CH_PCODE3':'str',
'/BIC/CH_PERSAD':'str',
'/BIC/CH_POBOX':'str',
'/BIC/CH_POBOXB':'str',
'/BIC/CH_POBOXC':'str',
'/BIC/CH_POBOXL':'str',
'/BIC/CH_POBOXN':'str',
'/BIC/CH_POBOXR':'str',
'/BIC/CH_POSTAR':'str',
'/BIC/CH_REGGRP':'str',
'/BIC/CH_SERVN':'str',
'/BIC/CH_SERVT':'str',
'/BIC/CH_SORT1':'str',
'/BIC/CH_SORT2':'str',
'/BIC/CH_SORTPF':'str',
'/BIC/CH_STREEA':'str',
'/BIC/CH_STREET':'str',
'/BIC/CH_TAXCD':'str',
'/BIC/CH_TOWNCD':'str',
'/BIC/CH_TOWNSH':'str',
'/BIC/CH_TRNSPZ':'str',
'/BIC/CH_UUIDAD':'str',
'/BIC/CH_UUIDBE':'str',
'/BIC/CH_XPCPT':'str',
'/BIC/CH_STRCD':'str',
'/BIC/CH_COUNCD':'str'}
colCliEnd = ['ADDR_NUMBR',
'DATEFROM',
'/BIC/CH_NATION',
'RECORDMODE',
'COUNTRY',
'DATETO',
'FAX_NUMBER',
'HOUSE_NUM1',
'HOUSE_NUM2',
'LANGU',
'REGION',
'ROOM_NUM',
'STR_SUPPL1',
'STR_SUPPL2',
'STR_SUPPL3',
'TEL_NUMBER',
'TIME_ZONE',
'/BIC/CH_ADDID',
'/BIC/CH_ADDRGR',
'/BIC/CH_ADDROR',
'/BIC/CH_BUILDI',
'/BIC/CH_CITY1',
'/BIC/CH_CITY2',
'/BIC/CH_CITYC',
'/BIC/CH_CITYC2',
'/BIC/CH_CITYH',
'/BIC/CH_CITYP',
'/BIC/CH_CKSTAT',
'/BIC/CH_COMM10',
'/BIC/CH_COMM11',
'/BIC/CH_COMM12',
'/BIC/CH_COMM13',
'/BIC/CH_COMM2',
'/BIC/CH_COMM3',
'/BIC/CH_COMM4',
'/BIC/CH_COMM5',
'/BIC/CH_COMM6',
'/BIC/CH_COMM7',
'/BIC/CH_COMM8',
'/BIC/CH_COMM9',
'/BIC/CH_COUNTY',
'/BIC/CH_DEFLT',
'/BIC/CH_ERRST',
'/BIC/CH_EXT01',
'/BIC/CH_EXT02',
'/BIC/CH_EXTENF',
'/BIC/CH_EXTENS',
'/BIC/CH_FLAGGR',
'/BIC/CH_FLOOR',
'/BIC/CH_FRMTR',
'/BIC/CH_GEGUID',
'/BIC/CH_HOMECT',
'/BIC/CH_HOUSN3',
'/BIC/CH_IDCAT',
'/BIC/CH_LANGCR',
'/BIC/CH_LOCT',
'/BIC/CH_MCCIT1',
'/BIC/CH_MCCOUN',
'/BIC/CH_MCNAM1',
'/BIC/CH_MCSTR1',
'/BIC/CH_MCTOWN',
'/BIC/CH_NAME1',
'/BIC/CH_NAME2',
'/BIC/CH_NAME3',
'/BIC/CH_NAME4',
'/BIC/CH_NAMEC',
'/BIC/CH_NAMET',
'/BIC/CH_NOTUSE',
'/BIC/CH_NOTUSS',
'/BIC/CH_PCOD1X',
'/BIC/CH_PCOD2X',
'/BIC/CH_PCOD3X',
'/BIC/CH_PCODE1',
'/BIC/CH_PCODE2',
'/BIC/CH_PCODE3',
'/BIC/CH_PERSAD',
'/BIC/CH_POBOX',
'/BIC/CH_POBOXB',
'/BIC/CH_POBOXC',
'/BIC/CH_POBOXL',
'/BIC/CH_POBOXN',
'/BIC/CH_POBOXR',
'/BIC/CH_POSTAR',
'/BIC/CH_REGGRP',
'/BIC/CH_SERVN',
'/BIC/CH_SERVT',
'/BIC/CH_SORT1',
'/BIC/CH_SORT2',
'/BIC/CH_SORTPF',
'/BIC/CH_STREEA',
'/BIC/CH_STREET',
'/BIC/CH_TAXCD',
'/BIC/CH_TOWNCD',
'/BIC/CH_TOWNSH',
'/BIC/CH_TRNSPZ',
'/BIC/CH_UUIDAD',
'/BIC/CH_UUIDBE',
'/BIC/CH_XPCPT',
'/BIC/CH_STRCD',
'/BIC/CH_COUNCD']

# %%
arquivoClienteEderecoECC = 'DA_AD004.20220621.201149'

ClienteEderecoECC = pd.read_csv(arquivoClienteEderecoECC
                         ,sep=';'
                         ,error_bad_lines=False
                         ,engine='python'
                         ,index_col=False
                               ,names=colCliEnd
                               ,dtype=dtypeCliEnd)

ClienteEderecoECC
# Out:
#          ADDR_NUMBR  DATEFROM /BIC/CH_NATION RECORDMODE COUNTRY    DATETO  \
# 0        0000022970  00010101            NaN        NaN      BR  99991231
# 1        0000022971  00010101            NaN        NaN      BR  99991231
# 2        0000022972  00010101            NaN        NaN      BR  99991231
# 3        0000022973  00010101            NaN        NaN      BR  99991231
# 4        0000022974  00010101            NaN        NaN      BR  99991231
# ...             ...       ...            ...        ...     ...       ...
# 1177926  9000000020  00010101            NaN        NaN      BR  99991231
# 1177927  9000000021  00010101            NaN        NaN      BR  99991231
# 1177928  9000000022  00010101            NaN        NaN      BR  99991231
# 1177929  9000000040  00010101            NaN        NaN      BR  99991231
# 1177930  9000000041  00010101            NaN        NaN      BR  99991231
#
#             FAX_NUMBER HOUSE_NUM1 HOUSE_NUM2 LANGU REGION ROOM_NUM  \
# ...

# %%
ClienteEderecoECC[ClienteEderecoECC['ADDR_NUMBR']=='0004583539']
# Out:
#         ADDR_NUMBR  DATEFROM /BIC/CH_NATION RECORDMODE COUNTRY    DATETO  \
# 996527  0004583539  00010101            NaN        NaN      BR  99991231
#
#        FAX_NUMBER HOUSE_NUM1 HOUSE_NUM2 LANGU REGION ROOM_NUM STR_SUPPL1  \
# 996527        NaN        151        NaN     P     RS      NaN        NaN
#
#        STR_SUPPL2 STR_SUPPL3      TEL_NUMBER TIME_ZONE /BIC/CH_ADDID  \
# 996527        NaN        NaN  (51)99387-8287    BRZLEA           NaN
#
#        /BIC/CH_ADDRGR /BIC/CH_ADDROR /BIC/CH_BUILDI    /BIC/CH_CITY1  \
# 996527             BP            NaN            NaN  SAPUCAIA DO SUL
#
#        /BIC/CH_CITY2 /BIC/CH_CITYC /BIC/CH_CITYC2 /BIC/CH_CITYH /BIC/CH_CITYP  \
# 996527   VILA JARDIM           NaN            NaN           NaN           NaN
#
#        /BIC/CH_CKSTAT /BIC/CH_COMM10 /BIC/CH_COMM11 /BIC/CH_COMM12  \
# 996527            NaN            NaN            NaN            NaN
#
#        /BIC/CH_COMM13 /BIC/CH_COMM2 /BIC/CH_COMM3 /BIC/CH_COMM4 /BIC/CH_COMM5  \
# ...

# %%
condominiosInstalacoes[condominiosInstalacoes['Tipo de Instalacao']=='PLD'].head(3)
# Out:
#   Codigo da Instalacao Tipo de categoria da instalacao Tipo de Instalacao  \
# 1           0000019521                               P                PLD
# 2           0000019522                               P                PLD
# 3           0000019527                               P                PLD
#
#   Quantidade de Tanques Capacidade de instalacao Objeto de Ligacao  \
# 1                     1                 1.362,00             OLB2G
# 2                     0                     0,00             OLB2G
# 3                     1                 2.270,00             OLB2G
#
#   Codigo Local Instalacao Superior      Rua do Objeto de Ligacao  \
# 1                           917471       RUA A 3 QD 03 LTS 01 21
# 2                          1056756                           NaN
# 3                           919661  AV MILAO COM AV NAPOLI QD 09
#
#   Numero do Objeto de ligacao Bairro de residencia do objeto de ligacao  \
# ...

# %%
condominiosInstalacoes[condominiosInstalacoes['Codigo Local Instalacao Superior']=='1061827'].head(3)
# Out:
#      Codigo da Instalacao Tipo de categoria da instalacao Tipo de Instalacao  \
# 702            0000033592                               P                PLD
# 1340           0000005397                               P                PLD
# 1343           0000005425                               P                PLD
#
#      Quantidade de Tanques Capacidade de instalacao Objeto de Ligacao  \
# 702                      1                   454,00             OLNNA
# 1340                     0                     0,00             OLB2A
# 1343                     1                     0,00             OLB2A
#
#      Codigo Local Instalacao Superior Rua do Objeto de Ligacao  \
# 702                           1061827       R PRAIA DE BARRETA
# 1340                          1061827                      NaN
# 1343                          1061827                      NaN
#
#      Numero do Objeto de ligacao Bairro de residencia do objeto de ligacao  \
# ...

# %%
result = pd.merge(left=df
                                              , right=condominiosInstalacoes
                                              , left_on='codigo'
                                              , right_on='Codigo Local Instalacao Superior'
                                                                                              
                                    )

# %%
result[result['codigo'].isin(['3940748','3940750'])][['codigo','logradouro','numero','Rua do Objeto de Ligacao','Numero do Objeto de ligacao']]
# Out:
#        codigo            logradouro  numero Rua do Objeto de Ligacao  \
# 5356  3940748  RUA FERNANDO CAMARGO   161.0              RUA ESPANHA
#
#      Numero do Objeto de ligacao
# 5356                         351

# %%
result.loc[result['logradouro'] == result['Rua do Objeto de Ligacao'], 'Comparacao'] = 'Igual'
result.loc[result['logradouro'] != result['Rua do Objeto de Ligacao'], 'Comparacao'] = 'Diferente'

# %%
result[result['Comparacao']=='Diferente'][['codigo','logradouro','numero','Rua do Objeto de Ligacao','Numero do Objeto de ligacao','Comparacao']].to_csv('de_para.csv',sep=';',index=False)

# %%
clienteECC[clienteECC['CUSTOMER']=='0003940748']
# Out:
#           CUSTOMER ACCNT_GRP  ADDR_NUMBR AF_CUSTDC AF_CUSTID /BIC/CH_LATIT  \
# 643795  0003940748      Z002  0004902364       NaN       NaN           NaN
#
#        APO_LOCNO BPARTNER       CITY  CITY_2 COUNTRY CUST_CLASS CUST_MKT  \
# 643795       NaN      NaN  AMERICANA  CENTRO      BR          E      NaN
#
#        CUS_F_CONS DBDUNS_NUM FAX_NUM FISCVARNT ID_TXNUMB3 ID_XCPD INDUSTRY  \
# 643795        NaN  000000000     NaN       NaN     ISENTO     NaN     0002
#
#        IND_CODE_1 IND_CODE_2 IND_CODE_3 IND_CODE_4 IND_CODE_5 KEYACCOUNT  \
# 643795       0034        NaN        NaN        NaN        NaN        NaN
#
#        /BIC/CH_LONG                                NAME  \
# 643795          NaN  DMTD BALDIN EMPR IMOBILIARIOS LTDA
#
#                                      NAME2 NAME3 NIELSEN_ID OUTL_TYPE  \
# 643795  DMTD BALDIN EMPR IMOBILIARIOS LTDA   NaN         02       NaN
#
#        PCOMPANY           PHONE PLANT  POBOX POBOX_LOC  POSTAL_CD POSTCD_BOX  \
# ...

# %%
resultCli = pd.merge(left=clienteECC
                                              , right=ClienteEderecoECC
                                              , left_on='ADDR_NUMBR'
                                              , right_on='ADDR_NUMBR'
                                                                                              
                                    )

# %%
resultCli[resultCli['CUSTOMER'].isin(['0003940748','0003940750'])][['CUSTOMER','ACCNT_GRP','NAME','STREET']]
# Out:
#           CUSTOMER ACCNT_GRP                                NAME  \
# 639477  0003940748      Z002  DMTD BALDIN EMPR IMOBILIARIOS LTDA
# 639479  0003940750      0002  DMTD BALDIN EMPR IMOBILIARIOS LTDA
#
#                           STREET
# 639477  RUA FERNANDO CAMARGO 161
# 639479           RUA ESPANHA 351
