# %%
import pandas as pd

# %%
arquivo = pd.read_csv('CRTLDespesaFrota.20220511.213846',sep=';',header=None)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (1,4,18,21,24,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
arquivo[arquivo[4] == 231823556]
# Out:
#                0           1        2       3            4             5   \
# 389224  VIA FACIL  0002100444  DSE4205  1012.0  231823556.0  1.000000e+09
# 389338  VIA FACIL  0002100444  DSG1271  1012.0  231823556.0  1.000000e+09
# 389415  VIA FACIL  0002100444  DSZ8489  1024.0  231823556.0  1.000000e+09
# 389440  VIA FACIL  0002100444  DSZ9563  1012.0  231823556.0  1.000000e+09
# 389583  VIA FACIL  0002100444  DWB1516  1067.0  231823556.0  1.000000e+09
# 389751  VIA FACIL  0002100444  DXE3921  1031.0  231823556.0  1.000000e+09
# 389844  VIA FACIL  0002100444  DXE4261  1012.0  231823556.0  1.000000e+09
# 390323  VIA FACIL  0002100444  EFT8092  1012.0  231823556.0  1.000000e+09
# 390456  VIA FACIL  0002100444  EKX1086  1035.0  231823556.0  1.000000e+09
# 390496  VIA FACIL  0002100444  EKX1096  1035.0  231823556.0  1.000000e+09
# 390577  VIA FACIL  0002100444  ENH3876  1035.0  231823556.0  1.000000e+09
# 390712  VIA FACIL  0002100444  ENX1804  1012.0  231823556.0  1.000000e+09
# ...
